# %% [markdown]
# SciVis2023 Full Dataset Processing Pipeline

# %%
## Step 1: Split per-sensor input files into manageable chuncks

import os

input_dir = "viz-stimulus"  # "input"       # Directory containing the input files
output_dir = "output-stimulus"   #-lesion     # Directory to store the output chunks
chunk_size = 300          # Number of lines in each chunk (300 lines per 30 seconds)
line_interval = 100       # Sampling interval in milliseconds (100ms interval)
sensor_files = 50000      # Total number of input sensor files

def get_chunk_filename(sensor_id, begin_ms):
    return f"{output_dir}/simstep_{sensor_id}_{begin_ms}.csv"

def preprocess_file(input_file):
    #sensor_id = int(input_file.split(".")[0].split("_")[1], 16) # Convert hexadecimal to integer
    sensor_id = input_file.split(".")[0].split(".")[0].split("_")[1]
    line_count = 0

    with open('simsplit.log', 'a') as log_file:
        print(f"sensor_id: {sensor_id}", file=log_file)

        with open(input_file, 'r') as infile:
            chunk_lines = []
            for line in infile:
                chunk_lines.append(line.strip())
                line_count += 1
                if line_count % chunk_size == 0:
                    begin_ms = line_count * line_interval
                    chunk_filename = get_chunk_filename(sensor_id, begin_ms)

                    print(f"writing: {chunk_filename}", file=log_file)

                    with open(chunk_filename, 'w') as outfile:
                        outfile.write('\n'.join(chunk_lines))
                    chunk_lines.clear()

            # Save any remaining lines as a last chunk
            if chunk_lines:
                begin_ms = line_count * line_interval
                chunk_filename = get_chunk_filename(sensor_id, begin_ms)
                with open(chunk_filename, 'w') as outfile:
                    outfile.write('\n'.join(chunk_lines))
            
    
if __name__ == "__main__":
    os.makedirs(output_dir, exist_ok=True)

    print("Beginnng splitting process. Writing log file: simsplit.log"
    # Process each input file in the input directory
    for i in range(sensor_files):
        input_file = os.path.join(input_dir, f"0_{i}.csv")
        with open('simsplit.log', 'a') as log_file:
            print(f"Visiting: {input_file}",file=log_file)
        # break # stop after first file to testing
        preprocess_file(input_file)

# %%
# average fine grain data to chuncks
import os

input_dir = "output-stimulus"     #-lesion      # Directory containing the output chunks
output_dir = "averages-stimulus"  #-lesion   # Directory to store the averaged data
chunk_size = 100          # Number of lines in each chunk (100 lines per 10 seconds)
line_interval = 100       # Sampling interval in milliseconds (100ms interval)

def get_output_filename(sensor_id, begin_ms):
    return f"{output_dir}/averaged_{sensor_id}_{begin_ms}.csv"

def aggregate_data(input_file):
    sensor_id = int(input_file.split(".")[0].split("_")[1])
    begin_ms = int(input_file.split(".")[0].split("_")[2])
    output_filename = get_output_filename(sensor_id, begin_ms)

    with open(input_file, 'r') as infile:
        chunk_lines = []
        aggregated_data = []
        for line in infile:
            chunk_lines.append(line.strip())
            if len(chunk_lines) == chunk_size:
                avg_data = [sum(values) / len(values) for values in zip(*[map(float, line.split(";")) for line in chunk_lines])]
                avg_data[0] = begin_ms
                aggregated_data.append(avg_data)
                chunk_lines.clear()

        # Save the aggregated data to the output file
        with open(output_filename, 'w') as outfile:
            for idx, avg_data in enumerate(aggregated_data):
                if idx == 1:
                    avg_data[0] += 10000
                elif idx == 2:
                    avg_data[0] += 20000
                outfile.write(";".join(map(str, avg_data)))
                outfile.write("\n")
                begin_ms += line_interval

if __name__ == "__main__":
    os.makedirs(output_dir, exist_ok=True)

    print("Beginnng data averaging process. Writing log file: simavg.log")
    
    # Process each file in the "output" directory
    for file in os.listdir(input_dir):
        with open('simavg.log', 'a') as log_file:
            print(f"Visiting: {file}",file=log_file)
        if file.endswith(".csv"):
            input_file = os.path.join(input_dir, file)
            aggregate_data(input_file)

    print("Completed data averaging process. See log file: simavg.log")
# Out:
# Beginnng data averaging process. Writing log file: simavg.log

# %%
import os

input_dir = "averages-lesion" #"-calcium" #"-stimulus" #"-lesion"     # Directory containing the input files
output_dir = "aggregates-lesion" #"-calcium" #-stimulus" #"-lesion"  # Directory to store the aggregated data
sensor_files = 50000       # Total number of sensor files
timestamps = range(0, 970000, 30000)  # Timestamps from 0 to 970000 in steps of 30000

def get_output_filename(timestamp):
    return f"{output_dir}/simagg_{timestamp}.csv"

def process_file(input_file):
    sensor_id = int(input_file.split(".")[0].split("_")[1])
    try:
        with open(input_file, 'r') as infile:
            lines = infile.readlines()[:3]  # Process only the first 3 lines of each input file
            for idx in range(0, len(lines)):
                line = lines[idx].strip()
                timestamp = line.split(";")[0]
                output_filename = get_output_filename(timestamp)

                values = line.split(";")[1:]  # Extracting the 12 values after the first timestamp
                values_rounded = [round(float(value), 4) for value in values]  # Round each value to 4 decimal digits
                values_str = ";".join(map(str, values_rounded))

                if not os.path.exists(output_filename):
                    # Write the headings on the first line if the file doesn't exist
                    with open(output_filename, 'a') as outfile:
                        outfile.write("SensorID;" + ";".join(["Step", "Fired", "FiredFraction", "ElectricActivity",
                                                             "Inhibition", "Calcium", "TargetCalcium", "SynapticInput",
                                                             "BackgroundActivity", "GrownAxons", "ConnectedAxons",
                                                             "GrownDendrites", "ConnectedDendrites"]) + "\n")

                with open(output_filename, 'a') as outfile:
                    outfile.write(f"{sensor_id};{values_str}\n")

                with open('simagg.log', 'a') as log_file:
                    print(f"Appending line: {sensor_id};{values_str} to file: {output_filename}",file=log_file)

    except FileNotFoundError:
        with open('simagg.log', 'a') as log_file:
            print(f"File not found: {input_file}",file=log_file)

if __name__ == "__main__":
    os.makedirs(output_dir, exist_ok=True)

    print("Beginnng data aggregation process. Writing log file: simagg.log")

    # Process each file in the "averages" directory
    for i in range(sensor_files):
        for timestamp in timestamps:
            input_file = os.path.join(input_dir, f"averaged_{i}_{timestamp}.csv")
            with open('simagg.log', 'a') as log_file:
                print(f"Visiting: {input_file}",file=log_file)
            process_file(input_file)
    print("Completed data aggregation process. See log file: simagg.log")
# Out:
# Beginnng data aggregation process. Writing log file: simagg.log
# Completed data aggregation process. See log file: simagg.log

# %%
# Merge Aggregates and Positions

import os
import csv

input_dir = "aggregates-stimulus" #"-lesion" #"-stimulus" #"-lesion"     # Directory containing the input files
output_dir = "merged-stimulus" #"-lesion" #"-calcium" #-stimulus" #"-lesion"  # Directory to store the aggregated data

#aggr_header = []
def merge_files():
    with open("positions.csv", 'r') as positions_file:
        positions_reader = csv.reader(positions_file)
        header = next(positions_reader)

        for filename in os.listdir(input_dir): #"-stimulus"):
            if filename.endswith(".csv"):
                timestamp = filename.split("_")[1].split(".")[0]
                print(f"Opening aggregates file: {filename}")

                with open(os.path.join(input_dir, filename), 'r') as aggregate_file:
                    aggregate_reader = csv.reader(aggregate_file)
                    aggr_header = next(aggregate_reader)  # Skip header
                    print(f"{filename} header: {aggr_header}")

                    merged_filename = os.path.join(output_dir, f"merged_data_{timestamp}.csv")
                    with open(merged_filename, 'w', newline='') as merged_file:
                        merged_writer = csv.writer(merged_file)
                        new_header = aggr_header[0].split(";")[0:]
                        new_header = header  + new_header[2:]
                        print(new_header) #[1] = header[1]
                        merged_writer.writerow(new_header) ##[1] + aggr_header[2])  ##  ["Fired", "Calcium"])

                        # Reset positions_reader to the beginning of the file
                        positions_file.seek(0)
                        next(positions_reader)  # Skip header

                        for pos_row, aggr_row_text in zip(positions_reader, aggregate_reader):
                            aggr_row = aggr_row_text[0].split(";")
                            sensor_id = aggr_row[0]
                            #print(f"Sensor ID: {sensor_id}")
                            #print(f"pos_row: {pos_row}")
                            #print(f"aggr_row: {aggr_row}")

                            data_to_write = pos_row[0:] + aggr_row[1:]#, aggr_row[2], aggr_row[3], aggr_row[4], aggr_row[5], aggr_row[6], aggr_row[7], aggr_row[8], aggr_row[9], aggr_row[10], aggr_row[11], aggr_row[12]]
                            #print(f"Data to write: {data_to_write}")
                            merged_writer.writerow(data_to_write)
                    #break # stop after first output file

if __name__ == "__main__":
    os.makedirs(output_dir, exist_ok=True)
    merge_files()
# Out:
# Opening aggregates file: simagg_190000.csv
# simagg_190000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_310000.csv
# simagg_310000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_520000.csv
# simagg_520000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_420000.csv
# simagg_420000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_600000.csv
# simagg_600000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_800000.csv
# simagg_800000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_510000.csv
# simagg_510000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_620000.csv
# simagg_620000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_30000.csv
# simagg_30000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_760000.csv
# simagg_760000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_650000.csv
# simagg_650000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_820000.csv
# simagg_820000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_250000.csv
# simagg_250000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_890000.csv
# simagg_890000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_240000.csv
# simagg_240000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_290000.csv
# simagg_290000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_690000.csv
# simagg_690000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_390000.csv
# simagg_390000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_850000.csv
# simagg_850000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_830000.csv
# simagg_830000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_450000.csv
# simagg_450000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_950000.csv
# simagg_950000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_120000.csv
# simagg_120000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_920000.csv
# simagg_920000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_810000.csv
# simagg_810000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_320000.csv
# simagg_320000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_730000.csv
# simagg_730000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_660000.csv
# simagg_660000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_740000.csv
# simagg_740000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_750000.csv
# simagg_750000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_210000.csv
# simagg_210000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_280000.csv
# simagg_280000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_960000.csv
# simagg_960000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_630000.csv
# simagg_630000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_840000.csv
# simagg_840000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_150000.csv
# simagg_150000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_80000.csv
# simagg_80000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_610000.csv
# simagg_610000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_560000.csv
# simagg_560000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_500000.csv
# simagg_500000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_930000.csv
# simagg_930000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_980000.csv
# simagg_980000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_440000.csv
# simagg_440000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_780000.csv
# simagg_780000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_580000.csv
# simagg_580000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_380000.csv
# simagg_380000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_900000.csv
# simagg_900000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_700000.csv
# simagg_700000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_130000.csv
# simagg_130000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_360000.csv
# simagg_360000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_330000.csv
# simagg_330000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_100000.csv
# simagg_100000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_460000.csv
# simagg_460000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_90000.csv
# simagg_90000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_570000.csv
# simagg_570000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_350000.csv
# simagg_350000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_200000.csv
# simagg_200000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_490000.csv
# simagg_490000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_400000.csv
# simagg_400000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_640000.csv
# simagg_640000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_680000.csv
# simagg_680000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_970000.csv
# simagg_970000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_160000.csv
# simagg_160000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_340000.csv
# simagg_340000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_910000.csv
# simagg_910000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_70000.csv
# simagg_70000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_590000.csv
# simagg_590000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_260000.csv
# simagg_260000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_270000.csv
# simagg_270000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_860000.csv
# simagg_860000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_60000.csv
# simagg_60000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_790000.csv
# simagg_790000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_470000.csv
# simagg_470000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_770000.csv
# simagg_770000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_870000.csv
# simagg_870000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_720000.csv
# simagg_720000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_110000.csv
# simagg_110000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_370000.csv
# simagg_370000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_710000.csv
# simagg_710000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_220000.csv
# simagg_220000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_410000.csv
# simagg_410000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_940000.csv
# simagg_940000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_530000.csv
# simagg_530000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_180000.csv
# simagg_180000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_480000.csv
# simagg_480000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_430000.csv
# simagg_430000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_550000.csv
# simagg_550000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_230000.csv
# simagg_230000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_880000.csv
# simagg_880000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_170000.csv
# simagg_170000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_540000.csv
# simagg_540000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_50000.csv
# simagg_50000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_40000.csv
# simagg_40000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_300000.csv
# simagg_300000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_670000.csv
# simagg_670000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']
# Opening aggregates file: simagg_140000.csv
# simagg_140000.csv header: ['SensorID;Step;Fired;FiredFraction;ElectricActivity;Inhibition;Calcium;TargetCalcium;SynapticInput;BackgroundActivity;GrownAxons;ConnectedAxons;GrownDendrites;ConnectedDendrites']
# ['label', 'anatomy', '', '', 'Fired', 'FiredFraction', 'ElectricActivity', 'Inhibition', 'Calcium', 'TargetCalcium', 'SynapticInput', 'BackgroundActivity', 'GrownAxons', 'ConnectedAxons', 'GrownDendrites', 'ConnectedDendrites']

# %%
# Final Merge With UMAP and Normalize
import pandas as pd
import numpy as np
import os
import re

# input_merged_dir = "merged-lesion" #"-calcium" # inpuddir -stimulus" #"
# input_umap_dir = "posinclust-lesion" #"viz-calcium-network/posinclust" #"viz-stimulus-network/posinclust" -stimulus" #"
# output_dir= "final-merged-lesion-natgrid" #"final-merged-stimulus-grid"
input_merged_dir = "merged-stimulus" #
input_umap_dir = "posinclust-stimulus" #
output_dir= "final-merged-stimulus-natgrid"


# Function to normalize values in columns
def normalize_column(col, min_value, max_value):
    # Replace NaN and Inf with specific values or handle them as needed
    col = col.fillna(0)  # Example: filling NaN with 0
    col = col.replace([np.inf, -np.inf], 0)  # Example: replacing infinite values with 0
    min_col = col.min()
    max_col = col.max()
    with open('simmergefin.log', 'a') as log_file:
        #print(f"sensor_id: {sensor_id}", file=log_file)
        print(min_col, max_col, file=log_file)
        print((col - min_col) / (max_col - min_col) * (max_value - min_value) + min_value, file=log_file)
    normalized_col = ((col - min_col) / (max_col - min_col) * (max_value - min_value) + min_value).astype(int)
    return normalized_col

# Function to post-process Clustering columns
def post_process_clustering(col):
    col_max = col.max()
    # Iterate through the range repeatedly until no more unused or solitary values are found
    for value in range(1, col_max + 1):
        count = (col == value).sum()
        if count == 0 or count == 1:
            missing_value = value
            col[col == col_max] = missing_value
            col_max -= 1
    return col
#The function iterates through the range of possible values and looks for any values that are missing or occur only once. When such a value is found, all instances of the maximum value in the column are replaced with that missing value, and col_max is decremented accordingly.
#This updated code should solve the problem without recursion and without a TypeError. You can use this function in the previous code to replace the existing post-processing function.

print("Beginnng final data merge and normalization process. Writing log file: simmergefin.log")
              
# Iterate through files in the posinclust folder
for filename in os.listdir(input_umap_dir):
    match = re.match(r'positions_(\d+)_(in|out)\.csv', filename)
    if match:
        timestamp, direction = match.groups()
        positions_umap_path = f'{input_umap_dir}/{filename}'
        #positions_isomap_path =  f'{input_isomap_dir}/{filename}'
        merged_path = f'{input_merged_dir}/merged_data_{timestamp}.csv'
        final_path = f'{output_dir}/final_merged_data_{timestamp}_{direction}.csv'

        print(f'Merging {positions_umap_path} and {merged_path} into {final_path}...')

        # Read the positions file
        positions_umap_data = pd.read_csv(positions_umap_path)
        positions_umap_data.columns = ["umap", "", "", "UMAPClustering","GridUMAPClustering"]
#         try:
#             positions_isomap_data = pd.read_csv(positions_isomap_path)
#         except FileNotFoundError:
#             print(f"File {positions_isomap_path} not found. Skipping to next file.")
#             continue  # Skip to next loop iteration
            
#         positions_isomap_data.columns = ["isomap", "", "", "IsomapGridClustering","IsomapClustering"]

        #Check and adjust "*Clustering" columns if there are zero values
        if 0 in positions_umap_data["UMAPClustering"]:
            positions_umap_data["UMAPClustering"] += 1
        if 0 in positions_umap_data["GridUMAPClustering"]:
            positions_umap_data["GridUMAPClustering"] += 1
        # if 0 in positions_isomap_data["IsomapGridClustering"]:
        #     positions_isomap_data["IsomapGridClustering"] += 1
        # if 0 in positions_isomap_data["IsomapClustering"]:
        #     positions_isomap_data["IsomapClustering"] += 1

        
        # Read the merged file, ignore header, and assign proper columns
        try:
            merged_data = pd.read_csv(merged_path) #, header=None, skiprows=1)
        except FileNotFoundError:
            print(f"File {merged_path} not found. Skipping to next file.")
            continue  # Skip to next loop iteration

        #merged_data.columns = ["label", "anatomy", "", "", "FiredClustering", "CalciumClustering"]

        # Append "Heatmaps" to first mirged column names after the 4th# Append "Clustering" to column names after the 4th
        new_columns = [col + "Heatmap" if idx > 3 else col for idx, col in enumerate(merged_data.columns)]
        new_columns[2] = ''
        new_columns[3] = ''
        
                
        # Assign the new column names to the DataFrame
        merged_data.columns = new_columns
        
        uncluster = []
        # Normalize values in columns 5 and 6 and all after in initial merge
        for col_name in new_columns[4:]: # + new_columns[11:]:  #[("FiredClustering", 9), ("CalciumClustering", 12)]:
            #col = merged_data[col_name]
            col = merged_data[col_name]
            #max_value = max(len(set(col)),20)
            if len(set(col)) < 10:
                max_value = len(set(col))
            else:
                max_value = 10
                
            if len(set(col)) > 1:
                normalized_col = normalize_column(col, 1, max_value)
            else:
                uncluster.append(col_name)
        
            if 0 in normalized_col:
                col += 1
            #normalized_col = normalize_column(col, 1, max_value)
            #normalized_col = post_process_clustering(normalized_col)
            merged_data[col_name] = normalized_col

        #new_col_name = col_name.replace("Clustering", "")
        #merged_data.rename(columns={col_name: new_col_name}, inplace=True)
        
        #for col_name in uncluster:
        with open('simmergefin.log', 'a') as log_file:
            print("uncluster",uncluster,file=log_file)
        merged_data.drop(columns=uncluster, inplace=True, errors='ignore')

        # Concatenate the merged_data and positions_data to place positions_data in columns 7-10
        final_data = pd.concat([merged_data, positions_umap_data], axis=1)

        # DONT Apply post-processing to all Clustering columns
        #for col_name in final_data.columns:
        #    if "Clustering" in col_name:
        #        final_data[col_name] = post_process_clustering(final_data[col_name])

        # Save the final data
        os.makedirs(output_dir, exist_ok=True)
        final_data.to_csv(final_path, index=False)

        
        with open('simmergefin.log', 'a') as log_file:
            print(f'Merged {positions_umap_path} and {merged_path} into {final_path}',file=log_file)
        print(f'Merged {positions_umap_path} and {merged_path} into {final_path}')

        
        # break # Stop after first file
print("Completed final data merge and normalization process. Wrote log file: simmergefin.log")
# Out:
# Beginnng final data merge and normalization process. Writing log file: simmergefin.log
# Merging posinclust-stimulus/positions_230000_out.csv and merged-stimulus/merged_data_230000.csv into final-merged-stimulus-natgrid/final_merged_data_230000_out.csv...
# Merged posinclust-stimulus/positions_230000_out.csv and merged-stimulus/merged_data_230000.csv into final-merged-stimulus-natgrid/final_merged_data_230000_out.csv
# Merging posinclust-stimulus/positions_290000_in.csv and merged-stimulus/merged_data_290000.csv into final-merged-stimulus-natgrid/final_merged_data_290000_in.csv...
# Merged posinclust-stimulus/positions_290000_in.csv and merged-stimulus/merged_data_290000.csv into final-merged-stimulus-natgrid/final_merged_data_290000_in.csv
# Merging posinclust-stimulus/positions_810000_out.csv and merged-stimulus/merged_data_810000.csv into final-merged-stimulus-natgrid/final_merged_data_810000_out.csv...
# Merged posinclust-stimulus/positions_810000_out.csv and merged-stimulus/merged_data_810000.csv into final-merged-stimulus-natgrid/final_merged_data_810000_out.csv
# Merging posinclust-stimulus/positions_750000_in.csv and merged-stimulus/merged_data_750000.csv into final-merged-stimulus-natgrid/final_merged_data_750000_in.csv...
# Merged posinclust-stimulus/positions_750000_in.csv and merged-stimulus/merged_data_750000.csv into final-merged-stimulus-natgrid/final_merged_data_750000_in.csv
# Merging posinclust-stimulus/positions_790000_out.csv and merged-stimulus/merged_data_790000.csv into final-merged-stimulus-natgrid/final_merged_data_790000_out.csv...
# Merged posinclust-stimulus/positions_790000_out.csv and merged-stimulus/merged_data_790000.csv into final-merged-stimulus-natgrid/final_merged_data_790000_out.csv
# Merging posinclust-stimulus/positions_270000_out.csv and merged-stimulus/merged_data_270000.csv into final-merged-stimulus-natgrid/final_merged_data_270000_out.csv...
# Merged posinclust-stimulus/positions_270000_out.csv and merged-stimulus/merged_data_270000.csv into final-merged-stimulus-natgrid/final_merged_data_270000_out.csv
# Merging posinclust-stimulus/positions_370000_out.csv and merged-stimulus/merged_data_370000.csv into final-merged-stimulus-natgrid/final_merged_data_370000_out.csv...
# Merged posinclust-stimulus/positions_370000_out.csv and merged-stimulus/merged_data_370000.csv into final-merged-stimulus-natgrid/final_merged_data_370000_out.csv
# Merging posinclust-stimulus/positions_250000_in.csv and merged-stimulus/merged_data_250000.csv into final-merged-stimulus-natgrid/final_merged_data_250000_in.csv...
# Merged posinclust-stimulus/positions_250000_in.csv and merged-stimulus/merged_data_250000.csv into final-merged-stimulus-natgrid/final_merged_data_250000_in.csv
# Merging posinclust-stimulus/positions_780000_in.csv and merged-stimulus/merged_data_780000.csv into final-merged-stimulus-natgrid/final_merged_data_780000_in.csv...
# Merged posinclust-stimulus/positions_780000_in.csv and merged-stimulus/merged_data_780000.csv into final-merged-stimulus-natgrid/final_merged_data_780000_in.csv
# Merging posinclust-stimulus/positions_210000_in.csv and merged-stimulus/merged_data_210000.csv into final-merged-stimulus-natgrid/final_merged_data_210000_in.csv...
# Merged posinclust-stimulus/positions_210000_in.csv and merged-stimulus/merged_data_210000.csv into final-merged-stimulus-natgrid/final_merged_data_210000_in.csv
# Merging posinclust-stimulus/positions_230000_in.csv and merged-stimulus/merged_data_230000.csv into final-merged-stimulus-natgrid/final_merged_data_230000_in.csv...
# Merged posinclust-stimulus/positions_230000_in.csv and merged-stimulus/merged_data_230000.csv into final-merged-stimulus-natgrid/final_merged_data_230000_in.csv
# Merging posinclust-stimulus/positions_800000_in.csv and merged-stimulus/merged_data_800000.csv into final-merged-stimulus-natgrid/final_merged_data_800000_in.csv...
# Merged posinclust-stimulus/positions_800000_in.csv and merged-stimulus/merged_data_800000.csv into final-merged-stimulus-natgrid/final_merged_data_800000_in.csv
# Merging posinclust-stimulus/positions_630000_out.csv and merged-stimulus/merged_data_630000.csv into final-merged-stimulus-natgrid/final_merged_data_630000_out.csv...
# Merged posinclust-stimulus/positions_630000_out.csv and merged-stimulus/merged_data_630000.csv into final-merged-stimulus-natgrid/final_merged_data_630000_out.csv
# Merging posinclust-stimulus/positions_210000_out.csv and merged-stimulus/merged_data_210000.csv into final-merged-stimulus-natgrid/final_merged_data_210000_out.csv...
# Merged posinclust-stimulus/positions_210000_out.csv and merged-stimulus/merged_data_210000.csv into final-merged-stimulus-natgrid/final_merged_data_210000_out.csv
# Merging posinclust-stimulus/positions_650000_in.csv and merged-stimulus/merged_data_650000.csv into final-merged-stimulus-natgrid/final_merged_data_650000_in.csv...
# Merged posinclust-stimulus/positions_650000_in.csv and merged-stimulus/merged_data_650000.csv into final-merged-stimulus-natgrid/final_merged_data_650000_in.csv
# Merging posinclust-stimulus/positions_150000_out.csv and merged-stimulus/merged_data_150000.csv into final-merged-stimulus-natgrid/final_merged_data_150000_out.csv...
# Merged posinclust-stimulus/positions_150000_out.csv and merged-stimulus/merged_data_150000.csv into final-merged-stimulus-natgrid/final_merged_data_150000_out.csv
# Merging posinclust-stimulus/positions_660000_out.csv and merged-stimulus/merged_data_660000.csv into final-merged-stimulus-natgrid/final_merged_data_660000_out.csv...
# Merged posinclust-stimulus/positions_660000_out.csv and merged-stimulus/merged_data_660000.csv into final-merged-stimulus-natgrid/final_merged_data_660000_out.csv
# Merging posinclust-stimulus/positions_130000_in.csv and merged-stimulus/merged_data_130000.csv into final-merged-stimulus-natgrid/final_merged_data_130000_in.csv...
# Merged posinclust-stimulus/positions_130000_in.csv and merged-stimulus/merged_data_130000.csv into final-merged-stimulus-natgrid/final_merged_data_130000_in.csv
# Merging posinclust-stimulus/positions_980000_out.csv and merged-stimulus/merged_data_980000.csv into final-merged-stimulus-natgrid/final_merged_data_980000_out.csv...
# Merged posinclust-stimulus/positions_980000_out.csv and merged-stimulus/merged_data_980000.csv into final-merged-stimulus-natgrid/final_merged_data_980000_out.csv
# Merging posinclust-stimulus/positions_10000_in.csv and merged-stimulus/merged_data_10000.csv into final-merged-stimulus-natgrid/final_merged_data_10000_in.csv...
# File merged-stimulus/merged_data_10000.csv not found. Skipping to next file.
# Merging posinclust-stimulus/positions_80000_out.csv and merged-stimulus/merged_data_80000.csv into final-merged-stimulus-natgrid/final_merged_data_80000_out.csv...
# Merged posinclust-stimulus/positions_80000_out.csv and merged-stimulus/merged_data_80000.csv into final-merged-stimulus-natgrid/final_merged_data_80000_out.csv
# Merging posinclust-stimulus/positions_960000_out.csv and merged-stimulus/merged_data_960000.csv into final-merged-stimulus-natgrid/final_merged_data_960000_out.csv...
# Merged posinclust-stimulus/positions_960000_out.csv and merged-stimulus/merged_data_960000.csv into final-merged-stimulus-natgrid/final_merged_data_960000_out.csv
# Merging posinclust-stimulus/positions_60000_in.csv and merged-stimulus/merged_data_60000.csv into final-merged-stimulus-natgrid/final_merged_data_60000_in.csv...
# Merged posinclust-stimulus/positions_60000_in.csv and merged-stimulus/merged_data_60000.csv into final-merged-stimulus-natgrid/final_merged_data_60000_in.csv
# Merging posinclust-stimulus/positions_840000_out.csv and merged-stimulus/merged_data_840000.csv into final-merged-stimulus-natgrid/final_merged_data_840000_out.csv...
# Merged posinclust-stimulus/positions_840000_out.csv and merged-stimulus/merged_data_840000.csv into final-merged-stimulus-natgrid/final_merged_data_840000_out.csv
# Merging posinclust-stimulus/positions_280000_out.csv and merged-stimulus/merged_data_280000.csv into final-merged-stimulus-natgrid/final_merged_data_280000_out.csv...
# Merged posinclust-stimulus/positions_280000_out.csv and merged-stimulus/merged_data_280000.csv into final-merged-stimulus-natgrid/final_merged_data_280000_out.csv
# Merging posinclust-stimulus/positions_490000_out.csv and merged-stimulus/merged_data_490000.csv into final-merged-stimulus-natgrid/final_merged_data_490000_out.csv...
# Merged posinclust-stimulus/positions_490000_out.csv and merged-stimulus/merged_data_490000.csv into final-merged-stimulus-natgrid/final_merged_data_490000_out.csv
# Merging posinclust-stimulus/positions_920000_out.csv and merged-stimulus/merged_data_920000.csv into final-merged-stimulus-natgrid/final_merged_data_920000_out.csv...
# Merged posinclust-stimulus/positions_920000_out.csv and merged-stimulus/merged_data_920000.csv into final-merged-stimulus-natgrid/final_merged_data_920000_out.csv
# Merging posinclust-stimulus/positions_530000_in.csv and merged-stimulus/merged_data_530000.csv into final-merged-stimulus-natgrid/final_merged_data_530000_in.csv...
# Merged posinclust-stimulus/positions_530000_in.csv and merged-stimulus/merged_data_530000.csv into final-merged-stimulus-natgrid/final_merged_data_530000_in.csv
# Merging posinclust-stimulus/positions_200000_in.csv and merged-stimulus/merged_data_200000.csv into final-merged-stimulus-natgrid/final_merged_data_200000_in.csv...
# Merged posinclust-stimulus/positions_200000_in.csv and merged-stimulus/merged_data_200000.csv into final-merged-stimulus-natgrid/final_merged_data_200000_in.csv
# Merging posinclust-stimulus/positions_950000_out.csv and merged-stimulus/merged_data_950000.csv into final-merged-stimulus-natgrid/final_merged_data_950000_out.csv...
# Merged posinclust-stimulus/positions_950000_out.csv and merged-stimulus/merged_data_950000.csv into final-merged-stimulus-natgrid/final_merged_data_950000_out.csv
# Merging posinclust-stimulus/positions_620000_out.csv and merged-stimulus/merged_data_620000.csv into final-merged-stimulus-natgrid/final_merged_data_620000_out.csv...
# Merged posinclust-stimulus/positions_620000_out.csv and merged-stimulus/merged_data_620000.csv into final-merged-stimulus-natgrid/final_merged_data_620000_out.csv
# Merging posinclust-stimulus/positions_920000_in.csv and merged-stimulus/merged_data_920000.csv into final-merged-stimulus-natgrid/final_merged_data_920000_in.csv...
# Merged posinclust-stimulus/positions_920000_in.csv and merged-stimulus/merged_data_920000.csv into final-merged-stimulus-natgrid/final_merged_data_920000_in.csv
# Merging posinclust-stimulus/positions_120000_out.csv and merged-stimulus/merged_data_120000.csv into final-merged-stimulus-natgrid/final_merged_data_120000_out.csv...
# Merged posinclust-stimulus/positions_120000_out.csv and merged-stimulus/merged_data_120000.csv into final-merged-stimulus-natgrid/final_merged_data_120000_out.csv
# Merging posinclust-stimulus/positions_990000_out.csv and merged-stimulus/merged_data_990000.csv into final-merged-stimulus-natgrid/final_merged_data_990000_out.csv...
# File merged-stimulus/merged_data_990000.csv not found. Skipping to next file.
# Merging posinclust-stimulus/positions_790000_in.csv and merged-stimulus/merged_data_790000.csv into final-merged-stimulus-natgrid/final_merged_data_790000_in.csv...
# Merged posinclust-stimulus/positions_790000_in.csv and merged-stimulus/merged_data_790000.csv into final-merged-stimulus-natgrid/final_merged_data_790000_in.csv
# Merging posinclust-stimulus/positions_100000_out.csv and merged-stimulus/merged_data_100000.csv into final-merged-stimulus-natgrid/final_merged_data_100000_out.csv...
# Merged posinclust-stimulus/positions_100000_out.csv and merged-stimulus/merged_data_100000.csv into final-merged-stimulus-natgrid/final_merged_data_100000_out.csv
# Merging posinclust-stimulus/positions_440000_out.csv and merged-stimulus/merged_data_440000.csv into final-merged-stimulus-natgrid/final_merged_data_440000_out.csv...
# Merged posinclust-stimulus/positions_440000_out.csv and merged-stimulus/merged_data_440000.csv into final-merged-stimulus-natgrid/final_merged_data_440000_out.csv
# Merging posinclust-stimulus/positions_660000_in.csv and merged-stimulus/merged_data_660000.csv into final-merged-stimulus-natgrid/final_merged_data_660000_in.csv...
# Merged posinclust-stimulus/positions_660000_in.csv and merged-stimulus/merged_data_660000.csv into final-merged-stimulus-natgrid/final_merged_data_660000_in.csv
# Merging posinclust-stimulus/positions_60000_out.csv and merged-stimulus/merged_data_60000.csv into final-merged-stimulus-natgrid/final_merged_data_60000_out.csv...
# Merged posinclust-stimulus/positions_60000_out.csv and merged-stimulus/merged_data_60000.csv into final-merged-stimulus-natgrid/final_merged_data_60000_out.csv
# Merging posinclust-stimulus/positions_190000_out.csv and merged-stimulus/merged_data_190000.csv into final-merged-stimulus-natgrid/final_merged_data_190000_out.csv...
# Merged posinclust-stimulus/positions_190000_out.csv and merged-stimulus/merged_data_190000.csv into final-merged-stimulus-natgrid/final_merged_data_190000_out.csv
# Merging posinclust-stimulus/positions_150000_in.csv and merged-stimulus/merged_data_150000.csv into final-merged-stimulus-natgrid/final_merged_data_150000_in.csv...
# Merged posinclust-stimulus/positions_150000_in.csv and merged-stimulus/merged_data_150000.csv into final-merged-stimulus-natgrid/final_merged_data_150000_in.csv
# Merging posinclust-stimulus/positions_770000_in.csv and merged-stimulus/merged_data_770000.csv into final-merged-stimulus-natgrid/final_merged_data_770000_in.csv...
# Merged posinclust-stimulus/positions_770000_in.csv and merged-stimulus/merged_data_770000.csv into final-merged-stimulus-natgrid/final_merged_data_770000_in.csv
# Merging posinclust-stimulus/positions_380000_out.csv and merged-stimulus/merged_data_380000.csv into final-merged-stimulus-natgrid/final_merged_data_380000_out.csv...
# Merged posinclust-stimulus/positions_380000_out.csv and merged-stimulus/merged_data_380000.csv into final-merged-stimulus-natgrid/final_merged_data_380000_out.csv
# Merging posinclust-stimulus/positions_470000_out.csv and merged-stimulus/merged_data_470000.csv into final-merged-stimulus-natgrid/final_merged_data_470000_out.csv...
# Merged posinclust-stimulus/positions_470000_out.csv and merged-stimulus/merged_data_470000.csv into final-merged-stimulus-natgrid/final_merged_data_470000_out.csv
# Merging posinclust-stimulus/positions_620000_in.csv and merged-stimulus/merged_data_620000.csv into final-merged-stimulus-natgrid/final_merged_data_620000_in.csv...
# Merged posinclust-stimulus/positions_620000_in.csv and merged-stimulus/merged_data_620000.csv into final-merged-stimulus-natgrid/final_merged_data_620000_in.csv
# Merging posinclust-stimulus/positions_350000_in.csv and merged-stimulus/merged_data_350000.csv into final-merged-stimulus-natgrid/final_merged_data_350000_in.csv...
# Merged posinclust-stimulus/positions_350000_in.csv and merged-stimulus/merged_data_350000.csv into final-merged-stimulus-natgrid/final_merged_data_350000_in.csv
# Merging posinclust-stimulus/positions_330000_in.csv and merged-stimulus/merged_data_330000.csv into final-merged-stimulus-natgrid/final_merged_data_330000_in.csv...
# Merged posinclust-stimulus/positions_330000_in.csv and merged-stimulus/merged_data_330000.csv into final-merged-stimulus-natgrid/final_merged_data_330000_in.csv
# Merging posinclust-stimulus/positions_910000_out.csv and merged-stimulus/merged_data_910000.csv into final-merged-stimulus-natgrid/final_merged_data_910000_out.csv...
# Merged posinclust-stimulus/positions_910000_out.csv and merged-stimulus/merged_data_910000.csv into final-merged-stimulus-natgrid/final_merged_data_910000_out.csv
# Merging posinclust-stimulus/positions_550000_out.csv and merged-stimulus/merged_data_550000.csv into final-merged-stimulus-natgrid/final_merged_data_550000_out.csv...
# Merged posinclust-stimulus/positions_550000_out.csv and merged-stimulus/merged_data_550000.csv into final-merged-stimulus-natgrid/final_merged_data_550000_out.csv
# Merging posinclust-stimulus/positions_170000_out.csv and merged-stimulus/merged_data_170000.csv into final-merged-stimulus-natgrid/final_merged_data_170000_out.csv...
# Merged posinclust-stimulus/positions_170000_out.csv and merged-stimulus/merged_data_170000.csv into final-merged-stimulus-natgrid/final_merged_data_170000_out.csv
# Merging posinclust-stimulus/positions_190000_in.csv and merged-stimulus/merged_data_190000.csv into final-merged-stimulus-natgrid/final_merged_data_190000_in.csv...
# Merged posinclust-stimulus/positions_190000_in.csv and merged-stimulus/merged_data_190000.csv into final-merged-stimulus-natgrid/final_merged_data_190000_in.csv
# Merging posinclust-stimulus/positions_30000_out.csv and merged-stimulus/merged_data_30000.csv into final-merged-stimulus-natgrid/final_merged_data_30000_out.csv...
# Merged posinclust-stimulus/positions_30000_out.csv and merged-stimulus/merged_data_30000.csv into final-merged-stimulus-natgrid/final_merged_data_30000_out.csv
# Merging posinclust-stimulus/positions_820000_in.csv and merged-stimulus/merged_data_820000.csv into final-merged-stimulus-natgrid/final_merged_data_820000_in.csv...
# Merged posinclust-stimulus/positions_820000_in.csv and merged-stimulus/merged_data_820000.csv into final-merged-stimulus-natgrid/final_merged_data_820000_in.csv
# Merging posinclust-stimulus/positions_50000_out.csv and merged-stimulus/merged_data_50000.csv into final-merged-stimulus-natgrid/final_merged_data_50000_out.csv...
# Merged posinclust-stimulus/positions_50000_out.csv and merged-stimulus/merged_data_50000.csv into final-merged-stimulus-natgrid/final_merged_data_50000_out.csv
# Merging posinclust-stimulus/positions_130000_out.csv and merged-stimulus/merged_data_130000.csv into final-merged-stimulus-natgrid/final_merged_data_130000_out.csv...
# Merged posinclust-stimulus/positions_130000_out.csv and merged-stimulus/merged_data_130000.csv into final-merged-stimulus-natgrid/final_merged_data_130000_out.csv
# Merging posinclust-stimulus/positions_720000_in.csv and merged-stimulus/merged_data_720000.csv into final-merged-stimulus-natgrid/final_merged_data_720000_in.csv...
# Merged posinclust-stimulus/positions_720000_in.csv and merged-stimulus/merged_data_720000.csv into final-merged-stimulus-natgrid/final_merged_data_720000_in.csv
# Merging posinclust-stimulus/positions_570000_out.csv and merged-stimulus/merged_data_570000.csv into final-merged-stimulus-natgrid/final_merged_data_570000_out.csv...
# Merged posinclust-stimulus/positions_570000_out.csv and merged-stimulus/merged_data_570000.csv into final-merged-stimulus-natgrid/final_merged_data_570000_out.csv
# Merging posinclust-stimulus/positions_700000_out.csv and merged-stimulus/merged_data_700000.csv into final-merged-stimulus-natgrid/final_merged_data_700000_out.csv...
# Merged posinclust-stimulus/positions_700000_out.csv and merged-stimulus/merged_data_700000.csv into final-merged-stimulus-natgrid/final_merged_data_700000_out.csv
# Merging posinclust-stimulus/positions_180000_out.csv and merged-stimulus/merged_data_180000.csv into final-merged-stimulus-natgrid/final_merged_data_180000_out.csv...
# Merged posinclust-stimulus/positions_180000_out.csv and merged-stimulus/merged_data_180000.csv into final-merged-stimulus-natgrid/final_merged_data_180000_out.csv
# Merging posinclust-stimulus/positions_900000_out.csv and merged-stimulus/merged_data_900000.csv into final-merged-stimulus-natgrid/final_merged_data_900000_out.csv...
# Merged posinclust-stimulus/positions_900000_out.csv and merged-stimulus/merged_data_900000.csv into final-merged-stimulus-natgrid/final_merged_data_900000_out.csv
# Merging posinclust-stimulus/positions_20000_in.csv and merged-stimulus/merged_data_20000.csv into final-merged-stimulus-natgrid/final_merged_data_20000_in.csv...
# File merged-stimulus/merged_data_20000.csv not found. Skipping to next file.
# Merging posinclust-stimulus/positions_40000_out.csv and merged-stimulus/merged_data_40000.csv into final-merged-stimulus-natgrid/final_merged_data_40000_out.csv...
# Merged posinclust-stimulus/positions_40000_out.csv and merged-stimulus/merged_data_40000.csv into final-merged-stimulus-natgrid/final_merged_data_40000_out.csv
# Merging posinclust-stimulus/positions_740000_in.csv and merged-stimulus/merged_data_740000.csv into final-merged-stimulus-natgrid/final_merged_data_740000_in.csv...
# Merged posinclust-stimulus/positions_740000_in.csv and merged-stimulus/merged_data_740000.csv into final-merged-stimulus-natgrid/final_merged_data_740000_in.csv
# Merging posinclust-stimulus/positions_520000_out.csv and merged-stimulus/merged_data_520000.csv into final-merged-stimulus-natgrid/final_merged_data_520000_out.csv...
# Merged posinclust-stimulus/positions_520000_out.csv and merged-stimulus/merged_data_520000.csv into final-merged-stimulus-natgrid/final_merged_data_520000_out.csv
# Merging posinclust-stimulus/positions_980000_in.csv and merged-stimulus/merged_data_980000.csv into final-merged-stimulus-natgrid/final_merged_data_980000_in.csv...
# Merged posinclust-stimulus/positions_980000_in.csv and merged-stimulus/merged_data_980000.csv into final-merged-stimulus-natgrid/final_merged_data_980000_in.csv
# Merging posinclust-stimulus/positions_300000_in.csv and merged-stimulus/merged_data_300000.csv into final-merged-stimulus-natgrid/final_merged_data_300000_in.csv...
# Merged posinclust-stimulus/positions_300000_in.csv and merged-stimulus/merged_data_300000.csv into final-merged-stimulus-natgrid/final_merged_data_300000_in.csv
# Merging posinclust-stimulus/positions_170000_in.csv and merged-stimulus/merged_data_170000.csv into final-merged-stimulus-natgrid/final_merged_data_170000_in.csv...
# Merged posinclust-stimulus/positions_170000_in.csv and merged-stimulus/merged_data_170000.csv into final-merged-stimulus-natgrid/final_merged_data_170000_in.csv
# Merging posinclust-stimulus/positions_710000_out.csv and merged-stimulus/merged_data_710000.csv into final-merged-stimulus-natgrid/final_merged_data_710000_out.csv...
# Merged posinclust-stimulus/positions_710000_out.csv and merged-stimulus/merged_data_710000.csv into final-merged-stimulus-natgrid/final_merged_data_710000_out.csv
# Merging posinclust-stimulus/positions_420000_in.csv and merged-stimulus/merged_data_420000.csv into final-merged-stimulus-natgrid/final_merged_data_420000_in.csv...
# Merged posinclust-stimulus/positions_420000_in.csv and merged-stimulus/merged_data_420000.csv into final-merged-stimulus-natgrid/final_merged_data_420000_in.csv
# Merging posinclust-stimulus/positions_970000_out.csv and merged-stimulus/merged_data_970000.csv into final-merged-stimulus-natgrid/final_merged_data_970000_out.csv...
# Merged posinclust-stimulus/positions_970000_out.csv and merged-stimulus/merged_data_970000.csv into final-merged-stimulus-natgrid/final_merged_data_970000_out.csv
# Merging posinclust-stimulus/positions_500000_out.csv and merged-stimulus/merged_data_500000.csv into final-merged-stimulus-natgrid/final_merged_data_500000_out.csv...
# Merged posinclust-stimulus/positions_500000_out.csv and merged-stimulus/merged_data_500000.csv into final-merged-stimulus-natgrid/final_merged_data_500000_out.csv
# Merging posinclust-stimulus/positions_630000_in.csv and merged-stimulus/merged_data_630000.csv into final-merged-stimulus-natgrid/final_merged_data_630000_in.csv...
# Merged posinclust-stimulus/positions_630000_in.csv and merged-stimulus/merged_data_630000.csv into final-merged-stimulus-natgrid/final_merged_data_630000_in.csv
# Merging posinclust-stimulus/positions_740000_out.csv and merged-stimulus/merged_data_740000.csv into final-merged-stimulus-natgrid/final_merged_data_740000_out.csv...
# Merged posinclust-stimulus/positions_740000_out.csv and merged-stimulus/merged_data_740000.csv into final-merged-stimulus-natgrid/final_merged_data_740000_out.csv
# Merging posinclust-stimulus/positions_840000_in.csv and merged-stimulus/merged_data_840000.csv into final-merged-stimulus-natgrid/final_merged_data_840000_in.csv...
# Merged posinclust-stimulus/positions_840000_in.csv and merged-stimulus/merged_data_840000.csv into final-merged-stimulus-natgrid/final_merged_data_840000_in.csv
# Merging posinclust-stimulus/positions_720000_out.csv and merged-stimulus/merged_data_720000.csv into final-merged-stimulus-natgrid/final_merged_data_720000_out.csv...
# Merged posinclust-stimulus/positions_720000_out.csv and merged-stimulus/merged_data_720000.csv into final-merged-stimulus-natgrid/final_merged_data_720000_out.csv
# Merging posinclust-stimulus/positions_730000_in.csv and merged-stimulus/merged_data_730000.csv into final-merged-stimulus-natgrid/final_merged_data_730000_in.csv...
# Merged posinclust-stimulus/positions_730000_in.csv and merged-stimulus/merged_data_730000.csv into final-merged-stimulus-natgrid/final_merged_data_730000_in.csv
# Merging posinclust-stimulus/positions_540000_out.csv and merged-stimulus/merged_data_540000.csv into final-merged-stimulus-natgrid/final_merged_data_540000_out.csv...
# Merged posinclust-stimulus/positions_540000_out.csv and merged-stimulus/merged_data_540000.csv into final-merged-stimulus-natgrid/final_merged_data_540000_out.csv
# Merging posinclust-stimulus/positions_880000_out.csv and merged-stimulus/merged_data_880000.csv into final-merged-stimulus-natgrid/final_merged_data_880000_out.csv...
# Merged posinclust-stimulus/positions_880000_out.csv and merged-stimulus/merged_data_880000.csv into final-merged-stimulus-natgrid/final_merged_data_880000_out.csv
# Merging posinclust-stimulus/positions_640000_out.csv and merged-stimulus/merged_data_640000.csv into final-merged-stimulus-natgrid/final_merged_data_640000_out.csv...
# Merged posinclust-stimulus/positions_640000_out.csv and merged-stimulus/merged_data_640000.csv into final-merged-stimulus-natgrid/final_merged_data_640000_out.csv
# Merging posinclust-stimulus/positions_550000_in.csv and merged-stimulus/merged_data_550000.csv into final-merged-stimulus-natgrid/final_merged_data_550000_in.csv...
# Merged posinclust-stimulus/positions_550000_in.csv and merged-stimulus/merged_data_550000.csv into final-merged-stimulus-natgrid/final_merged_data_550000_in.csv
# Merging posinclust-stimulus/positions_220000_in.csv and merged-stimulus/merged_data_220000.csv into final-merged-stimulus-natgrid/final_merged_data_220000_in.csv...
# Merged posinclust-stimulus/positions_220000_in.csv and merged-stimulus/merged_data_220000.csv into final-merged-stimulus-natgrid/final_merged_data_220000_in.csv
# Merging posinclust-stimulus/positions_340000_in.csv and merged-stimulus/merged_data_340000.csv into final-merged-stimulus-natgrid/final_merged_data_340000_in.csv...
# Merged posinclust-stimulus/positions_340000_in.csv and merged-stimulus/merged_data_340000.csv into final-merged-stimulus-natgrid/final_merged_data_340000_in.csv
# Merging posinclust-stimulus/positions_460000_out.csv and merged-stimulus/merged_data_460000.csv into final-merged-stimulus-natgrid/final_merged_data_460000_out.csv...
# Merged posinclust-stimulus/positions_460000_out.csv and merged-stimulus/merged_data_460000.csv into final-merged-stimulus-natgrid/final_merged_data_460000_out.csv
# Merging posinclust-stimulus/positions_560000_in.csv and merged-stimulus/merged_data_560000.csv into final-merged-stimulus-natgrid/final_merged_data_560000_in.csv...
# Merged posinclust-stimulus/positions_560000_in.csv and merged-stimulus/merged_data_560000.csv into final-merged-stimulus-natgrid/final_merged_data_560000_in.csv
# Merging posinclust-stimulus/positions_810000_in.csv and merged-stimulus/merged_data_810000.csv into final-merged-stimulus-natgrid/final_merged_data_810000_in.csv...
# Merged posinclust-stimulus/positions_810000_in.csv and merged-stimulus/merged_data_810000.csv into final-merged-stimulus-natgrid/final_merged_data_810000_in.csv
# Merging posinclust-stimulus/positions_410000_in.csv and merged-stimulus/merged_data_410000.csv into final-merged-stimulus-natgrid/final_merged_data_410000_in.csv...
# Merged posinclust-stimulus/positions_410000_in.csv and merged-stimulus/merged_data_410000.csv into final-merged-stimulus-natgrid/final_merged_data_410000_in.csv
# Merging posinclust-stimulus/positions_960000_in.csv and merged-stimulus/merged_data_960000.csv into final-merged-stimulus-natgrid/final_merged_data_960000_in.csv...
# Merged posinclust-stimulus/positions_960000_in.csv and merged-stimulus/merged_data_960000.csv into final-merged-stimulus-natgrid/final_merged_data_960000_in.csv
# Merging posinclust-stimulus/positions_670000_out.csv and merged-stimulus/merged_data_670000.csv into final-merged-stimulus-natgrid/final_merged_data_670000_out.csv...
# Merged posinclust-stimulus/positions_670000_out.csv and merged-stimulus/merged_data_670000.csv into final-merged-stimulus-natgrid/final_merged_data_670000_out.csv
# Merging posinclust-stimulus/positions_160000_in.csv and merged-stimulus/merged_data_160000.csv into final-merged-stimulus-natgrid/final_merged_data_160000_in.csv...
# Merged posinclust-stimulus/positions_160000_in.csv and merged-stimulus/merged_data_160000.csv into final-merged-stimulus-natgrid/final_merged_data_160000_in.csv
# Merging posinclust-stimulus/positions_430000_out.csv and merged-stimulus/merged_data_430000.csv into final-merged-stimulus-natgrid/final_merged_data_430000_out.csv...
# Merged posinclust-stimulus/positions_430000_out.csv and merged-stimulus/merged_data_430000.csv into final-merged-stimulus-natgrid/final_merged_data_430000_out.csv
# Merging posinclust-stimulus/positions_540000_in.csv and merged-stimulus/merged_data_540000.csv into final-merged-stimulus-natgrid/final_merged_data_540000_in.csv...
# Merged posinclust-stimulus/positions_540000_in.csv and merged-stimulus/merged_data_540000.csv into final-merged-stimulus-natgrid/final_merged_data_540000_in.csv
# Merging posinclust-stimulus/positions_880000_in.csv and merged-stimulus/merged_data_880000.csv into final-merged-stimulus-natgrid/final_merged_data_880000_in.csv...
# Merged posinclust-stimulus/positions_880000_in.csv and merged-stimulus/merged_data_880000.csv into final-merged-stimulus-natgrid/final_merged_data_880000_in.csv
# Merging posinclust-stimulus/positions_320000_out.csv and merged-stimulus/merged_data_320000.csv into final-merged-stimulus-natgrid/final_merged_data_320000_out.csv...
# Merged posinclust-stimulus/positions_320000_out.csv and merged-stimulus/merged_data_320000.csv into final-merged-stimulus-natgrid/final_merged_data_320000_out.csv
# Merging posinclust-stimulus/positions_340000_out.csv and merged-stimulus/merged_data_340000.csv into final-merged-stimulus-natgrid/final_merged_data_340000_out.csv...
# Merged posinclust-stimulus/positions_340000_out.csv and merged-stimulus/merged_data_340000.csv into final-merged-stimulus-natgrid/final_merged_data_340000_out.csv
# Merging posinclust-stimulus/positions_860000_out.csv and merged-stimulus/merged_data_860000.csv into final-merged-stimulus-natgrid/final_merged_data_860000_out.csv...
# Merged posinclust-stimulus/positions_860000_out.csv and merged-stimulus/merged_data_860000.csv into final-merged-stimulus-natgrid/final_merged_data_860000_out.csv
# Merging posinclust-stimulus/positions_350000_out.csv and merged-stimulus/merged_data_350000.csv into final-merged-stimulus-natgrid/final_merged_data_350000_out.csv...
# Merged posinclust-stimulus/positions_350000_out.csv and merged-stimulus/merged_data_350000.csv into final-merged-stimulus-natgrid/final_merged_data_350000_out.csv
# Merging posinclust-stimulus/positions_420000_out.csv and merged-stimulus/merged_data_420000.csv into final-merged-stimulus-natgrid/final_merged_data_420000_out.csv...
# Merged posinclust-stimulus/positions_420000_out.csv and merged-stimulus/merged_data_420000.csv into final-merged-stimulus-natgrid/final_merged_data_420000_out.csv
# Merging posinclust-stimulus/positions_450000_in.csv and merged-stimulus/merged_data_450000.csv into final-merged-stimulus-natgrid/final_merged_data_450000_in.csv...
# Merged posinclust-stimulus/positions_450000_in.csv and merged-stimulus/merged_data_450000.csv into final-merged-stimulus-natgrid/final_merged_data_450000_in.csv
# Merging posinclust-stimulus/positions_510000_out.csv and merged-stimulus/merged_data_510000.csv into final-merged-stimulus-natgrid/final_merged_data_510000_out.csv...
# Merged posinclust-stimulus/positions_510000_out.csv and merged-stimulus/merged_data_510000.csv into final-merged-stimulus-natgrid/final_merged_data_510000_out.csv
# Merging posinclust-stimulus/positions_320000_in.csv and merged-stimulus/merged_data_320000.csv into final-merged-stimulus-natgrid/final_merged_data_320000_in.csv...
# Merged posinclust-stimulus/positions_320000_in.csv and merged-stimulus/merged_data_320000.csv into final-merged-stimulus-natgrid/final_merged_data_320000_in.csv
# Merging posinclust-stimulus/positions_370000_in.csv and merged-stimulus/merged_data_370000.csv into final-merged-stimulus-natgrid/final_merged_data_370000_in.csv...
# Merged posinclust-stimulus/positions_370000_in.csv and merged-stimulus/merged_data_370000.csv into final-merged-stimulus-natgrid/final_merged_data_370000_in.csv
# Merging posinclust-stimulus/positions_240000_out.csv and merged-stimulus/merged_data_240000.csv into final-merged-stimulus-natgrid/final_merged_data_240000_out.csv...
# Merged posinclust-stimulus/positions_240000_out.csv and merged-stimulus/merged_data_240000.csv into final-merged-stimulus-natgrid/final_merged_data_240000_out.csv
# Merging posinclust-stimulus/positions_40000_in.csv and merged-stimulus/merged_data_40000.csv into final-merged-stimulus-natgrid/final_merged_data_40000_in.csv...
# Merged posinclust-stimulus/positions_40000_in.csv and merged-stimulus/merged_data_40000.csv into final-merged-stimulus-natgrid/final_merged_data_40000_in.csv
# Merging posinclust-stimulus/positions_140000_out.csv and merged-stimulus/merged_data_140000.csv into final-merged-stimulus-natgrid/final_merged_data_140000_out.csv...
# Merged posinclust-stimulus/positions_140000_out.csv and merged-stimulus/merged_data_140000.csv into final-merged-stimulus-natgrid/final_merged_data_140000_out.csv
# Merging posinclust-stimulus/positions_400000_in.csv and merged-stimulus/merged_data_400000.csv into final-merged-stimulus-natgrid/final_merged_data_400000_in.csv...
# Merged posinclust-stimulus/positions_400000_in.csv and merged-stimulus/merged_data_400000.csv into final-merged-stimulus-natgrid/final_merged_data_400000_in.csv
# Merging posinclust-stimulus/positions_970000_in.csv and merged-stimulus/merged_data_970000.csv into final-merged-stimulus-natgrid/final_merged_data_970000_in.csv...
# Merged posinclust-stimulus/positions_970000_in.csv and merged-stimulus/merged_data_970000.csv into final-merged-stimulus-natgrid/final_merged_data_970000_in.csv
# Merging posinclust-stimulus/positions_390000_out.csv and merged-stimulus/merged_data_390000.csv into final-merged-stimulus-natgrid/final_merged_data_390000_out.csv...
# Merged posinclust-stimulus/positions_390000_out.csv and merged-stimulus/merged_data_390000.csv into final-merged-stimulus-natgrid/final_merged_data_390000_out.csv
# Merging posinclust-stimulus/positions_590000_in.csv and merged-stimulus/merged_data_590000.csv into final-merged-stimulus-natgrid/final_merged_data_590000_in.csv...
# Merged posinclust-stimulus/positions_590000_in.csv and merged-stimulus/merged_data_590000.csv into final-merged-stimulus-natgrid/final_merged_data_590000_in.csv
# Merging posinclust-stimulus/positions_70000_in.csv and merged-stimulus/merged_data_70000.csv into final-merged-stimulus-natgrid/final_merged_data_70000_in.csv...
# Merged posinclust-stimulus/positions_70000_in.csv and merged-stimulus/merged_data_70000.csv into final-merged-stimulus-natgrid/final_merged_data_70000_in.csv
# Merging posinclust-stimulus/positions_680000_in.csv and merged-stimulus/merged_data_680000.csv into final-merged-stimulus-natgrid/final_merged_data_680000_in.csv...
# Merged posinclust-stimulus/positions_680000_in.csv and merged-stimulus/merged_data_680000.csv into final-merged-stimulus-natgrid/final_merged_data_680000_in.csv
# Merging posinclust-stimulus/positions_110000_out.csv and merged-stimulus/merged_data_110000.csv into final-merged-stimulus-natgrid/final_merged_data_110000_out.csv...
# Merged posinclust-stimulus/positions_110000_out.csv and merged-stimulus/merged_data_110000.csv into final-merged-stimulus-natgrid/final_merged_data_110000_out.csv
# Merging posinclust-stimulus/positions_300000_out.csv and merged-stimulus/merged_data_300000.csv into final-merged-stimulus-natgrid/final_merged_data_300000_out.csv...
# Merged posinclust-stimulus/positions_300000_out.csv and merged-stimulus/merged_data_300000.csv into final-merged-stimulus-natgrid/final_merged_data_300000_out.csv
# Merging posinclust-stimulus/positions_200000_out.csv and merged-stimulus/merged_data_200000.csv into final-merged-stimulus-natgrid/final_merged_data_200000_out.csv...
# Merged posinclust-stimulus/positions_200000_out.csv and merged-stimulus/merged_data_200000.csv into final-merged-stimulus-natgrid/final_merged_data_200000_out.csv
# Merging posinclust-stimulus/positions_700000_in.csv and merged-stimulus/merged_data_700000.csv into final-merged-stimulus-natgrid/final_merged_data_700000_in.csv...
# Merged posinclust-stimulus/positions_700000_in.csv and merged-stimulus/merged_data_700000.csv into final-merged-stimulus-natgrid/final_merged_data_700000_in.csv
# Merging posinclust-stimulus/positions_90000_out.csv and merged-stimulus/merged_data_90000.csv into final-merged-stimulus-natgrid/final_merged_data_90000_out.csv...
# Merged posinclust-stimulus/positions_90000_out.csv and merged-stimulus/merged_data_90000.csv into final-merged-stimulus-natgrid/final_merged_data_90000_out.csv
# Merging posinclust-stimulus/positions_1000000_in.csv and merged-stimulus/merged_data_1000000.csv into final-merged-stimulus-natgrid/final_merged_data_1000000_in.csv...
# File merged-stimulus/merged_data_1000000.csv not found. Skipping to next file.
# Merging posinclust-stimulus/positions_110000_in.csv and merged-stimulus/merged_data_110000.csv into final-merged-stimulus-natgrid/final_merged_data_110000_in.csv...
# Merged posinclust-stimulus/positions_110000_in.csv and merged-stimulus/merged_data_110000.csv into final-merged-stimulus-natgrid/final_merged_data_110000_in.csv
# Merging posinclust-stimulus/positions_760000_out.csv and merged-stimulus/merged_data_760000.csv into final-merged-stimulus-natgrid/final_merged_data_760000_out.csv...
# Merged posinclust-stimulus/positions_760000_out.csv and merged-stimulus/merged_data_760000.csv into final-merged-stimulus-natgrid/final_merged_data_760000_out.csv
# Merging posinclust-stimulus/positions_470000_in.csv and merged-stimulus/merged_data_470000.csv into final-merged-stimulus-natgrid/final_merged_data_470000_in.csv...
# Merged posinclust-stimulus/positions_470000_in.csv and merged-stimulus/merged_data_470000.csv into final-merged-stimulus-natgrid/final_merged_data_470000_in.csv
# Merging posinclust-stimulus/positions_610000_out.csv and merged-stimulus/merged_data_610000.csv into final-merged-stimulus-natgrid/final_merged_data_610000_out.csv...
# Merged posinclust-stimulus/positions_610000_out.csv and merged-stimulus/merged_data_610000.csv into final-merged-stimulus-natgrid/final_merged_data_610000_out.csv
# Merging posinclust-stimulus/positions_870000_in.csv and merged-stimulus/merged_data_870000.csv into final-merged-stimulus-natgrid/final_merged_data_870000_in.csv...
# Merged posinclust-stimulus/positions_870000_in.csv and merged-stimulus/merged_data_870000.csv into final-merged-stimulus-natgrid/final_merged_data_870000_in.csv
# Merging posinclust-stimulus/positions_160000_out.csv and merged-stimulus/merged_data_160000.csv into final-merged-stimulus-natgrid/final_merged_data_160000_out.csv...
# Merged posinclust-stimulus/positions_160000_out.csv and merged-stimulus/merged_data_160000.csv into final-merged-stimulus-natgrid/final_merged_data_160000_out.csv
# Merging posinclust-stimulus/positions_480000_in.csv and merged-stimulus/merged_data_480000.csv into final-merged-stimulus-natgrid/final_merged_data_480000_in.csv...
# Merged posinclust-stimulus/positions_480000_in.csv and merged-stimulus/merged_data_480000.csv into final-merged-stimulus-natgrid/final_merged_data_480000_in.csv
# Merging posinclust-stimulus/positions_240000_in.csv and merged-stimulus/merged_data_240000.csv into final-merged-stimulus-natgrid/final_merged_data_240000_in.csv...
# Merged posinclust-stimulus/positions_240000_in.csv and merged-stimulus/merged_data_240000.csv into final-merged-stimulus-natgrid/final_merged_data_240000_in.csv
# Merging posinclust-stimulus/positions_280000_in.csv and merged-stimulus/merged_data_280000.csv into final-merged-stimulus-natgrid/final_merged_data_280000_in.csv...
# Merged posinclust-stimulus/positions_280000_in.csv and merged-stimulus/merged_data_280000.csv into final-merged-stimulus-natgrid/final_merged_data_280000_in.csv
# Merging posinclust-stimulus/positions_510000_in.csv and merged-stimulus/merged_data_510000.csv into final-merged-stimulus-natgrid/final_merged_data_510000_in.csv...
# Merged posinclust-stimulus/positions_510000_in.csv and merged-stimulus/merged_data_510000.csv into final-merged-stimulus-natgrid/final_merged_data_510000_in.csv
# Merging posinclust-stimulus/positions_100000_in.csv and merged-stimulus/merged_data_100000.csv into final-merged-stimulus-natgrid/final_merged_data_100000_in.csv...
# Merged posinclust-stimulus/positions_100000_in.csv and merged-stimulus/merged_data_100000.csv into final-merged-stimulus-natgrid/final_merged_data_100000_in.csv
# Merging posinclust-stimulus/positions_430000_in.csv and merged-stimulus/merged_data_430000.csv into final-merged-stimulus-natgrid/final_merged_data_430000_in.csv...
# Merged posinclust-stimulus/positions_430000_in.csv and merged-stimulus/merged_data_430000.csv into final-merged-stimulus-natgrid/final_merged_data_430000_in.csv
# Merging posinclust-stimulus/positions_860000_in.csv and merged-stimulus/merged_data_860000.csv into final-merged-stimulus-natgrid/final_merged_data_860000_in.csv...
# Merged posinclust-stimulus/positions_860000_in.csv and merged-stimulus/merged_data_860000.csv into final-merged-stimulus-natgrid/final_merged_data_860000_in.csv
# Merging posinclust-stimulus/positions_770000_out.csv and merged-stimulus/merged_data_770000.csv into final-merged-stimulus-natgrid/final_merged_data_770000_out.csv...
# Merged posinclust-stimulus/positions_770000_out.csv and merged-stimulus/merged_data_770000.csv into final-merged-stimulus-natgrid/final_merged_data_770000_out.csv
# Merging posinclust-stimulus/positions_990000_in.csv and merged-stimulus/merged_data_990000.csv into final-merged-stimulus-natgrid/final_merged_data_990000_in.csv...
# File merged-stimulus/merged_data_990000.csv not found. Skipping to next file.
# Merging posinclust-stimulus/positions_380000_in.csv and merged-stimulus/merged_data_380000.csv into final-merged-stimulus-natgrid/final_merged_data_380000_in.csv...
# Merged posinclust-stimulus/positions_380000_in.csv and merged-stimulus/merged_data_380000.csv into final-merged-stimulus-natgrid/final_merged_data_380000_in.csv
# Merging posinclust-stimulus/positions_890000_out.csv and merged-stimulus/merged_data_890000.csv into final-merged-stimulus-natgrid/final_merged_data_890000_out.csv...
# Merged posinclust-stimulus/positions_890000_out.csv and merged-stimulus/merged_data_890000.csv into final-merged-stimulus-natgrid/final_merged_data_890000_out.csv
# Merging posinclust-stimulus/positions_690000_out.csv and merged-stimulus/merged_data_690000.csv into final-merged-stimulus-natgrid/final_merged_data_690000_out.csv...
# Merged posinclust-stimulus/positions_690000_out.csv and merged-stimulus/merged_data_690000.csv into final-merged-stimulus-natgrid/final_merged_data_690000_out.csv
# Merging posinclust-stimulus/positions_520000_in.csv and merged-stimulus/merged_data_520000.csv into final-merged-stimulus-natgrid/final_merged_data_520000_in.csv...
# Merged posinclust-stimulus/positions_520000_in.csv and merged-stimulus/merged_data_520000.csv into final-merged-stimulus-natgrid/final_merged_data_520000_in.csv
# Merging posinclust-stimulus/positions_890000_in.csv and merged-stimulus/merged_data_890000.csv into final-merged-stimulus-natgrid/final_merged_data_890000_in.csv...
# Merged posinclust-stimulus/positions_890000_in.csv and merged-stimulus/merged_data_890000.csv into final-merged-stimulus-natgrid/final_merged_data_890000_in.csv
# Merging posinclust-stimulus/positions_410000_out.csv and merged-stimulus/merged_data_410000.csv into final-merged-stimulus-natgrid/final_merged_data_410000_out.csv...
# Merged posinclust-stimulus/positions_410000_out.csv and merged-stimulus/merged_data_410000.csv into final-merged-stimulus-natgrid/final_merged_data_410000_out.csv
# Merging posinclust-stimulus/positions_250000_out.csv and merged-stimulus/merged_data_250000.csv into final-merged-stimulus-natgrid/final_merged_data_250000_out.csv...
# Merged posinclust-stimulus/positions_250000_out.csv and merged-stimulus/merged_data_250000.csv into final-merged-stimulus-natgrid/final_merged_data_250000_out.csv
# Merging posinclust-stimulus/positions_650000_out.csv and merged-stimulus/merged_data_650000.csv into final-merged-stimulus-natgrid/final_merged_data_650000_out.csv...
# Merged posinclust-stimulus/positions_650000_out.csv and merged-stimulus/merged_data_650000.csv into final-merged-stimulus-natgrid/final_merged_data_650000_out.csv
# Merging posinclust-stimulus/positions_50000_in.csv and merged-stimulus/merged_data_50000.csv into final-merged-stimulus-natgrid/final_merged_data_50000_in.csv...
# Merged posinclust-stimulus/positions_50000_in.csv and merged-stimulus/merged_data_50000.csv into final-merged-stimulus-natgrid/final_merged_data_50000_in.csv
# Merging posinclust-stimulus/positions_690000_in.csv and merged-stimulus/merged_data_690000.csv into final-merged-stimulus-natgrid/final_merged_data_690000_in.csv...
# Merged posinclust-stimulus/positions_690000_in.csv and merged-stimulus/merged_data_690000.csv into final-merged-stimulus-natgrid/final_merged_data_690000_in.csv
# Merging posinclust-stimulus/positions_670000_in.csv and merged-stimulus/merged_data_670000.csv into final-merged-stimulus-natgrid/final_merged_data_670000_in.csv...
# Merged posinclust-stimulus/positions_670000_in.csv and merged-stimulus/merged_data_670000.csv into final-merged-stimulus-natgrid/final_merged_data_670000_in.csv
# Merging posinclust-stimulus/positions_70000_out.csv and merged-stimulus/merged_data_70000.csv into final-merged-stimulus-natgrid/final_merged_data_70000_out.csv...
# Merged posinclust-stimulus/positions_70000_out.csv and merged-stimulus/merged_data_70000.csv into final-merged-stimulus-natgrid/final_merged_data_70000_out.csv
# Merging posinclust-stimulus/positions_950000_in.csv and merged-stimulus/merged_data_950000.csv into final-merged-stimulus-natgrid/final_merged_data_950000_in.csv...
# Merged posinclust-stimulus/positions_950000_in.csv and merged-stimulus/merged_data_950000.csv into final-merged-stimulus-natgrid/final_merged_data_950000_in.csv
# Merging posinclust-stimulus/positions_750000_out.csv and merged-stimulus/merged_data_750000.csv into final-merged-stimulus-natgrid/final_merged_data_750000_out.csv...
# Merged posinclust-stimulus/positions_750000_out.csv and merged-stimulus/merged_data_750000.csv into final-merged-stimulus-natgrid/final_merged_data_750000_out.csv
# Merging posinclust-stimulus/positions_570000_in.csv and merged-stimulus/merged_data_570000.csv into final-merged-stimulus-natgrid/final_merged_data_570000_in.csv...
# Merged posinclust-stimulus/positions_570000_in.csv and merged-stimulus/merged_data_570000.csv into final-merged-stimulus-natgrid/final_merged_data_570000_in.csv
# Merging posinclust-stimulus/positions_590000_out.csv and merged-stimulus/merged_data_590000.csv into final-merged-stimulus-natgrid/final_merged_data_590000_out.csv...
# Merged posinclust-stimulus/positions_590000_out.csv and merged-stimulus/merged_data_590000.csv into final-merged-stimulus-natgrid/final_merged_data_590000_out.csv
# Merging posinclust-stimulus/positions_80000_in.csv and merged-stimulus/merged_data_80000.csv into final-merged-stimulus-natgrid/final_merged_data_80000_in.csv...
# ...
# Merging posinclust-stimulus/positions_450000_out.csv and merged-stimulus/merged_data_450000.csv into final-merged-stimulus-natgrid/final_merged_data_450000_out.csv...
# Merged posinclust-stimulus/positions_450000_out.csv and merged-stimulus/merged_data_450000.csv into final-merged-stimulus-natgrid/final_merged_data_450000_out.csv
# Merging posinclust-stimulus/positions_730000_out.csv and merged-stimulus/merged_data_730000.csv into final-merged-stimulus-natgrid/final_merged_data_730000_out.csv...
# Merged posinclust-stimulus/positions_730000_out.csv and merged-stimulus/merged_data_730000.csv into final-merged-stimulus-natgrid/final_merged_data_730000_out.csv
# Merging posinclust-stimulus/positions_490000_in.csv and merged-stimulus/merged_data_490000.csv into final-merged-stimulus-natgrid/final_merged_data_490000_in.csv...
# Merged posinclust-stimulus/positions_490000_in.csv and merged-stimulus/merged_data_490000.csv into final-merged-stimulus-natgrid/final_merged_data_490000_in.csv
# Merging posinclust-stimulus/positions_460000_in.csv and merged-stimulus/merged_data_460000.csv into final-merged-stimulus-natgrid/final_merged_data_460000_in.csv...
# Merged posinclust-stimulus/positions_460000_in.csv and merged-stimulus/merged_data_460000.csv into final-merged-stimulus-natgrid/final_merged_data_460000_in.csv
# Merging posinclust-stimulus/positions_680000_out.csv and merged-stimulus/merged_data_680000.csv into final-merged-stimulus-natgrid/final_merged_data_680000_out.csv...
# Merged posinclust-stimulus/positions_680000_out.csv and merged-stimulus/merged_data_680000.csv into final-merged-stimulus-natgrid/final_merged_data_680000_out.csv
# Merging posinclust-stimulus/positions_360000_in.csv and merged-stimulus/merged_data_360000.csv into final-merged-stimulus-natgrid/final_merged_data_360000_in.csv...
# Merged posinclust-stimulus/positions_360000_in.csv and merged-stimulus/merged_data_360000.csv into final-merged-stimulus-natgrid/final_merged_data_360000_in.csv
# Merging posinclust-stimulus/positions_940000_out.csv and merged-stimulus/merged_data_940000.csv into final-merged-stimulus-natgrid/final_merged_data_940000_out.csv...
# Merged posinclust-stimulus/positions_940000_out.csv and merged-stimulus/merged_data_940000.csv into final-merged-stimulus-natgrid/final_merged_data_940000_out.csv
# Merging posinclust-stimulus/positions_270000_in.csv and merged-stimulus/merged_data_270000.csv into final-merged-stimulus-natgrid/final_merged_data_270000_in.csv...
# Merged posinclust-stimulus/positions_270000_in.csv and merged-stimulus/merged_data_270000.csv into final-merged-stimulus-natgrid/final_merged_data_270000_in.csv
# Merging posinclust-stimulus/positions_610000_in.csv and merged-stimulus/merged_data_610000.csv into final-merged-stimulus-natgrid/final_merged_data_610000_in.csv...
# Merged posinclust-stimulus/positions_610000_in.csv and merged-stimulus/merged_data_610000.csv into final-merged-stimulus-natgrid/final_merged_data_610000_in.csv
# Merging posinclust-stimulus/positions_290000_out.csv and merged-stimulus/merged_data_290000.csv into final-merged-stimulus-natgrid/final_merged_data_290000_out.csv...
# Merged posinclust-stimulus/positions_290000_out.csv and merged-stimulus/merged_data_290000.csv into final-merged-stimulus-natgrid/final_merged_data_290000_out.csv
# Merging posinclust-stimulus/positions_260000_out.csv and merged-stimulus/merged_data_260000.csv into final-merged-stimulus-natgrid/final_merged_data_260000_out.csv...
# Merged posinclust-stimulus/positions_260000_out.csv and merged-stimulus/merged_data_260000.csv into final-merged-stimulus-natgrid/final_merged_data_260000_out.csv
# Merging posinclust-stimulus/positions_870000_out.csv and merged-stimulus/merged_data_870000.csv into final-merged-stimulus-natgrid/final_merged_data_870000_out.csv...
# Merged posinclust-stimulus/positions_870000_out.csv and merged-stimulus/merged_data_870000.csv into final-merged-stimulus-natgrid/final_merged_data_870000_out.csv
# Merging posinclust-stimulus/positions_480000_out.csv and merged-stimulus/merged_data_480000.csv into final-merged-stimulus-natgrid/final_merged_data_480000_out.csv...
# Merged posinclust-stimulus/positions_480000_out.csv and merged-stimulus/merged_data_480000.csv into final-merged-stimulus-natgrid/final_merged_data_480000_out.csv
# Merging posinclust-stimulus/positions_580000_in.csv and merged-stimulus/merged_data_580000.csv into final-merged-stimulus-natgrid/final_merged_data_580000_in.csv...
# Merged posinclust-stimulus/positions_580000_in.csv and merged-stimulus/merged_data_580000.csv into final-merged-stimulus-natgrid/final_merged_data_580000_in.csv
# Merging posinclust-stimulus/positions_220000_out.csv and merged-stimulus/merged_data_220000.csv into final-merged-stimulus-natgrid/final_merged_data_220000_out.csv...
# Merged posinclust-stimulus/positions_220000_out.csv and merged-stimulus/merged_data_220000.csv into final-merged-stimulus-natgrid/final_merged_data_220000_out.csv
# Merging posinclust-stimulus/positions_1000000_out.csv and merged-stimulus/merged_data_1000000.csv into final-merged-stimulus-natgrid/final_merged_data_1000000_out.csv...
# File merged-stimulus/merged_data_1000000.csv not found. Skipping to next file.
# Merging posinclust-stimulus/positions_120000_in.csv and merged-stimulus/merged_data_120000.csv into final-merged-stimulus-natgrid/final_merged_data_120000_in.csv...
# Merged posinclust-stimulus/positions_120000_in.csv and merged-stimulus/merged_data_120000.csv into final-merged-stimulus-natgrid/final_merged_data_120000_in.csv
# Merging posinclust-stimulus/positions_10000_out.csv and merged-stimulus/merged_data_10000.csv into final-merged-stimulus-natgrid/final_merged_data_10000_out.csv...
# File merged-stimulus/merged_data_10000.csv not found. Skipping to next file.
# Merging posinclust-stimulus/positions_310000_in.csv and merged-stimulus/merged_data_310000.csv into final-merged-stimulus-natgrid/final_merged_data_310000_in.csv...
# Merged posinclust-stimulus/positions_310000_in.csv and merged-stimulus/merged_data_310000.csv into final-merged-stimulus-natgrid/final_merged_data_310000_in.csv
# Merging posinclust-stimulus/positions_830000_out.csv and merged-stimulus/merged_data_830000.csv into final-merged-stimulus-natgrid/final_merged_data_830000_out.csv...
# Merged posinclust-stimulus/positions_830000_out.csv and merged-stimulus/merged_data_830000.csv into final-merged-stimulus-natgrid/final_merged_data_830000_out.csv
# Merging posinclust-stimulus/positions_90000_in.csv and merged-stimulus/merged_data_90000.csv into final-merged-stimulus-natgrid/final_merged_data_90000_in.csv...
# Merged posinclust-stimulus/positions_90000_in.csv and merged-stimulus/merged_data_90000.csv into final-merged-stimulus-natgrid/final_merged_data_90000_in.csv
# Merging posinclust-stimulus/positions_710000_in.csv and merged-stimulus/merged_data_710000.csv into final-merged-stimulus-natgrid/final_merged_data_710000_in.csv...
# Merged posinclust-stimulus/positions_710000_in.csv and merged-stimulus/merged_data_710000.csv into final-merged-stimulus-natgrid/final_merged_data_710000_in.csv
# Merging posinclust-stimulus/positions_390000_in.csv and merged-stimulus/merged_data_390000.csv into final-merged-stimulus-natgrid/final_merged_data_390000_in.csv...
# Merged posinclust-stimulus/positions_390000_in.csv and merged-stimulus/merged_data_390000.csv into final-merged-stimulus-natgrid/final_merged_data_390000_in.csv
# Merging posinclust-stimulus/positions_850000_in.csv and merged-stimulus/merged_data_850000.csv into final-merged-stimulus-natgrid/final_merged_data_850000_in.csv...
# Merged posinclust-stimulus/positions_850000_in.csv and merged-stimulus/merged_data_850000.csv into final-merged-stimulus-natgrid/final_merged_data_850000_in.csv
# Merging posinclust-stimulus/positions_900000_in.csv and merged-stimulus/merged_data_900000.csv into final-merged-stimulus-natgrid/final_merged_data_900000_in.csv...
# Merged posinclust-stimulus/positions_900000_in.csv and merged-stimulus/merged_data_900000.csv into final-merged-stimulus-natgrid/final_merged_data_900000_in.csv
# Merging posinclust-stimulus/positions_140000_in.csv and merged-stimulus/merged_data_140000.csv into final-merged-stimulus-natgrid/final_merged_data_140000_in.csv...
# Merged posinclust-stimulus/positions_140000_in.csv and merged-stimulus/merged_data_140000.csv into final-merged-stimulus-natgrid/final_merged_data_140000_in.csv
# Merging posinclust-stimulus/positions_930000_out.csv and merged-stimulus/merged_data_930000.csv into final-merged-stimulus-natgrid/final_merged_data_930000_out.csv...
# Merged posinclust-stimulus/positions_930000_out.csv and merged-stimulus/merged_data_930000.csv into final-merged-stimulus-natgrid/final_merged_data_930000_out.csv
# Merging posinclust-stimulus/positions_260000_in.csv and merged-stimulus/merged_data_260000.csv into final-merged-stimulus-natgrid/final_merged_data_260000_in.csv...
# Merged posinclust-stimulus/positions_260000_in.csv and merged-stimulus/merged_data_260000.csv into final-merged-stimulus-natgrid/final_merged_data_260000_in.csv
# Merging posinclust-stimulus/positions_400000_out.csv and merged-stimulus/merged_data_400000.csv into final-merged-stimulus-natgrid/final_merged_data_400000_out.csv...
# Merged posinclust-stimulus/positions_400000_out.csv and merged-stimulus/merged_data_400000.csv into final-merged-stimulus-natgrid/final_merged_data_400000_out.csv
# Merging posinclust-stimulus/positions_940000_in.csv and merged-stimulus/merged_data_940000.csv into final-merged-stimulus-natgrid/final_merged_data_940000_in.csv...
# Merged posinclust-stimulus/positions_940000_in.csv and merged-stimulus/merged_data_940000.csv into final-merged-stimulus-natgrid/final_merged_data_940000_in.csv
# Merging posinclust-stimulus/positions_180000_in.csv and merged-stimulus/merged_data_180000.csv into final-merged-stimulus-natgrid/final_merged_data_180000_in.csv...
# Merged posinclust-stimulus/positions_180000_in.csv and merged-stimulus/merged_data_180000.csv into final-merged-stimulus-natgrid/final_merged_data_180000_in.csv
# Merging posinclust-stimulus/positions_600000_out.csv and merged-stimulus/merged_data_600000.csv into final-merged-stimulus-natgrid/final_merged_data_600000_out.csv...
# Merged posinclust-stimulus/positions_600000_out.csv and merged-stimulus/merged_data_600000.csv into final-merged-stimulus-natgrid/final_merged_data_600000_out.csv
# Merging posinclust-stimulus/positions_530000_out.csv and merged-stimulus/merged_data_530000.csv into final-merged-stimulus-natgrid/final_merged_data_530000_out.csv...
# Merged posinclust-stimulus/positions_530000_out.csv and merged-stimulus/merged_data_530000.csv into final-merged-stimulus-natgrid/final_merged_data_530000_out.csv
# Merging posinclust-stimulus/positions_30000_in.csv and merged-stimulus/merged_data_30000.csv into final-merged-stimulus-natgrid/final_merged_data_30000_in.csv...
# Merged posinclust-stimulus/positions_30000_in.csv and merged-stimulus/merged_data_30000.csv into final-merged-stimulus-natgrid/final_merged_data_30000_in.csv
# Merging posinclust-stimulus/positions_640000_in.csv and merged-stimulus/merged_data_640000.csv into final-merged-stimulus-natgrid/final_merged_data_640000_in.csv...
# Merged posinclust-stimulus/positions_640000_in.csv and merged-stimulus/merged_data_640000.csv into final-merged-stimulus-natgrid/final_merged_data_640000_in.csv
# Merging posinclust-stimulus/positions_600000_in.csv and merged-stimulus/merged_data_600000.csv into final-merged-stimulus-natgrid/final_merged_data_600000_in.csv...
# Merged posinclust-stimulus/positions_600000_in.csv and merged-stimulus/merged_data_600000.csv into final-merged-stimulus-natgrid/final_merged_data_600000_in.csv
# Merging posinclust-stimulus/positions_440000_in.csv and merged-stimulus/merged_data_440000.csv into final-merged-stimulus-natgrid/final_merged_data_440000_in.csv...
# Merged posinclust-stimulus/positions_440000_in.csv and merged-stimulus/merged_data_440000.csv into final-merged-stimulus-natgrid/final_merged_data_440000_in.csv
# Merging posinclust-stimulus/positions_580000_out.csv and merged-stimulus/merged_data_580000.csv into final-merged-stimulus-natgrid/final_merged_data_580000_out.csv...
# Merged posinclust-stimulus/positions_580000_out.csv and merged-stimulus/merged_data_580000.csv into final-merged-stimulus-natgrid/final_merged_data_580000_out.csv
# Merging posinclust-stimulus/positions_760000_in.csv and merged-stimulus/merged_data_760000.csv into final-merged-stimulus-natgrid/final_merged_data_760000_in.csv...
# Merged posinclust-stimulus/positions_760000_in.csv and merged-stimulus/merged_data_760000.csv into final-merged-stimulus-natgrid/final_merged_data_760000_in.csv
# Merging posinclust-stimulus/positions_560000_out.csv and merged-stimulus/merged_data_560000.csv into final-merged-stimulus-natgrid/final_merged_data_560000_out.csv...
# Merged posinclust-stimulus/positions_560000_out.csv and merged-stimulus/merged_data_560000.csv into final-merged-stimulus-natgrid/final_merged_data_560000_out.csv
# Merging posinclust-stimulus/positions_910000_in.csv and merged-stimulus/merged_data_910000.csv into final-merged-stimulus-natgrid/final_merged_data_910000_in.csv...
# Merged posinclust-stimulus/positions_910000_in.csv and merged-stimulus/merged_data_910000.csv into final-merged-stimulus-natgrid/final_merged_data_910000_in.csv
# Merging posinclust-stimulus/positions_500000_in.csv and merged-stimulus/merged_data_500000.csv into final-merged-stimulus-natgrid/final_merged_data_500000_in.csv...
# Merged posinclust-stimulus/positions_500000_in.csv and merged-stimulus/merged_data_500000.csv into final-merged-stimulus-natgrid/final_merged_data_500000_in.csv
# Merging posinclust-stimulus/positions_930000_in.csv and merged-stimulus/merged_data_930000.csv into final-merged-stimulus-natgrid/final_merged_data_930000_in.csv...
# Merged posinclust-stimulus/positions_930000_in.csv and merged-stimulus/merged_data_930000.csv into final-merged-stimulus-natgrid/final_merged_data_930000_in.csv
# Merging posinclust-stimulus/positions_800000_out.csv and merged-stimulus/merged_data_800000.csv into final-merged-stimulus-natgrid/final_merged_data_800000_out.csv...
# Merged posinclust-stimulus/positions_800000_out.csv and merged-stimulus/merged_data_800000.csv into final-merged-stimulus-natgrid/final_merged_data_800000_out.csv
# Merging posinclust-stimulus/positions_330000_out.csv and merged-stimulus/merged_data_330000.csv into final-merged-stimulus-natgrid/final_merged_data_330000_out.csv...
# Merged posinclust-stimulus/positions_330000_out.csv and merged-stimulus/merged_data_330000.csv into final-merged-stimulus-natgrid/final_merged_data_330000_out.csv
# Merging posinclust-stimulus/positions_20000_out.csv and merged-stimulus/merged_data_20000.csv into final-merged-stimulus-natgrid/final_merged_data_20000_out.csv...
# File merged-stimulus/merged_data_20000.csv not found. Skipping to next file.
# Merging posinclust-stimulus/positions_360000_out.csv and merged-stimulus/merged_data_360000.csv into final-merged-stimulus-natgrid/final_merged_data_360000_out.csv...
# Merged posinclust-stimulus/positions_360000_out.csv and merged-stimulus/merged_data_360000.csv into final-merged-stimulus-natgrid/final_merged_data_360000_out.csv
# Merging posinclust-stimulus/positions_820000_out.csv and merged-stimulus/merged_data_820000.csv into final-merged-stimulus-natgrid/final_merged_data_820000_out.csv...
# Merged posinclust-stimulus/positions_820000_out.csv and merged-stimulus/merged_data_820000.csv into final-merged-stimulus-natgrid/final_merged_data_820000_out.csv
# Merging posinclust-stimulus/positions_830000_in.csv and merged-stimulus/merged_data_830000.csv into final-merged-stimulus-natgrid/final_merged_data_830000_in.csv...
# Merged posinclust-stimulus/positions_830000_in.csv and merged-stimulus/merged_data_830000.csv into final-merged-stimulus-natgrid/final_merged_data_830000_in.csv
# Completed final data merge and normalization process. Wrote log file: simmergefin.log

# %%
# Final Merge With UMAP and and Isomap and Normalize
import pandas as pd
import numpy as np
import os
import re

input_merged_dir = "merged-calcium"
input_umap_dir = "viz-calcium-network/posinclust" #"viz-stimulus-network/posinclust"
input_isomap_dir = "Isomap2/calcium-posinclust/"
output_dir= "final-merged-calcium"

# Function to normalize values in columns
def normalize_column(col, min_value, max_value):
    # Replace NaN and Inf with specific values or handle them as needed
    col = col.fillna(0)  # Example: filling NaN with 0
    col = col.replace([np.inf, -np.inf], 0)  # Example: replacing infinite values with 0
    min_col = col.min()
    max_col = col.max()
    with open('simmergefin.log', 'a') as log_file:
        #print(f"sensor_id: {sensor_id}", file=log_file)
        print(min_col, max_col, file=log_file)
        print((col - min_col) / (max_col - min_col) * (max_value - min_value) + min_value, file=log_file)
    normalized_col = ((col - min_col) / (max_col - min_col) * (max_value - min_value) + min_value).astype(int)
    return normalized_col

# Function to post-process Clustering columns
def post_process_clustering(col):
    col_max = col.max()
    # Iterate through the range repeatedly until no more unused or solitary values are found
    for value in range(1, col_max + 1):
        count = (col == value).sum()
        if count == 0 or count == 1:
            missing_value = value
            col[col == col_max] = missing_value
            col_max -= 1
    return col
#The function iterates through the range of possible values and looks for any values that are missing or occur only once. When such a value is found, all instances of the maximum value in the column are replaced with that missing value, and col_max is decremented accordingly.
#This updated code should solve the problem without recursion and without a TypeError. You can use this function in the previous code to replace the existing post-processing function.

print("Beginnng final data merge and normalization process. Writing log file: simmergefin.log")
              
# Iterate through files in the posinclust folder
for filename in os.listdir(input_umap_dir):
    match = re.match(r'positions_(\d+)_(in|out)\.csv', filename)
    if match:
        timestamp, direction = match.groups()
        positions_umap_path = f'{input_umap_dir}/{filename}'
        positions_isomap_path =  f'{input_isomap_dir}/{filename}'
        merged_path = f'{input_merged_dir}/merged_data_{timestamp}.csv'
        final_path = f'{output_dir}/final_merged_data_{timestamp}_{direction}.csv'

        print(f'Merging {positions_umap_path}, {positions_isomap_path} and {merged_path} into {final_path}...')

        # Read the positions file
        positions_umap_data = pd.read_csv(positions_umap_path)
        positions_umap_data.columns = ["umap", "", "", "UMAPClustering","GridUMAPClustering"]
        try:
            positions_isomap_data = pd.read_csv(positions_isomap_path)
        except FileNotFoundError:
            print(f"File {positions_isomap_path} not found. Skipping to next file.")
            continue  # Skip to next loop iteration
            
        positions_isomap_data.columns = ["isomap", "", "", "IsomapGridClustering","IsomapClustering"]

        # Check and adjust "*Clustering" columns if there are zero values
        # if 0 in positions_umap_data["UMAPClustering"]:
        #     positions_umap_data["UMAPClustering"] += 1
        # if 0 in positions_umap_data["GridUMAPClustering"]:
        #     positions_umap_data["GridUMAPClustering"] += 1
        # if 0 in positions_isomap_data["IsomapGridClustering"]:
        #     positions_isomap_data["IsomapGridClustering"] += 1
        # if 0 in positions_isomap_data["IsomapClustering"]:
        #     positions_isomap_data["IsomapClustering"] += 1

        
        # Read the merged file, ignore header, and assign proper columns
        try:
            merged_data = pd.read_csv(merged_path) #, header=None, skiprows=1)
        except FileNotFoundError:
            print(f"File {merged_path} not found. Skipping to next file.")
            continue  # Skip to next loop iteration

        #merged_data.columns = ["label", "anatomy", "", "", "FiredClustering", "CalciumClustering"]

        # Append "Heatmaps" to first mirged column names after the 4th# Append "Clustering" to column names after the 4th
        new_columns = [col + "Heatmap" if idx > 3 else col for idx, col in enumerate(merged_data.columns)]
        new_columns[2] = ''
        new_columns[3] = ''
        
                
        # Assign the new column names to the DataFrame
        merged_data.columns = new_columns
        
        uncluster = []
        # Normalize values in columns 5 and 6 and all after in initial merge
        for col_name in new_columns[4:]: # + new_columns[11:]:  #[("FiredClustering", 9), ("CalciumClustering", 12)]:
            #col = merged_data[col_name]
            col = merged_data[col_name]
            #max_value = max(len(set(col)),20)
            if len(set(col)) < 10:
                max_value = len(set(col))
            else:
                max_value = 10
                
            if len(set(col)) > 1:
                normalized_col = normalize_column(col, 1, max_value)
            else:
                uncluster.append(col_name)
        
            if 0 in normalized_col:
                col += 1
            #normalized_col = normalize_column(col, 1, max_value)
            #normalized_col = post_process_clustering(normalized_col)
            merged_data[col_name] = normalized_col

        #new_col_name = col_name.replace("Clustering", "")
        #merged_data.rename(columns={col_name: new_col_name}, inplace=True)
        
        #for col_name in uncluster:
        with open('simmergefin.log', 'a') as log_file:
            print("uncluster",uncluster,file=log_file)
        merged_data.drop(columns=uncluster, inplace=True, errors='ignore')

        # Concatenate the merged_data and positions_data to place positions_data in columns 7-10
        final_data = pd.concat([merged_data, positions_umap_data, positions_isomap_data], axis=1)

        # DONT Apply post-processing to all Clustering columns
        #for col_name in final_data.columns:
        #    if "Clustering" in col_name:
        #        final_data[col_name] = post_process_clustering(final_data[col_name])

        # Save the final data
        os.makedirs(output_dir, exist_ok=True)
        final_data.to_csv(final_path, index=False)

        
        with open('simmergefin.log', 'a') as log_file:
            print(f'Merged {positions_umap_path}, {positions_isomap_path} and {merged_path} into {final_path}',file=log_file)
        print(f'Merged {positions_umap_path},{positions_isomap_path} and {merged_path} into {final_path}')

        
        # break # Stop after first file
print("Completed final data merge and normalization process. Wrote log file: simmergefin.log")
# Out:
# Beginnng final data merge and normalization process. Writing log file: simmergefin.log
# Merging viz-calcium-network/posinclust/positions_230000_out.csv, Isomap2/calcium-posinclust//positions_230000_out.csv and merged-calcium/merged_data_230000.csv into final-merged-calcium/final_merged_data_230000_out.csv...
# Merged viz-calcium-network/posinclust/positions_230000_out.csv,Isomap2/calcium-posinclust//positions_230000_out.csv and merged-calcium/merged_data_230000.csv into final-merged-calcium/final_merged_data_230000_out.csv
# Merging viz-calcium-network/posinclust/positions_290000_in.csv, Isomap2/calcium-posinclust//positions_290000_in.csv and merged-calcium/merged_data_290000.csv into final-merged-calcium/final_merged_data_290000_in.csv...
# Merged viz-calcium-network/posinclust/positions_290000_in.csv,Isomap2/calcium-posinclust//positions_290000_in.csv and merged-calcium/merged_data_290000.csv into final-merged-calcium/final_merged_data_290000_in.csv
# Merging viz-calcium-network/posinclust/positions_810000_out.csv, Isomap2/calcium-posinclust//positions_810000_out.csv and merged-calcium/merged_data_810000.csv into final-merged-calcium/final_merged_data_810000_out.csv...
# Merged viz-calcium-network/posinclust/positions_810000_out.csv,Isomap2/calcium-posinclust//positions_810000_out.csv and merged-calcium/merged_data_810000.csv into final-merged-calcium/final_merged_data_810000_out.csv
# Merging viz-calcium-network/posinclust/positions_750000_in.csv, Isomap2/calcium-posinclust//positions_750000_in.csv and merged-calcium/merged_data_750000.csv into final-merged-calcium/final_merged_data_750000_in.csv...
# Merged viz-calcium-network/posinclust/positions_750000_in.csv,Isomap2/calcium-posinclust//positions_750000_in.csv and merged-calcium/merged_data_750000.csv into final-merged-calcium/final_merged_data_750000_in.csv
# Merging viz-calcium-network/posinclust/positions_790000_out.csv, Isomap2/calcium-posinclust//positions_790000_out.csv and merged-calcium/merged_data_790000.csv into final-merged-calcium/final_merged_data_790000_out.csv...
# Merged viz-calcium-network/posinclust/positions_790000_out.csv,Isomap2/calcium-posinclust//positions_790000_out.csv and merged-calcium/merged_data_790000.csv into final-merged-calcium/final_merged_data_790000_out.csv
# Merging viz-calcium-network/posinclust/positions_270000_out.csv, Isomap2/calcium-posinclust//positions_270000_out.csv and merged-calcium/merged_data_270000.csv into final-merged-calcium/final_merged_data_270000_out.csv...
# Merged viz-calcium-network/posinclust/positions_270000_out.csv,Isomap2/calcium-posinclust//positions_270000_out.csv and merged-calcium/merged_data_270000.csv into final-merged-calcium/final_merged_data_270000_out.csv
# Merging viz-calcium-network/posinclust/positions_370000_out.csv, Isomap2/calcium-posinclust//positions_370000_out.csv and merged-calcium/merged_data_370000.csv into final-merged-calcium/final_merged_data_370000_out.csv...
# Merged viz-calcium-network/posinclust/positions_370000_out.csv,Isomap2/calcium-posinclust//positions_370000_out.csv and merged-calcium/merged_data_370000.csv into final-merged-calcium/final_merged_data_370000_out.csv
# Merging viz-calcium-network/posinclust/positions_250000_in.csv, Isomap2/calcium-posinclust//positions_250000_in.csv and merged-calcium/merged_data_250000.csv into final-merged-calcium/final_merged_data_250000_in.csv...
# Merged viz-calcium-network/posinclust/positions_250000_in.csv,Isomap2/calcium-posinclust//positions_250000_in.csv and merged-calcium/merged_data_250000.csv into final-merged-calcium/final_merged_data_250000_in.csv
# Merging viz-calcium-network/posinclust/positions_780000_in.csv, Isomap2/calcium-posinclust//positions_780000_in.csv and merged-calcium/merged_data_780000.csv into final-merged-calcium/final_merged_data_780000_in.csv...
# Merged viz-calcium-network/posinclust/positions_780000_in.csv,Isomap2/calcium-posinclust//positions_780000_in.csv and merged-calcium/merged_data_780000.csv into final-merged-calcium/final_merged_data_780000_in.csv
# Merging viz-calcium-network/posinclust/positions_210000_in.csv, Isomap2/calcium-posinclust//positions_210000_in.csv and merged-calcium/merged_data_210000.csv into final-merged-calcium/final_merged_data_210000_in.csv...
# Merged viz-calcium-network/posinclust/positions_210000_in.csv,Isomap2/calcium-posinclust//positions_210000_in.csv and merged-calcium/merged_data_210000.csv into final-merged-calcium/final_merged_data_210000_in.csv
# Merging viz-calcium-network/posinclust/positions_800000_in.csv, Isomap2/calcium-posinclust//positions_800000_in.csv and merged-calcium/merged_data_800000.csv into final-merged-calcium/final_merged_data_800000_in.csv...
# Merged viz-calcium-network/posinclust/positions_800000_in.csv,Isomap2/calcium-posinclust//positions_800000_in.csv and merged-calcium/merged_data_800000.csv into final-merged-calcium/final_merged_data_800000_in.csv
# Merging viz-calcium-network/posinclust/positions_630000_out.csv, Isomap2/calcium-posinclust//positions_630000_out.csv and merged-calcium/merged_data_630000.csv into final-merged-calcium/final_merged_data_630000_out.csv...
# Merged viz-calcium-network/posinclust/positions_630000_out.csv,Isomap2/calcium-posinclust//positions_630000_out.csv and merged-calcium/merged_data_630000.csv into final-merged-calcium/final_merged_data_630000_out.csv
# Merging viz-calcium-network/posinclust/positions_210000_out.csv, Isomap2/calcium-posinclust//positions_210000_out.csv and merged-calcium/merged_data_210000.csv into final-merged-calcium/final_merged_data_210000_out.csv...
# Merged viz-calcium-network/posinclust/positions_210000_out.csv,Isomap2/calcium-posinclust//positions_210000_out.csv and merged-calcium/merged_data_210000.csv into final-merged-calcium/final_merged_data_210000_out.csv
# Merging viz-calcium-network/posinclust/positions_650000_in.csv, Isomap2/calcium-posinclust//positions_650000_in.csv and merged-calcium/merged_data_650000.csv into final-merged-calcium/final_merged_data_650000_in.csv...
# Merged viz-calcium-network/posinclust/positions_650000_in.csv,Isomap2/calcium-posinclust//positions_650000_in.csv and merged-calcium/merged_data_650000.csv into final-merged-calcium/final_merged_data_650000_in.csv
# Merging viz-calcium-network/posinclust/positions_150000_out.csv, Isomap2/calcium-posinclust//positions_150000_out.csv and merged-calcium/merged_data_150000.csv into final-merged-calcium/final_merged_data_150000_out.csv...
# Merged viz-calcium-network/posinclust/positions_150000_out.csv,Isomap2/calcium-posinclust//positions_150000_out.csv and merged-calcium/merged_data_150000.csv into final-merged-calcium/final_merged_data_150000_out.csv
# Merging viz-calcium-network/posinclust/positions_660000_out.csv, Isomap2/calcium-posinclust//positions_660000_out.csv and merged-calcium/merged_data_660000.csv into final-merged-calcium/final_merged_data_660000_out.csv...
# Merged viz-calcium-network/posinclust/positions_660000_out.csv,Isomap2/calcium-posinclust//positions_660000_out.csv and merged-calcium/merged_data_660000.csv into final-merged-calcium/final_merged_data_660000_out.csv
# Merging viz-calcium-network/posinclust/positions_130000_in.csv, Isomap2/calcium-posinclust//positions_130000_in.csv and merged-calcium/merged_data_130000.csv into final-merged-calcium/final_merged_data_130000_in.csv...
# Merged viz-calcium-network/posinclust/positions_130000_in.csv,Isomap2/calcium-posinclust//positions_130000_in.csv and merged-calcium/merged_data_130000.csv into final-merged-calcium/final_merged_data_130000_in.csv
# Merging viz-calcium-network/posinclust/positions_980000_out.csv, Isomap2/calcium-posinclust//positions_980000_out.csv and merged-calcium/merged_data_980000.csv into final-merged-calcium/final_merged_data_980000_out.csv...
# Merged viz-calcium-network/posinclust/positions_980000_out.csv,Isomap2/calcium-posinclust//positions_980000_out.csv and merged-calcium/merged_data_980000.csv into final-merged-calcium/final_merged_data_980000_out.csv
# Merging viz-calcium-network/posinclust/positions_10000_in.csv, Isomap2/calcium-posinclust//positions_10000_in.csv and merged-calcium/merged_data_10000.csv into final-merged-calcium/final_merged_data_10000_in.csv...
# File merged-calcium/merged_data_10000.csv not found. Skipping to next file.
# Merging viz-calcium-network/posinclust/positions_80000_out.csv, Isomap2/calcium-posinclust//positions_80000_out.csv and merged-calcium/merged_data_80000.csv into final-merged-calcium/final_merged_data_80000_out.csv...
# Merged viz-calcium-network/posinclust/positions_80000_out.csv,Isomap2/calcium-posinclust//positions_80000_out.csv and merged-calcium/merged_data_80000.csv into final-merged-calcium/final_merged_data_80000_out.csv
# Merging viz-calcium-network/posinclust/positions_960000_out.csv, Isomap2/calcium-posinclust//positions_960000_out.csv and merged-calcium/merged_data_960000.csv into final-merged-calcium/final_merged_data_960000_out.csv...
# Merged viz-calcium-network/posinclust/positions_960000_out.csv,Isomap2/calcium-posinclust//positions_960000_out.csv and merged-calcium/merged_data_960000.csv into final-merged-calcium/final_merged_data_960000_out.csv
# Merging viz-calcium-network/posinclust/positions_60000_in.csv, Isomap2/calcium-posinclust//positions_60000_in.csv and merged-calcium/merged_data_60000.csv into final-merged-calcium/final_merged_data_60000_in.csv...
# Merged viz-calcium-network/posinclust/positions_60000_in.csv,Isomap2/calcium-posinclust//positions_60000_in.csv and merged-calcium/merged_data_60000.csv into final-merged-calcium/final_merged_data_60000_in.csv
# Merging viz-calcium-network/posinclust/positions_840000_out.csv, Isomap2/calcium-posinclust//positions_840000_out.csv and merged-calcium/merged_data_840000.csv into final-merged-calcium/final_merged_data_840000_out.csv...
# Merged viz-calcium-network/posinclust/positions_840000_out.csv,Isomap2/calcium-posinclust//positions_840000_out.csv and merged-calcium/merged_data_840000.csv into final-merged-calcium/final_merged_data_840000_out.csv
# Merging viz-calcium-network/posinclust/positions_280000_out.csv, Isomap2/calcium-posinclust//positions_280000_out.csv and merged-calcium/merged_data_280000.csv into final-merged-calcium/final_merged_data_280000_out.csv...
# Merged viz-calcium-network/posinclust/positions_280000_out.csv,Isomap2/calcium-posinclust//positions_280000_out.csv and merged-calcium/merged_data_280000.csv into final-merged-calcium/final_merged_data_280000_out.csv
# Merging viz-calcium-network/posinclust/positions_490000_out.csv, Isomap2/calcium-posinclust//positions_490000_out.csv and merged-calcium/merged_data_490000.csv into final-merged-calcium/final_merged_data_490000_out.csv...
# Merged viz-calcium-network/posinclust/positions_490000_out.csv,Isomap2/calcium-posinclust//positions_490000_out.csv and merged-calcium/merged_data_490000.csv into final-merged-calcium/final_merged_data_490000_out.csv
# Merging viz-calcium-network/posinclust/positions_920000_out.csv, Isomap2/calcium-posinclust//positions_920000_out.csv and merged-calcium/merged_data_920000.csv into final-merged-calcium/final_merged_data_920000_out.csv...
# Merged viz-calcium-network/posinclust/positions_920000_out.csv,Isomap2/calcium-posinclust//positions_920000_out.csv and merged-calcium/merged_data_920000.csv into final-merged-calcium/final_merged_data_920000_out.csv
# Merging viz-calcium-network/posinclust/positions_530000_in.csv, Isomap2/calcium-posinclust//positions_530000_in.csv and merged-calcium/merged_data_530000.csv into final-merged-calcium/final_merged_data_530000_in.csv...
# Merged viz-calcium-network/posinclust/positions_530000_in.csv,Isomap2/calcium-posinclust//positions_530000_in.csv and merged-calcium/merged_data_530000.csv into final-merged-calcium/final_merged_data_530000_in.csv
# Merging viz-calcium-network/posinclust/positions_200000_in.csv, Isomap2/calcium-posinclust//positions_200000_in.csv and merged-calcium/merged_data_200000.csv into final-merged-calcium/final_merged_data_200000_in.csv...
# Merged viz-calcium-network/posinclust/positions_200000_in.csv,Isomap2/calcium-posinclust//positions_200000_in.csv and merged-calcium/merged_data_200000.csv into final-merged-calcium/final_merged_data_200000_in.csv
# Merging viz-calcium-network/posinclust/positions_950000_out.csv, Isomap2/calcium-posinclust//positions_950000_out.csv and merged-calcium/merged_data_950000.csv into final-merged-calcium/final_merged_data_950000_out.csv...
# Merged viz-calcium-network/posinclust/positions_950000_out.csv,Isomap2/calcium-posinclust//positions_950000_out.csv and merged-calcium/merged_data_950000.csv into final-merged-calcium/final_merged_data_950000_out.csv
# Merging viz-calcium-network/posinclust/positions_0_in.csv, Isomap2/calcium-posinclust//positions_0_in.csv and merged-calcium/merged_data_0.csv into final-merged-calcium/final_merged_data_0_in.csv...
# File Isomap2/calcium-posinclust//positions_0_in.csv not found. Skipping to next file.
# Merging viz-calcium-network/posinclust/positions_620000_out.csv, Isomap2/calcium-posinclust//positions_620000_out.csv and merged-calcium/merged_data_620000.csv into final-merged-calcium/final_merged_data_620000_out.csv...
# Merged viz-calcium-network/posinclust/positions_620000_out.csv,Isomap2/calcium-posinclust//positions_620000_out.csv and merged-calcium/merged_data_620000.csv into final-merged-calcium/final_merged_data_620000_out.csv
# Merging viz-calcium-network/posinclust/positions_920000_in.csv, Isomap2/calcium-posinclust//positions_920000_in.csv and merged-calcium/merged_data_920000.csv into final-merged-calcium/final_merged_data_920000_in.csv...
# Merged viz-calcium-network/posinclust/positions_920000_in.csv,Isomap2/calcium-posinclust//positions_920000_in.csv and merged-calcium/merged_data_920000.csv into final-merged-calcium/final_merged_data_920000_in.csv
# Merging viz-calcium-network/posinclust/positions_120000_out.csv, Isomap2/calcium-posinclust//positions_120000_out.csv and merged-calcium/merged_data_120000.csv into final-merged-calcium/final_merged_data_120000_out.csv...
# Merged viz-calcium-network/posinclust/positions_120000_out.csv,Isomap2/calcium-posinclust//positions_120000_out.csv and merged-calcium/merged_data_120000.csv into final-merged-calcium/final_merged_data_120000_out.csv
# Merging viz-calcium-network/posinclust/positions_990000_out.csv, Isomap2/calcium-posinclust//positions_990000_out.csv and merged-calcium/merged_data_990000.csv into final-merged-calcium/final_merged_data_990000_out.csv...
# File merged-calcium/merged_data_990000.csv not found. Skipping to next file.
# Merging viz-calcium-network/posinclust/positions_790000_in.csv, Isomap2/calcium-posinclust//positions_790000_in.csv and merged-calcium/merged_data_790000.csv into final-merged-calcium/final_merged_data_790000_in.csv...
# Merged viz-calcium-network/posinclust/positions_790000_in.csv,Isomap2/calcium-posinclust//positions_790000_in.csv and merged-calcium/merged_data_790000.csv into final-merged-calcium/final_merged_data_790000_in.csv
# Merging viz-calcium-network/posinclust/positions_100000_out.csv, Isomap2/calcium-posinclust//positions_100000_out.csv and merged-calcium/merged_data_100000.csv into final-merged-calcium/final_merged_data_100000_out.csv...
# Merged viz-calcium-network/posinclust/positions_100000_out.csv,Isomap2/calcium-posinclust//positions_100000_out.csv and merged-calcium/merged_data_100000.csv into final-merged-calcium/final_merged_data_100000_out.csv
# Merging viz-calcium-network/posinclust/positions_440000_out.csv, Isomap2/calcium-posinclust//positions_440000_out.csv and merged-calcium/merged_data_440000.csv into final-merged-calcium/final_merged_data_440000_out.csv...
# File Isomap2/calcium-posinclust//positions_440000_out.csv not found. Skipping to next file.
# Merging viz-calcium-network/posinclust/positions_660000_in.csv, Isomap2/calcium-posinclust//positions_660000_in.csv and merged-calcium/merged_data_660000.csv into final-merged-calcium/final_merged_data_660000_in.csv...
# Merged viz-calcium-network/posinclust/positions_660000_in.csv,Isomap2/calcium-posinclust//positions_660000_in.csv and merged-calcium/merged_data_660000.csv into final-merged-calcium/final_merged_data_660000_in.csv
# Merging viz-calcium-network/posinclust/positions_60000_out.csv, Isomap2/calcium-posinclust//positions_60000_out.csv and merged-calcium/merged_data_60000.csv into final-merged-calcium/final_merged_data_60000_out.csv...
# Merged viz-calcium-network/posinclust/positions_60000_out.csv,Isomap2/calcium-posinclust//positions_60000_out.csv and merged-calcium/merged_data_60000.csv into final-merged-calcium/final_merged_data_60000_out.csv
# Merging viz-calcium-network/posinclust/positions_190000_out.csv, Isomap2/calcium-posinclust//positions_190000_out.csv and merged-calcium/merged_data_190000.csv into final-merged-calcium/final_merged_data_190000_out.csv...
# Merged viz-calcium-network/posinclust/positions_190000_out.csv,Isomap2/calcium-posinclust//positions_190000_out.csv and merged-calcium/merged_data_190000.csv into final-merged-calcium/final_merged_data_190000_out.csv
# Merging viz-calcium-network/posinclust/positions_150000_in.csv, Isomap2/calcium-posinclust//positions_150000_in.csv and merged-calcium/merged_data_150000.csv into final-merged-calcium/final_merged_data_150000_in.csv...
# Merged viz-calcium-network/posinclust/positions_150000_in.csv,Isomap2/calcium-posinclust//positions_150000_in.csv and merged-calcium/merged_data_150000.csv into final-merged-calcium/final_merged_data_150000_in.csv
# Merging viz-calcium-network/posinclust/positions_770000_in.csv, Isomap2/calcium-posinclust//positions_770000_in.csv and merged-calcium/merged_data_770000.csv into final-merged-calcium/final_merged_data_770000_in.csv...
# Merged viz-calcium-network/posinclust/positions_770000_in.csv,Isomap2/calcium-posinclust//positions_770000_in.csv and merged-calcium/merged_data_770000.csv into final-merged-calcium/final_merged_data_770000_in.csv
# Merging viz-calcium-network/posinclust/positions_380000_out.csv, Isomap2/calcium-posinclust//positions_380000_out.csv and merged-calcium/merged_data_380000.csv into final-merged-calcium/final_merged_data_380000_out.csv...
# Merged viz-calcium-network/posinclust/positions_380000_out.csv,Isomap2/calcium-posinclust//positions_380000_out.csv and merged-calcium/merged_data_380000.csv into final-merged-calcium/final_merged_data_380000_out.csv
# Merging viz-calcium-network/posinclust/positions_470000_out.csv, Isomap2/calcium-posinclust//positions_470000_out.csv and merged-calcium/merged_data_470000.csv into final-merged-calcium/final_merged_data_470000_out.csv...
# Merged viz-calcium-network/posinclust/positions_470000_out.csv,Isomap2/calcium-posinclust//positions_470000_out.csv and merged-calcium/merged_data_470000.csv into final-merged-calcium/final_merged_data_470000_out.csv
# Merging viz-calcium-network/posinclust/positions_620000_in.csv, Isomap2/calcium-posinclust//positions_620000_in.csv and merged-calcium/merged_data_620000.csv into final-merged-calcium/final_merged_data_620000_in.csv...
# Merged viz-calcium-network/posinclust/positions_620000_in.csv,Isomap2/calcium-posinclust//positions_620000_in.csv and merged-calcium/merged_data_620000.csv into final-merged-calcium/final_merged_data_620000_in.csv
# Merging viz-calcium-network/posinclust/positions_330000_in.csv, Isomap2/calcium-posinclust//positions_330000_in.csv and merged-calcium/merged_data_330000.csv into final-merged-calcium/final_merged_data_330000_in.csv...
# Merged viz-calcium-network/posinclust/positions_330000_in.csv,Isomap2/calcium-posinclust//positions_330000_in.csv and merged-calcium/merged_data_330000.csv into final-merged-calcium/final_merged_data_330000_in.csv
# Merging viz-calcium-network/posinclust/positions_910000_out.csv, Isomap2/calcium-posinclust//positions_910000_out.csv and merged-calcium/merged_data_910000.csv into final-merged-calcium/final_merged_data_910000_out.csv...
# Merged viz-calcium-network/posinclust/positions_910000_out.csv,Isomap2/calcium-posinclust//positions_910000_out.csv and merged-calcium/merged_data_910000.csv into final-merged-calcium/final_merged_data_910000_out.csv
# Merging viz-calcium-network/posinclust/positions_550000_out.csv, Isomap2/calcium-posinclust//positions_550000_out.csv and merged-calcium/merged_data_550000.csv into final-merged-calcium/final_merged_data_550000_out.csv...
# Merged viz-calcium-network/posinclust/positions_550000_out.csv,Isomap2/calcium-posinclust//positions_550000_out.csv and merged-calcium/merged_data_550000.csv into final-merged-calcium/final_merged_data_550000_out.csv
# Merging viz-calcium-network/posinclust/positions_170000_out.csv, Isomap2/calcium-posinclust//positions_170000_out.csv and merged-calcium/merged_data_170000.csv into final-merged-calcium/final_merged_data_170000_out.csv...
# Merged viz-calcium-network/posinclust/positions_170000_out.csv,Isomap2/calcium-posinclust//positions_170000_out.csv and merged-calcium/merged_data_170000.csv into final-merged-calcium/final_merged_data_170000_out.csv
# Merging viz-calcium-network/posinclust/positions_190000_in.csv, Isomap2/calcium-posinclust//positions_190000_in.csv and merged-calcium/merged_data_190000.csv into final-merged-calcium/final_merged_data_190000_in.csv...
# Merged viz-calcium-network/posinclust/positions_190000_in.csv,Isomap2/calcium-posinclust//positions_190000_in.csv and merged-calcium/merged_data_190000.csv into final-merged-calcium/final_merged_data_190000_in.csv
# Merging viz-calcium-network/posinclust/positions_30000_out.csv, Isomap2/calcium-posinclust//positions_30000_out.csv and merged-calcium/merged_data_30000.csv into final-merged-calcium/final_merged_data_30000_out.csv...
# Merged viz-calcium-network/posinclust/positions_30000_out.csv,Isomap2/calcium-posinclust//positions_30000_out.csv and merged-calcium/merged_data_30000.csv into final-merged-calcium/final_merged_data_30000_out.csv
# Merging viz-calcium-network/posinclust/positions_820000_in.csv, Isomap2/calcium-posinclust//positions_820000_in.csv and merged-calcium/merged_data_820000.csv into final-merged-calcium/final_merged_data_820000_in.csv...
# Merged viz-calcium-network/posinclust/positions_820000_in.csv,Isomap2/calcium-posinclust//positions_820000_in.csv and merged-calcium/merged_data_820000.csv into final-merged-calcium/final_merged_data_820000_in.csv
# Merging viz-calcium-network/posinclust/positions_50000_out.csv, Isomap2/calcium-posinclust//positions_50000_out.csv and merged-calcium/merged_data_50000.csv into final-merged-calcium/final_merged_data_50000_out.csv...
# Merged viz-calcium-network/posinclust/positions_50000_out.csv,Isomap2/calcium-posinclust//positions_50000_out.csv and merged-calcium/merged_data_50000.csv into final-merged-calcium/final_merged_data_50000_out.csv
# Merging viz-calcium-network/posinclust/positions_130000_out.csv, Isomap2/calcium-posinclust//positions_130000_out.csv and merged-calcium/merged_data_130000.csv into final-merged-calcium/final_merged_data_130000_out.csv...
# Merged viz-calcium-network/posinclust/positions_130000_out.csv,Isomap2/calcium-posinclust//positions_130000_out.csv and merged-calcium/merged_data_130000.csv into final-merged-calcium/final_merged_data_130000_out.csv
# Merging viz-calcium-network/posinclust/positions_720000_in.csv, Isomap2/calcium-posinclust//positions_720000_in.csv and merged-calcium/merged_data_720000.csv into final-merged-calcium/final_merged_data_720000_in.csv...
# Merged viz-calcium-network/posinclust/positions_720000_in.csv,Isomap2/calcium-posinclust//positions_720000_in.csv and merged-calcium/merged_data_720000.csv into final-merged-calcium/final_merged_data_720000_in.csv
# Merging viz-calcium-network/posinclust/positions_570000_out.csv, Isomap2/calcium-posinclust//positions_570000_out.csv and merged-calcium/merged_data_570000.csv into final-merged-calcium/final_merged_data_570000_out.csv...
# Merged viz-calcium-network/posinclust/positions_570000_out.csv,Isomap2/calcium-posinclust//positions_570000_out.csv and merged-calcium/merged_data_570000.csv into final-merged-calcium/final_merged_data_570000_out.csv
# Merging viz-calcium-network/posinclust/positions_700000_out.csv, Isomap2/calcium-posinclust//positions_700000_out.csv and merged-calcium/merged_data_700000.csv into final-merged-calcium/final_merged_data_700000_out.csv...
# Merged viz-calcium-network/posinclust/positions_700000_out.csv,Isomap2/calcium-posinclust//positions_700000_out.csv and merged-calcium/merged_data_700000.csv into final-merged-calcium/final_merged_data_700000_out.csv
# Merging viz-calcium-network/posinclust/positions_180000_out.csv, Isomap2/calcium-posinclust//positions_180000_out.csv and merged-calcium/merged_data_180000.csv into final-merged-calcium/final_merged_data_180000_out.csv...
# Merged viz-calcium-network/posinclust/positions_180000_out.csv,Isomap2/calcium-posinclust//positions_180000_out.csv and merged-calcium/merged_data_180000.csv into final-merged-calcium/final_merged_data_180000_out.csv
# Merging viz-calcium-network/posinclust/positions_0_out.csv, Isomap2/calcium-posinclust//positions_0_out.csv and merged-calcium/merged_data_0.csv into final-merged-calcium/final_merged_data_0_out.csv...
# File Isomap2/calcium-posinclust//positions_0_out.csv not found. Skipping to next file.
# Merging viz-calcium-network/posinclust/positions_900000_out.csv, Isomap2/calcium-posinclust//positions_900000_out.csv and merged-calcium/merged_data_900000.csv into final-merged-calcium/final_merged_data_900000_out.csv...
# Merged viz-calcium-network/posinclust/positions_900000_out.csv,Isomap2/calcium-posinclust//positions_900000_out.csv and merged-calcium/merged_data_900000.csv into final-merged-calcium/final_merged_data_900000_out.csv
# Merging viz-calcium-network/posinclust/positions_20000_in.csv, Isomap2/calcium-posinclust//positions_20000_in.csv and merged-calcium/merged_data_20000.csv into final-merged-calcium/final_merged_data_20000_in.csv...
# File merged-calcium/merged_data_20000.csv not found. Skipping to next file.
# Merging viz-calcium-network/posinclust/positions_40000_out.csv, Isomap2/calcium-posinclust//positions_40000_out.csv and merged-calcium/merged_data_40000.csv into final-merged-calcium/final_merged_data_40000_out.csv...
# Merged viz-calcium-network/posinclust/positions_40000_out.csv,Isomap2/calcium-posinclust//positions_40000_out.csv and merged-calcium/merged_data_40000.csv into final-merged-calcium/final_merged_data_40000_out.csv
# Merging viz-calcium-network/posinclust/positions_740000_in.csv, Isomap2/calcium-posinclust//positions_740000_in.csv and merged-calcium/merged_data_740000.csv into final-merged-calcium/final_merged_data_740000_in.csv...
# Merged viz-calcium-network/posinclust/positions_740000_in.csv,Isomap2/calcium-posinclust//positions_740000_in.csv and merged-calcium/merged_data_740000.csv into final-merged-calcium/final_merged_data_740000_in.csv
# Merging viz-calcium-network/posinclust/positions_520000_out.csv, Isomap2/calcium-posinclust//positions_520000_out.csv and merged-calcium/merged_data_520000.csv into final-merged-calcium/final_merged_data_520000_out.csv...
# Merged viz-calcium-network/posinclust/positions_520000_out.csv,Isomap2/calcium-posinclust//positions_520000_out.csv and merged-calcium/merged_data_520000.csv into final-merged-calcium/final_merged_data_520000_out.csv
# Merging viz-calcium-network/posinclust/positions_980000_in.csv, Isomap2/calcium-posinclust//positions_980000_in.csv and merged-calcium/merged_data_980000.csv into final-merged-calcium/final_merged_data_980000_in.csv...
# Merged viz-calcium-network/posinclust/positions_980000_in.csv,Isomap2/calcium-posinclust//positions_980000_in.csv and merged-calcium/merged_data_980000.csv into final-merged-calcium/final_merged_data_980000_in.csv
# Merging viz-calcium-network/posinclust/positions_300000_in.csv, Isomap2/calcium-posinclust//positions_300000_in.csv and merged-calcium/merged_data_300000.csv into final-merged-calcium/final_merged_data_300000_in.csv...
# Merged viz-calcium-network/posinclust/positions_300000_in.csv,Isomap2/calcium-posinclust//positions_300000_in.csv and merged-calcium/merged_data_300000.csv into final-merged-calcium/final_merged_data_300000_in.csv
# Merging viz-calcium-network/posinclust/positions_170000_in.csv, Isomap2/calcium-posinclust//positions_170000_in.csv and merged-calcium/merged_data_170000.csv into final-merged-calcium/final_merged_data_170000_in.csv...
# Merged viz-calcium-network/posinclust/positions_170000_in.csv,Isomap2/calcium-posinclust//positions_170000_in.csv and merged-calcium/merged_data_170000.csv into final-merged-calcium/final_merged_data_170000_in.csv
# Merging viz-calcium-network/posinclust/positions_710000_out.csv, Isomap2/calcium-posinclust//positions_710000_out.csv and merged-calcium/merged_data_710000.csv into final-merged-calcium/final_merged_data_710000_out.csv...
# Merged viz-calcium-network/posinclust/positions_710000_out.csv,Isomap2/calcium-posinclust//positions_710000_out.csv and merged-calcium/merged_data_710000.csv into final-merged-calcium/final_merged_data_710000_out.csv
# Merging viz-calcium-network/posinclust/positions_420000_in.csv, Isomap2/calcium-posinclust//positions_420000_in.csv and merged-calcium/merged_data_420000.csv into final-merged-calcium/final_merged_data_420000_in.csv...
# File Isomap2/calcium-posinclust//positions_420000_in.csv not found. Skipping to next file.
# Merging viz-calcium-network/posinclust/positions_970000_out.csv, Isomap2/calcium-posinclust//positions_970000_out.csv and merged-calcium/merged_data_970000.csv into final-merged-calcium/final_merged_data_970000_out.csv...
# Merged viz-calcium-network/posinclust/positions_970000_out.csv,Isomap2/calcium-posinclust//positions_970000_out.csv and merged-calcium/merged_data_970000.csv into final-merged-calcium/final_merged_data_970000_out.csv
# Merging viz-calcium-network/posinclust/positions_500000_out.csv, Isomap2/calcium-posinclust//positions_500000_out.csv and merged-calcium/merged_data_500000.csv into final-merged-calcium/final_merged_data_500000_out.csv...
# Merged viz-calcium-network/posinclust/positions_500000_out.csv,Isomap2/calcium-posinclust//positions_500000_out.csv and merged-calcium/merged_data_500000.csv into final-merged-calcium/final_merged_data_500000_out.csv
# Merging viz-calcium-network/posinclust/positions_630000_in.csv, Isomap2/calcium-posinclust//positions_630000_in.csv and merged-calcium/merged_data_630000.csv into final-merged-calcium/final_merged_data_630000_in.csv...
# Merged viz-calcium-network/posinclust/positions_630000_in.csv,Isomap2/calcium-posinclust//positions_630000_in.csv and merged-calcium/merged_data_630000.csv into final-merged-calcium/final_merged_data_630000_in.csv
# Merging viz-calcium-network/posinclust/positions_740000_out.csv, Isomap2/calcium-posinclust//positions_740000_out.csv and merged-calcium/merged_data_740000.csv into final-merged-calcium/final_merged_data_740000_out.csv...
# Merged viz-calcium-network/posinclust/positions_740000_out.csv,Isomap2/calcium-posinclust//positions_740000_out.csv and merged-calcium/merged_data_740000.csv into final-merged-calcium/final_merged_data_740000_out.csv
# Merging viz-calcium-network/posinclust/positions_840000_in.csv, Isomap2/calcium-posinclust//positions_840000_in.csv and merged-calcium/merged_data_840000.csv into final-merged-calcium/final_merged_data_840000_in.csv...
# Merged viz-calcium-network/posinclust/positions_840000_in.csv,Isomap2/calcium-posinclust//positions_840000_in.csv and merged-calcium/merged_data_840000.csv into final-merged-calcium/final_merged_data_840000_in.csv
# Merging viz-calcium-network/posinclust/positions_720000_out.csv, Isomap2/calcium-posinclust//positions_720000_out.csv and merged-calcium/merged_data_720000.csv into final-merged-calcium/final_merged_data_720000_out.csv...
# Merged viz-calcium-network/posinclust/positions_720000_out.csv,Isomap2/calcium-posinclust//positions_720000_out.csv and merged-calcium/merged_data_720000.csv into final-merged-calcium/final_merged_data_720000_out.csv
# Merging viz-calcium-network/posinclust/positions_730000_in.csv, Isomap2/calcium-posinclust//positions_730000_in.csv and merged-calcium/merged_data_730000.csv into final-merged-calcium/final_merged_data_730000_in.csv...
# Merged viz-calcium-network/posinclust/positions_730000_in.csv,Isomap2/calcium-posinclust//positions_730000_in.csv and merged-calcium/merged_data_730000.csv into final-merged-calcium/final_merged_data_730000_in.csv
# Merging viz-calcium-network/posinclust/positions_880000_out.csv, Isomap2/calcium-posinclust//positions_880000_out.csv and merged-calcium/merged_data_880000.csv into final-merged-calcium/final_merged_data_880000_out.csv...
# Merged viz-calcium-network/posinclust/positions_880000_out.csv,Isomap2/calcium-posinclust//positions_880000_out.csv and merged-calcium/merged_data_880000.csv into final-merged-calcium/final_merged_data_880000_out.csv
# Merging viz-calcium-network/posinclust/positions_640000_out.csv, Isomap2/calcium-posinclust//positions_640000_out.csv and merged-calcium/merged_data_640000.csv into final-merged-calcium/final_merged_data_640000_out.csv...
# Merged viz-calcium-network/posinclust/positions_640000_out.csv,Isomap2/calcium-posinclust//positions_640000_out.csv and merged-calcium/merged_data_640000.csv into final-merged-calcium/final_merged_data_640000_out.csv
# Merging viz-calcium-network/posinclust/positions_550000_in.csv, Isomap2/calcium-posinclust//positions_550000_in.csv and merged-calcium/merged_data_550000.csv into final-merged-calcium/final_merged_data_550000_in.csv...
# Merged viz-calcium-network/posinclust/positions_550000_in.csv,Isomap2/calcium-posinclust//positions_550000_in.csv and merged-calcium/merged_data_550000.csv into final-merged-calcium/final_merged_data_550000_in.csv
# Merging viz-calcium-network/posinclust/positions_220000_in.csv, Isomap2/calcium-posinclust//positions_220000_in.csv and merged-calcium/merged_data_220000.csv into final-merged-calcium/final_merged_data_220000_in.csv...
# Merged viz-calcium-network/posinclust/positions_220000_in.csv,Isomap2/calcium-posinclust//positions_220000_in.csv and merged-calcium/merged_data_220000.csv into final-merged-calcium/final_merged_data_220000_in.csv
# Merging viz-calcium-network/posinclust/positions_340000_in.csv, Isomap2/calcium-posinclust//positions_340000_in.csv and merged-calcium/merged_data_340000.csv into final-merged-calcium/final_merged_data_340000_in.csv...
# Merged viz-calcium-network/posinclust/positions_340000_in.csv,Isomap2/calcium-posinclust//positions_340000_in.csv and merged-calcium/merged_data_340000.csv into final-merged-calcium/final_merged_data_340000_in.csv
# Merging viz-calcium-network/posinclust/positions_460000_out.csv, Isomap2/calcium-posinclust//positions_460000_out.csv and merged-calcium/merged_data_460000.csv into final-merged-calcium/final_merged_data_460000_out.csv...
# Merged viz-calcium-network/posinclust/positions_460000_out.csv,Isomap2/calcium-posinclust//positions_460000_out.csv and merged-calcium/merged_data_460000.csv into final-merged-calcium/final_merged_data_460000_out.csv
# Merging viz-calcium-network/posinclust/positions_560000_in.csv, Isomap2/calcium-posinclust//positions_560000_in.csv and merged-calcium/merged_data_560000.csv into final-merged-calcium/final_merged_data_560000_in.csv...
# Merged viz-calcium-network/posinclust/positions_560000_in.csv,Isomap2/calcium-posinclust//positions_560000_in.csv and merged-calcium/merged_data_560000.csv into final-merged-calcium/final_merged_data_560000_in.csv
# Merging viz-calcium-network/posinclust/positions_810000_in.csv, Isomap2/calcium-posinclust//positions_810000_in.csv and merged-calcium/merged_data_810000.csv into final-merged-calcium/final_merged_data_810000_in.csv...
# Merged viz-calcium-network/posinclust/positions_810000_in.csv,Isomap2/calcium-posinclust//positions_810000_in.csv and merged-calcium/merged_data_810000.csv into final-merged-calcium/final_merged_data_810000_in.csv
# Merging viz-calcium-network/posinclust/positions_410000_in.csv, Isomap2/calcium-posinclust//positions_410000_in.csv and merged-calcium/merged_data_410000.csv into final-merged-calcium/final_merged_data_410000_in.csv...
# Merged viz-calcium-network/posinclust/positions_410000_in.csv,Isomap2/calcium-posinclust//positions_410000_in.csv and merged-calcium/merged_data_410000.csv into final-merged-calcium/final_merged_data_410000_in.csv
# Merging viz-calcium-network/posinclust/positions_960000_in.csv, Isomap2/calcium-posinclust//positions_960000_in.csv and merged-calcium/merged_data_960000.csv into final-merged-calcium/final_merged_data_960000_in.csv...
# Merged viz-calcium-network/posinclust/positions_960000_in.csv,Isomap2/calcium-posinclust//positions_960000_in.csv and merged-calcium/merged_data_960000.csv into final-merged-calcium/final_merged_data_960000_in.csv
# Merging viz-calcium-network/posinclust/positions_670000_out.csv, Isomap2/calcium-posinclust//positions_670000_out.csv and merged-calcium/merged_data_670000.csv into final-merged-calcium/final_merged_data_670000_out.csv...
# Merged viz-calcium-network/posinclust/positions_670000_out.csv,Isomap2/calcium-posinclust//positions_670000_out.csv and merged-calcium/merged_data_670000.csv into final-merged-calcium/final_merged_data_670000_out.csv
# Merging viz-calcium-network/posinclust/positions_160000_in.csv, Isomap2/calcium-posinclust//positions_160000_in.csv and merged-calcium/merged_data_160000.csv into final-merged-calcium/final_merged_data_160000_in.csv...
# Merged viz-calcium-network/posinclust/positions_160000_in.csv,Isomap2/calcium-posinclust//positions_160000_in.csv and merged-calcium/merged_data_160000.csv into final-merged-calcium/final_merged_data_160000_in.csv
# Merging viz-calcium-network/posinclust/positions_430000_out.csv, Isomap2/calcium-posinclust//positions_430000_out.csv and merged-calcium/merged_data_430000.csv into final-merged-calcium/final_merged_data_430000_out.csv...
# Merged viz-calcium-network/posinclust/positions_430000_out.csv,Isomap2/calcium-posinclust//positions_430000_out.csv and merged-calcium/merged_data_430000.csv into final-merged-calcium/final_merged_data_430000_out.csv
# Merging viz-calcium-network/posinclust/positions_540000_in.csv, Isomap2/calcium-posinclust//positions_540000_in.csv and merged-calcium/merged_data_540000.csv into final-merged-calcium/final_merged_data_540000_in.csv...
# Merged viz-calcium-network/posinclust/positions_540000_in.csv,Isomap2/calcium-posinclust//positions_540000_in.csv and merged-calcium/merged_data_540000.csv into final-merged-calcium/final_merged_data_540000_in.csv
# Merging viz-calcium-network/posinclust/positions_880000_in.csv, Isomap2/calcium-posinclust//positions_880000_in.csv and merged-calcium/merged_data_880000.csv into final-merged-calcium/final_merged_data_880000_in.csv...
# Merged viz-calcium-network/posinclust/positions_880000_in.csv,Isomap2/calcium-posinclust//positions_880000_in.csv and merged-calcium/merged_data_880000.csv into final-merged-calcium/final_merged_data_880000_in.csv
# Merging viz-calcium-network/posinclust/positions_320000_out.csv, Isomap2/calcium-posinclust//positions_320000_out.csv and merged-calcium/merged_data_320000.csv into final-merged-calcium/final_merged_data_320000_out.csv...
# Merged viz-calcium-network/posinclust/positions_320000_out.csv,Isomap2/calcium-posinclust//positions_320000_out.csv and merged-calcium/merged_data_320000.csv into final-merged-calcium/final_merged_data_320000_out.csv
# Merging viz-calcium-network/posinclust/positions_340000_out.csv, Isomap2/calcium-posinclust//positions_340000_out.csv and merged-calcium/merged_data_340000.csv into final-merged-calcium/final_merged_data_340000_out.csv...
# Merged viz-calcium-network/posinclust/positions_340000_out.csv,Isomap2/calcium-posinclust//positions_340000_out.csv and merged-calcium/merged_data_340000.csv into final-merged-calcium/final_merged_data_340000_out.csv
# Merging viz-calcium-network/posinclust/positions_860000_out.csv, Isomap2/calcium-posinclust//positions_860000_out.csv and merged-calcium/merged_data_860000.csv into final-merged-calcium/final_merged_data_860000_out.csv...
# Merged viz-calcium-network/posinclust/positions_860000_out.csv,Isomap2/calcium-posinclust//positions_860000_out.csv and merged-calcium/merged_data_860000.csv into final-merged-calcium/final_merged_data_860000_out.csv
# Merging viz-calcium-network/posinclust/positions_350000_out.csv, Isomap2/calcium-posinclust//positions_350000_out.csv and merged-calcium/merged_data_350000.csv into final-merged-calcium/final_merged_data_350000_out.csv...
# Merged viz-calcium-network/posinclust/positions_350000_out.csv,Isomap2/calcium-posinclust//positions_350000_out.csv and merged-calcium/merged_data_350000.csv into final-merged-calcium/final_merged_data_350000_out.csv
# Merging viz-calcium-network/posinclust/positions_420000_out.csv, Isomap2/calcium-posinclust//positions_420000_out.csv and merged-calcium/merged_data_420000.csv into final-merged-calcium/final_merged_data_420000_out.csv...
# File Isomap2/calcium-posinclust//positions_420000_out.csv not found. Skipping to next file.
# Merging viz-calcium-network/posinclust/positions_450000_in.csv, Isomap2/calcium-posinclust//positions_450000_in.csv and merged-calcium/merged_data_450000.csv into final-merged-calcium/final_merged_data_450000_in.csv...
# Merged viz-calcium-network/posinclust/positions_450000_in.csv,Isomap2/calcium-posinclust//positions_450000_in.csv and merged-calcium/merged_data_450000.csv into final-merged-calcium/final_merged_data_450000_in.csv
# Merging viz-calcium-network/posinclust/positions_510000_out.csv, Isomap2/calcium-posinclust//positions_510000_out.csv and merged-calcium/merged_data_510000.csv into final-merged-calcium/final_merged_data_510000_out.csv...
# Merged viz-calcium-network/posinclust/positions_510000_out.csv,Isomap2/calcium-posinclust//positions_510000_out.csv and merged-calcium/merged_data_510000.csv into final-merged-calcium/final_merged_data_510000_out.csv
# Merging viz-calcium-network/posinclust/positions_320000_in.csv, Isomap2/calcium-posinclust//positions_320000_in.csv and merged-calcium/merged_data_320000.csv into final-merged-calcium/final_merged_data_320000_in.csv...
# Merged viz-calcium-network/posinclust/positions_320000_in.csv,Isomap2/calcium-posinclust//positions_320000_in.csv and merged-calcium/merged_data_320000.csv into final-merged-calcium/final_merged_data_320000_in.csv
# Merging viz-calcium-network/posinclust/positions_370000_in.csv, Isomap2/calcium-posinclust//positions_370000_in.csv and merged-calcium/merged_data_370000.csv into final-merged-calcium/final_merged_data_370000_in.csv...
# Merged viz-calcium-network/posinclust/positions_370000_in.csv,Isomap2/calcium-posinclust//positions_370000_in.csv and merged-calcium/merged_data_370000.csv into final-merged-calcium/final_merged_data_370000_in.csv
# Merging viz-calcium-network/posinclust/positions_240000_out.csv, Isomap2/calcium-posinclust//positions_240000_out.csv and merged-calcium/merged_data_240000.csv into final-merged-calcium/final_merged_data_240000_out.csv...
# Merged viz-calcium-network/posinclust/positions_240000_out.csv,Isomap2/calcium-posinclust//positions_240000_out.csv and merged-calcium/merged_data_240000.csv into final-merged-calcium/final_merged_data_240000_out.csv
# Merging viz-calcium-network/posinclust/positions_40000_in.csv, Isomap2/calcium-posinclust//positions_40000_in.csv and merged-calcium/merged_data_40000.csv into final-merged-calcium/final_merged_data_40000_in.csv...
# Merged viz-calcium-network/posinclust/positions_40000_in.csv,Isomap2/calcium-posinclust//positions_40000_in.csv and merged-calcium/merged_data_40000.csv into final-merged-calcium/final_merged_data_40000_in.csv
# Merging viz-calcium-network/posinclust/positions_140000_out.csv, Isomap2/calcium-posinclust//positions_140000_out.csv and merged-calcium/merged_data_140000.csv into final-merged-calcium/final_merged_data_140000_out.csv...
# Merged viz-calcium-network/posinclust/positions_140000_out.csv,Isomap2/calcium-posinclust//positions_140000_out.csv and merged-calcium/merged_data_140000.csv into final-merged-calcium/final_merged_data_140000_out.csv
# Merging viz-calcium-network/posinclust/positions_400000_in.csv, Isomap2/calcium-posinclust//positions_400000_in.csv and merged-calcium/merged_data_400000.csv into final-merged-calcium/final_merged_data_400000_in.csv...
# Merged viz-calcium-network/posinclust/positions_400000_in.csv,Isomap2/calcium-posinclust//positions_400000_in.csv and merged-calcium/merged_data_400000.csv into final-merged-calcium/final_merged_data_400000_in.csv
# Merging viz-calcium-network/posinclust/positions_970000_in.csv, Isomap2/calcium-posinclust//positions_970000_in.csv and merged-calcium/merged_data_970000.csv into final-merged-calcium/final_merged_data_970000_in.csv...
# Merged viz-calcium-network/posinclust/positions_970000_in.csv,Isomap2/calcium-posinclust//positions_970000_in.csv and merged-calcium/merged_data_970000.csv into final-merged-calcium/final_merged_data_970000_in.csv
# Merging viz-calcium-network/posinclust/positions_390000_out.csv, Isomap2/calcium-posinclust//positions_390000_out.csv and merged-calcium/merged_data_390000.csv into final-merged-calcium/final_merged_data_390000_out.csv...
# Merged viz-calcium-network/posinclust/positions_390000_out.csv,Isomap2/calcium-posinclust//positions_390000_out.csv and merged-calcium/merged_data_390000.csv into final-merged-calcium/final_merged_data_390000_out.csv
# Merging viz-calcium-network/posinclust/positions_590000_in.csv, Isomap2/calcium-posinclust//positions_590000_in.csv and merged-calcium/merged_data_590000.csv into final-merged-calcium/final_merged_data_590000_in.csv...
# Merged viz-calcium-network/posinclust/positions_590000_in.csv,Isomap2/calcium-posinclust//positions_590000_in.csv and merged-calcium/merged_data_590000.csv into final-merged-calcium/final_merged_data_590000_in.csv
# Merging viz-calcium-network/posinclust/positions_70000_in.csv, Isomap2/calcium-posinclust//positions_70000_in.csv and merged-calcium/merged_data_70000.csv into final-merged-calcium/final_merged_data_70000_in.csv...
# Merged viz-calcium-network/posinclust/positions_70000_in.csv,Isomap2/calcium-posinclust//positions_70000_in.csv and merged-calcium/merged_data_70000.csv into final-merged-calcium/final_merged_data_70000_in.csv
# Merging viz-calcium-network/posinclust/positions_680000_in.csv, Isomap2/calcium-posinclust//positions_680000_in.csv and merged-calcium/merged_data_680000.csv into final-merged-calcium/final_merged_data_680000_in.csv...
# Merged viz-calcium-network/posinclust/positions_680000_in.csv,Isomap2/calcium-posinclust//positions_680000_in.csv and merged-calcium/merged_data_680000.csv into final-merged-calcium/final_merged_data_680000_in.csv
# Merging viz-calcium-network/posinclust/positions_110000_out.csv, Isomap2/calcium-posinclust//positions_110000_out.csv and merged-calcium/merged_data_110000.csv into final-merged-calcium/final_merged_data_110000_out.csv...
# Merged viz-calcium-network/posinclust/positions_110000_out.csv,Isomap2/calcium-posinclust//positions_110000_out.csv and merged-calcium/merged_data_110000.csv into final-merged-calcium/final_merged_data_110000_out.csv
# Merging viz-calcium-network/posinclust/positions_300000_out.csv, Isomap2/calcium-posinclust//positions_300000_out.csv and merged-calcium/merged_data_300000.csv into final-merged-calcium/final_merged_data_300000_out.csv...
# Merged viz-calcium-network/posinclust/positions_300000_out.csv,Isomap2/calcium-posinclust//positions_300000_out.csv and merged-calcium/merged_data_300000.csv into final-merged-calcium/final_merged_data_300000_out.csv
# Merging viz-calcium-network/posinclust/positions_200000_out.csv, Isomap2/calcium-posinclust//positions_200000_out.csv and merged-calcium/merged_data_200000.csv into final-merged-calcium/final_merged_data_200000_out.csv...
# Merged viz-calcium-network/posinclust/positions_200000_out.csv,Isomap2/calcium-posinclust//positions_200000_out.csv and merged-calcium/merged_data_200000.csv into final-merged-calcium/final_merged_data_200000_out.csv
# ...
# Merged viz-calcium-network/posinclust/positions_260000_out.csv,Isomap2/calcium-posinclust//positions_260000_out.csv and merged-calcium/merged_data_260000.csv into final-merged-calcium/final_merged_data_260000_out.csv
# Merging viz-calcium-network/posinclust/positions_870000_out.csv, Isomap2/calcium-posinclust//positions_870000_out.csv and merged-calcium/merged_data_870000.csv into final-merged-calcium/final_merged_data_870000_out.csv...
# Merged viz-calcium-network/posinclust/positions_870000_out.csv,Isomap2/calcium-posinclust//positions_870000_out.csv and merged-calcium/merged_data_870000.csv into final-merged-calcium/final_merged_data_870000_out.csv
# Merging viz-calcium-network/posinclust/positions_480000_out.csv, Isomap2/calcium-posinclust//positions_480000_out.csv and merged-calcium/merged_data_480000.csv into final-merged-calcium/final_merged_data_480000_out.csv...
# Merged viz-calcium-network/posinclust/positions_480000_out.csv,Isomap2/calcium-posinclust//positions_480000_out.csv and merged-calcium/merged_data_480000.csv into final-merged-calcium/final_merged_data_480000_out.csv
# Merging viz-calcium-network/posinclust/positions_580000_in.csv, Isomap2/calcium-posinclust//positions_580000_in.csv and merged-calcium/merged_data_580000.csv into final-merged-calcium/final_merged_data_580000_in.csv...
# Merged viz-calcium-network/posinclust/positions_580000_in.csv,Isomap2/calcium-posinclust//positions_580000_in.csv and merged-calcium/merged_data_580000.csv into final-merged-calcium/final_merged_data_580000_in.csv
# Merging viz-calcium-network/posinclust/positions_220000_out.csv, Isomap2/calcium-posinclust//positions_220000_out.csv and merged-calcium/merged_data_220000.csv into final-merged-calcium/final_merged_data_220000_out.csv...
# Merged viz-calcium-network/posinclust/positions_220000_out.csv,Isomap2/calcium-posinclust//positions_220000_out.csv and merged-calcium/merged_data_220000.csv into final-merged-calcium/final_merged_data_220000_out.csv
# Merging viz-calcium-network/posinclust/positions_1000000_out.csv, Isomap2/calcium-posinclust//positions_1000000_out.csv and merged-calcium/merged_data_1000000.csv into final-merged-calcium/final_merged_data_1000000_out.csv...
# File merged-calcium/merged_data_1000000.csv not found. Skipping to next file.
# Merging viz-calcium-network/posinclust/positions_120000_in.csv, Isomap2/calcium-posinclust//positions_120000_in.csv and merged-calcium/merged_data_120000.csv into final-merged-calcium/final_merged_data_120000_in.csv...
# Merged viz-calcium-network/posinclust/positions_120000_in.csv,Isomap2/calcium-posinclust//positions_120000_in.csv and merged-calcium/merged_data_120000.csv into final-merged-calcium/final_merged_data_120000_in.csv
# Merging viz-calcium-network/posinclust/positions_10000_out.csv, Isomap2/calcium-posinclust//positions_10000_out.csv and merged-calcium/merged_data_10000.csv into final-merged-calcium/final_merged_data_10000_out.csv...
# File merged-calcium/merged_data_10000.csv not found. Skipping to next file.
# Merging viz-calcium-network/posinclust/positions_310000_in.csv, Isomap2/calcium-posinclust//positions_310000_in.csv and merged-calcium/merged_data_310000.csv into final-merged-calcium/final_merged_data_310000_in.csv...
# Merged viz-calcium-network/posinclust/positions_310000_in.csv,Isomap2/calcium-posinclust//positions_310000_in.csv and merged-calcium/merged_data_310000.csv into final-merged-calcium/final_merged_data_310000_in.csv
# Merging viz-calcium-network/posinclust/positions_830000_out.csv, Isomap2/calcium-posinclust//positions_830000_out.csv and merged-calcium/merged_data_830000.csv into final-merged-calcium/final_merged_data_830000_out.csv...
# Merged viz-calcium-network/posinclust/positions_830000_out.csv,Isomap2/calcium-posinclust//positions_830000_out.csv and merged-calcium/merged_data_830000.csv into final-merged-calcium/final_merged_data_830000_out.csv
# Merging viz-calcium-network/posinclust/positions_90000_in.csv, Isomap2/calcium-posinclust//positions_90000_in.csv and merged-calcium/merged_data_90000.csv into final-merged-calcium/final_merged_data_90000_in.csv...
# Merged viz-calcium-network/posinclust/positions_90000_in.csv,Isomap2/calcium-posinclust//positions_90000_in.csv and merged-calcium/merged_data_90000.csv into final-merged-calcium/final_merged_data_90000_in.csv
# Merging viz-calcium-network/posinclust/positions_710000_in.csv, Isomap2/calcium-posinclust//positions_710000_in.csv and merged-calcium/merged_data_710000.csv into final-merged-calcium/final_merged_data_710000_in.csv...
# Merged viz-calcium-network/posinclust/positions_710000_in.csv,Isomap2/calcium-posinclust//positions_710000_in.csv and merged-calcium/merged_data_710000.csv into final-merged-calcium/final_merged_data_710000_in.csv
# Merging viz-calcium-network/posinclust/positions_850000_in.csv, Isomap2/calcium-posinclust//positions_850000_in.csv and merged-calcium/merged_data_850000.csv into final-merged-calcium/final_merged_data_850000_in.csv...
# Merged viz-calcium-network/posinclust/positions_850000_in.csv,Isomap2/calcium-posinclust//positions_850000_in.csv and merged-calcium/merged_data_850000.csv into final-merged-calcium/final_merged_data_850000_in.csv
# Merging viz-calcium-network/posinclust/positions_900000_in.csv, Isomap2/calcium-posinclust//positions_900000_in.csv and merged-calcium/merged_data_900000.csv into final-merged-calcium/final_merged_data_900000_in.csv...
# Merged viz-calcium-network/posinclust/positions_900000_in.csv,Isomap2/calcium-posinclust//positions_900000_in.csv and merged-calcium/merged_data_900000.csv into final-merged-calcium/final_merged_data_900000_in.csv
# Merging viz-calcium-network/posinclust/positions_140000_in.csv, Isomap2/calcium-posinclust//positions_140000_in.csv and merged-calcium/merged_data_140000.csv into final-merged-calcium/final_merged_data_140000_in.csv...
# Merged viz-calcium-network/posinclust/positions_140000_in.csv,Isomap2/calcium-posinclust//positions_140000_in.csv and merged-calcium/merged_data_140000.csv into final-merged-calcium/final_merged_data_140000_in.csv
# Merging viz-calcium-network/posinclust/positions_930000_out.csv, Isomap2/calcium-posinclust//positions_930000_out.csv and merged-calcium/merged_data_930000.csv into final-merged-calcium/final_merged_data_930000_out.csv...
# Merged viz-calcium-network/posinclust/positions_930000_out.csv,Isomap2/calcium-posinclust//positions_930000_out.csv and merged-calcium/merged_data_930000.csv into final-merged-calcium/final_merged_data_930000_out.csv
# Merging viz-calcium-network/posinclust/positions_260000_in.csv, Isomap2/calcium-posinclust//positions_260000_in.csv and merged-calcium/merged_data_260000.csv into final-merged-calcium/final_merged_data_260000_in.csv...
# Merged viz-calcium-network/posinclust/positions_260000_in.csv,Isomap2/calcium-posinclust//positions_260000_in.csv and merged-calcium/merged_data_260000.csv into final-merged-calcium/final_merged_data_260000_in.csv
# Merging viz-calcium-network/posinclust/positions_400000_out.csv, Isomap2/calcium-posinclust//positions_400000_out.csv and merged-calcium/merged_data_400000.csv into final-merged-calcium/final_merged_data_400000_out.csv...
# Merged viz-calcium-network/posinclust/positions_400000_out.csv,Isomap2/calcium-posinclust//positions_400000_out.csv and merged-calcium/merged_data_400000.csv into final-merged-calcium/final_merged_data_400000_out.csv
# Merging viz-calcium-network/posinclust/positions_940000_in.csv, Isomap2/calcium-posinclust//positions_940000_in.csv and merged-calcium/merged_data_940000.csv into final-merged-calcium/final_merged_data_940000_in.csv...
# Merged viz-calcium-network/posinclust/positions_940000_in.csv,Isomap2/calcium-posinclust//positions_940000_in.csv and merged-calcium/merged_data_940000.csv into final-merged-calcium/final_merged_data_940000_in.csv
# Merging viz-calcium-network/posinclust/positions_180000_in.csv, Isomap2/calcium-posinclust//positions_180000_in.csv and merged-calcium/merged_data_180000.csv into final-merged-calcium/final_merged_data_180000_in.csv...
# Merged viz-calcium-network/posinclust/positions_180000_in.csv,Isomap2/calcium-posinclust//positions_180000_in.csv and merged-calcium/merged_data_180000.csv into final-merged-calcium/final_merged_data_180000_in.csv
# Merging viz-calcium-network/posinclust/positions_600000_out.csv, Isomap2/calcium-posinclust//positions_600000_out.csv and merged-calcium/merged_data_600000.csv into final-merged-calcium/final_merged_data_600000_out.csv...
# Merged viz-calcium-network/posinclust/positions_600000_out.csv,Isomap2/calcium-posinclust//positions_600000_out.csv and merged-calcium/merged_data_600000.csv into final-merged-calcium/final_merged_data_600000_out.csv
# Merging viz-calcium-network/posinclust/positions_530000_out.csv, Isomap2/calcium-posinclust//positions_530000_out.csv and merged-calcium/merged_data_530000.csv into final-merged-calcium/final_merged_data_530000_out.csv...
# Merged viz-calcium-network/posinclust/positions_530000_out.csv,Isomap2/calcium-posinclust//positions_530000_out.csv and merged-calcium/merged_data_530000.csv into final-merged-calcium/final_merged_data_530000_out.csv
# Merging viz-calcium-network/posinclust/positions_30000_in.csv, Isomap2/calcium-posinclust//positions_30000_in.csv and merged-calcium/merged_data_30000.csv into final-merged-calcium/final_merged_data_30000_in.csv...
# Merged viz-calcium-network/posinclust/positions_30000_in.csv,Isomap2/calcium-posinclust//positions_30000_in.csv and merged-calcium/merged_data_30000.csv into final-merged-calcium/final_merged_data_30000_in.csv
# Merging viz-calcium-network/posinclust/positions_640000_in.csv, Isomap2/calcium-posinclust//positions_640000_in.csv and merged-calcium/merged_data_640000.csv into final-merged-calcium/final_merged_data_640000_in.csv...
# Merged viz-calcium-network/posinclust/positions_640000_in.csv,Isomap2/calcium-posinclust//positions_640000_in.csv and merged-calcium/merged_data_640000.csv into final-merged-calcium/final_merged_data_640000_in.csv
# Merging viz-calcium-network/posinclust/positions_600000_in.csv, Isomap2/calcium-posinclust//positions_600000_in.csv and merged-calcium/merged_data_600000.csv into final-merged-calcium/final_merged_data_600000_in.csv...
# Merged viz-calcium-network/posinclust/positions_600000_in.csv,Isomap2/calcium-posinclust//positions_600000_in.csv and merged-calcium/merged_data_600000.csv into final-merged-calcium/final_merged_data_600000_in.csv
# Merging viz-calcium-network/posinclust/positions_440000_in.csv, Isomap2/calcium-posinclust//positions_440000_in.csv and merged-calcium/merged_data_440000.csv into final-merged-calcium/final_merged_data_440000_in.csv...
# Merged viz-calcium-network/posinclust/positions_440000_in.csv,Isomap2/calcium-posinclust//positions_440000_in.csv and merged-calcium/merged_data_440000.csv into final-merged-calcium/final_merged_data_440000_in.csv
# Merging viz-calcium-network/posinclust/positions_580000_out.csv, Isomap2/calcium-posinclust//positions_580000_out.csv and merged-calcium/merged_data_580000.csv into final-merged-calcium/final_merged_data_580000_out.csv...
# Merged viz-calcium-network/posinclust/positions_580000_out.csv,Isomap2/calcium-posinclust//positions_580000_out.csv and merged-calcium/merged_data_580000.csv into final-merged-calcium/final_merged_data_580000_out.csv
# Merging viz-calcium-network/posinclust/positions_760000_in.csv, Isomap2/calcium-posinclust//positions_760000_in.csv and merged-calcium/merged_data_760000.csv into final-merged-calcium/final_merged_data_760000_in.csv...
# Merged viz-calcium-network/posinclust/positions_760000_in.csv,Isomap2/calcium-posinclust//positions_760000_in.csv and merged-calcium/merged_data_760000.csv into final-merged-calcium/final_merged_data_760000_in.csv
# Merging viz-calcium-network/posinclust/positions_560000_out.csv, Isomap2/calcium-posinclust//positions_560000_out.csv and merged-calcium/merged_data_560000.csv into final-merged-calcium/final_merged_data_560000_out.csv...
# Merged viz-calcium-network/posinclust/positions_560000_out.csv,Isomap2/calcium-posinclust//positions_560000_out.csv and merged-calcium/merged_data_560000.csv into final-merged-calcium/final_merged_data_560000_out.csv
# Merging viz-calcium-network/posinclust/positions_910000_in.csv, Isomap2/calcium-posinclust//positions_910000_in.csv and merged-calcium/merged_data_910000.csv into final-merged-calcium/final_merged_data_910000_in.csv...
# Merged viz-calcium-network/posinclust/positions_910000_in.csv,Isomap2/calcium-posinclust//positions_910000_in.csv and merged-calcium/merged_data_910000.csv into final-merged-calcium/final_merged_data_910000_in.csv
# Merging viz-calcium-network/posinclust/positions_500000_in.csv, Isomap2/calcium-posinclust//positions_500000_in.csv and merged-calcium/merged_data_500000.csv into final-merged-calcium/final_merged_data_500000_in.csv...
# Merged viz-calcium-network/posinclust/positions_500000_in.csv,Isomap2/calcium-posinclust//positions_500000_in.csv and merged-calcium/merged_data_500000.csv into final-merged-calcium/final_merged_data_500000_in.csv
# Merging viz-calcium-network/posinclust/positions_930000_in.csv, Isomap2/calcium-posinclust//positions_930000_in.csv and merged-calcium/merged_data_930000.csv into final-merged-calcium/final_merged_data_930000_in.csv...
# Merged viz-calcium-network/posinclust/positions_930000_in.csv,Isomap2/calcium-posinclust//positions_930000_in.csv and merged-calcium/merged_data_930000.csv into final-merged-calcium/final_merged_data_930000_in.csv
# Merging viz-calcium-network/posinclust/positions_800000_out.csv, Isomap2/calcium-posinclust//positions_800000_out.csv and merged-calcium/merged_data_800000.csv into final-merged-calcium/final_merged_data_800000_out.csv...
# Merged viz-calcium-network/posinclust/positions_800000_out.csv,Isomap2/calcium-posinclust//positions_800000_out.csv and merged-calcium/merged_data_800000.csv into final-merged-calcium/final_merged_data_800000_out.csv
# Merging viz-calcium-network/posinclust/positions_330000_out.csv, Isomap2/calcium-posinclust//positions_330000_out.csv and merged-calcium/merged_data_330000.csv into final-merged-calcium/final_merged_data_330000_out.csv...
# Merged viz-calcium-network/posinclust/positions_330000_out.csv,Isomap2/calcium-posinclust//positions_330000_out.csv and merged-calcium/merged_data_330000.csv into final-merged-calcium/final_merged_data_330000_out.csv
# Merging viz-calcium-network/posinclust/positions_20000_out.csv, Isomap2/calcium-posinclust//positions_20000_out.csv and merged-calcium/merged_data_20000.csv into final-merged-calcium/final_merged_data_20000_out.csv...
# File merged-calcium/merged_data_20000.csv not found. Skipping to next file.
# Merging viz-calcium-network/posinclust/positions_360000_out.csv, Isomap2/calcium-posinclust//positions_360000_out.csv and merged-calcium/merged_data_360000.csv into final-merged-calcium/final_merged_data_360000_out.csv...
# Merged viz-calcium-network/posinclust/positions_360000_out.csv,Isomap2/calcium-posinclust//positions_360000_out.csv and merged-calcium/merged_data_360000.csv into final-merged-calcium/final_merged_data_360000_out.csv
# Merging viz-calcium-network/posinclust/positions_820000_out.csv, Isomap2/calcium-posinclust//positions_820000_out.csv and merged-calcium/merged_data_820000.csv into final-merged-calcium/final_merged_data_820000_out.csv...
# Merged viz-calcium-network/posinclust/positions_820000_out.csv,Isomap2/calcium-posinclust//positions_820000_out.csv and merged-calcium/merged_data_820000.csv into final-merged-calcium/final_merged_data_820000_out.csv
# Merging viz-calcium-network/posinclust/positions_830000_in.csv, Isomap2/calcium-posinclust//positions_830000_in.csv and merged-calcium/merged_data_830000.csv into final-merged-calcium/final_merged_data_830000_in.csv...
# Merged viz-calcium-network/posinclust/positions_830000_in.csv,Isomap2/calcium-posinclust//positions_830000_in.csv and merged-calcium/merged_data_830000.csv into final-merged-calcium/final_merged_data_830000_in.csv
# Completed final data merge and normalization process. Wrote log file: simmergefin.log

# %%
max(5,7)

# %%
## Clean up cluster labels final merged files 

import pandas as pd
import os

# Path to the directory where the output files from the first script are saved
# output_directory = 'final-merged-lesion-natgrid' #finalmergedcalcium #stimulus-natgrid'
# clean_directory = 'clean_final-lesion-natgrid' #-stimulus-natgrid'
# output_prefix = "lesion"  #"stimulus" #
output_directory = 'final-merged-stimulus-natgrid'
clean_directory = 'clean_final-stimulus-natgrid'
output_prefix = "stimulus" #

def post_process_clustering(col):
    col = col.copy()
    col_max = col.max()
    was_dirty = False
    max_count = (col == col_max).sum()
    print("max_count",max_count)
    if max_count == 1:
        col[col == col_max] = col_max-1
        #col_max -= 1
    value = 1
    #for value in range(1, col_max + 1:
    while value < col_max:
        count = (col == value).sum()
        if count == 0 or count == 1:
            print(f"value dirty: {value}")
            was_dirty = True
            col[col == col_max] = value
            print("col_max",col_max)
            col_max -= 1
        value += 1
    return col, was_dirty

# Path to the directory where the cleaned files will be saved
if not os.path.exists(clean_directory):
    os.makedirs(clean_directory)

# Loop through the files in the output directory
for filename in os.listdir(output_directory):
    if filename.startswith('final_merged_data_'):
        print(f"Processing file: {filename}")  # Debug statement

        # Load the file
        #file_path = os.path.join(output_directory, filename)
        #data = pd.read_csv(file_path, header=0)
        # Read the header separately
        file_path = os.path.join(output_directory, filename)
        with open(file_path, 'r') as f:
            header_line = f.readline().strip()

        # Read the data without the header
        data = pd.read_csv(file_path, header=None, skiprows=1)
        data.columns = header_line.split(',')

        # Post-process Clustering columns
        for col_name in data.columns:
            if "Clustering" in col_name or "Heatmap" in col_name:
                print(f"  Processing column: {col_name}")  # Debug statement
                was_dirty = True
                iteration = 0
                #while was_dirty :
                while was_dirty and iteration < 12:  #data[col_name].max():
                    print(f"    Iteration: {iteration}")  # Debug statement
                    cleaned_col, was_dirty = post_process_clustering(data[col_name])
                    data[col_name] = cleaned_col
                    iteration += 1

                
        # Split the filename by the underscore character
        parts = filename.split('_')

        # Change the first part to "lesion"
        parts[0] = output_prefix #"stimulus" #"lesion"

        # Join the parts back together with underscores
        new_filename = '_'.join(parts)

        # Save the cleaned data to the new directory
        cleaned_file_path = os.path.join(clean_directory, new_filename)
        data.to_csv(cleaned_file_path, index=False)

        print(f"  File {filename} processed and saved.")  # Debug statement
                  
        #break

print("Post-processing complete, cleaned files saved in", clean_directory)
# Out:
# Processing file: final_merged_data_360000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 13545
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 14
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_360000_out.csv processed and saved.
# Processing file: final_merged_data_50000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 7
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 23
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 23
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 24670
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 24670
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 145
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 5
#   File final_merged_data_50000_out.csv processed and saved.
# Processing file: final_merged_data_300000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
# value dirty: 1
# col_max 10
#     Iteration: 1
# max_count 32
# value dirty: 1
# col_max 9
#     Iteration: 2
# max_count 12906
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 12548
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 3
# value dirty: 1
# col_max 131
#     Iteration: 1
# max_count 4
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_300000_out.csv processed and saved.
# Processing file: final_merged_data_860000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 5
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 21790
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 2
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_860000_out.csv processed and saved.
# Processing file: final_merged_data_660000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 21790
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 2
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_660000_out.csv processed and saved.
# Processing file: final_merged_data_940000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 21790
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 2
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_940000_in.csv processed and saved.
# Processing file: final_merged_data_640000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 5
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 21790
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 2
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_640000_out.csv processed and saved.
# Processing file: final_merged_data_710000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 21790
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 2
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_710000_in.csv processed and saved.
# Processing file: final_merged_data_310000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
# value dirty: 1
# col_max 10
# value dirty: 2
# col_max 9
#     Iteration: 1
# max_count 24568
# value dirty: 1
# col_max 8
#     Iteration: 2
# max_count 20239
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 13063
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 812
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_310000_in.csv processed and saved.
# Processing file: final_merged_data_980000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
# value dirty: 9
# col_max 10
#     Iteration: 1
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 21790
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 2
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_980000_in.csv processed and saved.
# Processing file: final_merged_data_780000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 21790
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 2
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_780000_in.csv processed and saved.
# Processing file: final_merged_data_450000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 3
# value dirty: 9
# col_max 10
#     Iteration: 1
# max_count 4
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 12691
# value dirty: 3
# col_max 10
#     Iteration: 1
# max_count 3661
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 5
# value dirty: 1
# col_max 135
#     Iteration: 1
# max_count 69
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_450000_in.csv processed and saved.
# Processing file: final_merged_data_510000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 12731
# value dirty: 4
# col_max 10
#     Iteration: 1
# max_count 3335
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 6
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 3
#   File final_merged_data_510000_in.csv processed and saved.
# Processing file: final_merged_data_530000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
# value dirty: 9
# col_max 10
#     Iteration: 1
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 12458
# value dirty: 2
# col_max 10
#     Iteration: 1
# max_count 3369
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 6
# value dirty: 1
# col_max 139
#     Iteration: 1
# max_count 22
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 3
#   File final_merged_data_530000_in.csv processed and saved.
# Processing file: final_merged_data_160000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 22
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 9650
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 18
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 5
#   File final_merged_data_160000_in.csv processed and saved.
# Processing file: final_merged_data_480000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
# value dirty: 8
# col_max 10
#     Iteration: 1
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 13779
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 3
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_480000_out.csv processed and saved.
# Processing file: final_merged_data_250000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 6
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
# value dirty: 2
# col_max 10
#     Iteration: 1
# max_count 35
# value dirty: 2
# col_max 9
#     Iteration: 2
# max_count 14965
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 13406
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 46
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_250000_in.csv processed and saved.
# Processing file: final_merged_data_740000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 21790
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 2
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_740000_out.csv processed and saved.
# Processing file: final_merged_data_450000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 3
# value dirty: 9
# col_max 10
#     Iteration: 1
# max_count 4
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 12691
# value dirty: 3
# col_max 10
#     Iteration: 1
# max_count 3661
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 5
# value dirty: 1
# col_max 135
#     Iteration: 1
# max_count 69
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_450000_out.csv processed and saved.
# Processing file: final_merged_data_560000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 14296
# value dirty: 2
# col_max 10
#     Iteration: 1
# max_count 3461
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 348
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 4
#   File final_merged_data_560000_out.csv processed and saved.
# Processing file: final_merged_data_390000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 3
# value dirty: 9
# col_max 10
#     Iteration: 1
# max_count 4
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
# value dirty: 1
# col_max 10
#     Iteration: 1
# max_count 43
# value dirty: 1
# col_max 9
#     Iteration: 2
# max_count 11971
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 13468
# value dirty: 2
# col_max 10
# value dirty: 4
# col_max 9
#     Iteration: 1
# max_count 3669
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 55
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 3
#   File final_merged_data_390000_in.csv processed and saved.
# Processing file: final_merged_data_930000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 21790
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 2
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_930000_in.csv processed and saved.
# Processing file: final_merged_data_190000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 4
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 4
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 4
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
# value dirty: 1
# col_max 10
#     Iteration: 1
# max_count 57
# value dirty: 1
# col_max 9
#     Iteration: 2
# max_count 22236
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 9178
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 87
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_190000_out.csv processed and saved.
# Processing file: final_merged_data_390000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 3
# value dirty: 9
# col_max 10
#     Iteration: 1
# max_count 4
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
# value dirty: 1
# col_max 10
#     Iteration: 1
# max_count 43
# value dirty: 1
# col_max 9
#     Iteration: 2
# max_count 11971
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 13468
# value dirty: 2
# col_max 10
# value dirty: 4
# col_max 9
#     Iteration: 1
# max_count 3669
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 55
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 3
#   File final_merged_data_390000_out.csv processed and saved.
# Processing file: final_merged_data_610000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
# value dirty: 9
# col_max 10
#     Iteration: 1
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 13621
# value dirty: 2
# col_max 10
#     Iteration: 1
# max_count 3616
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 2
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_610000_in.csv processed and saved.
# Processing file: final_merged_data_100000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 16
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
# value dirty: 2
# col_max 10
# value dirty: 3
# col_max 9
# value dirty: 7
# col_max 8
#     Iteration: 1
# max_count 3648
# value dirty: 2
# col_max 7
#     Iteration: 2
# max_count 313
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 10829
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 173
# value dirty: 1
# col_max 178
#     Iteration: 1
# max_count 5
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 4
#   File final_merged_data_100000_out.csv processed and saved.
# Processing file: final_merged_data_260000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 4
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 8
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
# value dirty: 2
# col_max 10
#     Iteration: 1
# max_count 16
# value dirty: 2
# col_max 9
#     Iteration: 2
# max_count 7003
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 13088
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 329
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 3
#   File final_merged_data_260000_out.csv processed and saved.
# Processing file: final_merged_data_430000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 10500
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 55
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_430000_in.csv processed and saved.
# Processing file: final_merged_data_310000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
# value dirty: 1
# col_max 10
# value dirty: 2
# col_max 9
#     Iteration: 1
# max_count 24568
# value dirty: 1
# col_max 8
#     Iteration: 2
# max_count 20239
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 13063
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 812
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_310000_out.csv processed and saved.
# Processing file: final_merged_data_720000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 21790
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 2
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_720000_in.csv processed and saved.
# Processing file: final_merged_data_500000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
# value dirty: 9
# col_max 10
#     Iteration: 1
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 12992
# value dirty: 2
# col_max 10
# value dirty: 3
# col_max 9
# value dirty: 4
# col_max 8
#     Iteration: 1
# max_count 4057
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 112
# value dirty: 1
# col_max 123
#     Iteration: 1
# max_count 150
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_500000_out.csv processed and saved.
# Processing file: final_merged_data_370000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 14007
# value dirty: 2
# col_max 10
#     Iteration: 1
# max_count 3372
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 4
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_370000_in.csv processed and saved.
# Processing file: final_merged_data_910000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 21790
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 2
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_910000_in.csv processed and saved.
# Processing file: final_merged_data_710000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 21790
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 2
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_710000_out.csv processed and saved.
# Processing file: final_merged_data_980000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
# value dirty: 9
# col_max 10
#     Iteration: 1
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 21790
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 2
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_980000_out.csv processed and saved.
# Processing file: final_merged_data_560000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 14296
# value dirty: 2
# col_max 10
#     Iteration: 1
# max_count 3461
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 348
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 4
#   File final_merged_data_560000_in.csv processed and saved.
# Processing file: final_merged_data_150000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 4
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 14
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 10517
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 2
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 6
#   File final_merged_data_150000_in.csv processed and saved.
# Processing file: final_merged_data_150000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 4
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 14
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 10517
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 2
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 6
#   File final_merged_data_150000_out.csv processed and saved.
# Processing file: final_merged_data_810000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
# value dirty: 9
# col_max 10
#     Iteration: 1
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 21790
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 2
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_810000_out.csv processed and saved.
# Processing file: final_merged_data_100000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 16
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
# value dirty: 2
# col_max 10
# value dirty: 3
# col_max 9
# value dirty: 7
# col_max 8
#     Iteration: 1
# max_count 3648
# value dirty: 2
# col_max 7
#     Iteration: 2
# max_count 313
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 10829
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 173
# value dirty: 1
# col_max 178
#     Iteration: 1
# max_count 5
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 4
#   File final_merged_data_100000_in.csv processed and saved.
# Processing file: final_merged_data_730000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 21790
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 2
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_730000_in.csv processed and saved.
# Processing file: final_merged_data_380000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 9
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 13247
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 3
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_380000_out.csv processed and saved.
# Processing file: final_merged_data_360000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 13545
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 14
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_360000_in.csv processed and saved.
# Processing file: final_merged_data_230000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 4
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 4
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
# value dirty: 2
# col_max 10
#     Iteration: 1
# max_count 342
# value dirty: 2
# col_max 9
#     Iteration: 2
# max_count 27782
# ...
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 23
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 23
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 24670
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 24670
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 3
# value dirty: 1
# col_max 124
#     Iteration: 1
# max_count 1109
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 3
#   File final_merged_data_40000_out.csv processed and saved.
# Processing file: final_merged_data_500000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
# value dirty: 9
# col_max 10
#     Iteration: 1
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 12992
# value dirty: 2
# col_max 10
# value dirty: 3
# col_max 9
# value dirty: 4
# col_max 8
#     Iteration: 1
# max_count 4057
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 112
# value dirty: 1
# col_max 123
#     Iteration: 1
# max_count 150
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_500000_in.csv processed and saved.
# Processing file: final_merged_data_480000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
# value dirty: 8
# col_max 10
#     Iteration: 1
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 13779
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 3
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_480000_in.csv processed and saved.
# Processing file: final_merged_data_130000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 7
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 14
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
# value dirty: 3
# col_max 10
#     Iteration: 1
# max_count 4267
# value dirty: 3
# col_max 9
#     Iteration: 2
# max_count 20393
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 9733
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 42
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_130000_in.csv processed and saved.
# Processing file: final_merged_data_950000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 21790
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 2
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_950000_in.csv processed and saved.
# Processing file: final_merged_data_120000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 12
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
# value dirty: 3
# col_max 10
#     Iteration: 1
# max_count 7307
# value dirty: 3
# col_max 9
#     Iteration: 2
# max_count 17361
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 10244
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 18
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 4
#   File final_merged_data_120000_out.csv processed and saved.
# Processing file: final_merged_data_830000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 5
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 21790
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 2
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_830000_out.csv processed and saved.
# Processing file: final_merged_data_40000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 23
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 23
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 24670
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 24670
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 3
# value dirty: 1
# col_max 124
#     Iteration: 1
# max_count 1109
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 3
#   File final_merged_data_40000_in.csv processed and saved.
# Processing file: final_merged_data_580000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 10964
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 3
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_580000_in.csv processed and saved.
# Processing file: final_merged_data_730000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 21790
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 2
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_730000_out.csv processed and saved.
# Processing file: final_merged_data_840000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 21790
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 2
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_840000_in.csv processed and saved.
# Processing file: final_merged_data_410000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 14293
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 5
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_410000_in.csv processed and saved.
# Processing file: final_merged_data_510000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 12731
# value dirty: 4
# col_max 10
#     Iteration: 1
# max_count 3335
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 6
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 3
#   File final_merged_data_510000_out.csv processed and saved.
# Processing file: final_merged_data_970000_in.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 2
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 21790
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 2
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_970000_in.csv processed and saved.
# Processing file: final_merged_data_960000_out.csv
#   Processing column: FiredHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: FiredFractionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ElectricActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: InhibitionHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: CalciumHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: SynapticInputHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: BackgroundActivityHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: GrownAxonsHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedAxonsHeatmap
#     Iteration: 0
# max_count 3
#   Processing column: GrownDendritesHeatmap
#     Iteration: 0
# max_count 1
#   Processing column: ConnectedDendritesHeatmap
#     Iteration: 0
# max_count 21790
#   Processing column: UMAPClustering
#     Iteration: 0
# max_count 2
#   Processing column: GridUMAPClustering
#     Iteration: 0
# max_count 2
#   File final_merged_data_960000_out.csv processed and saved.
# Post-processing complete, cleaned files saved in clean_final-stimulus-natgrid

# %%
# For the lesion dataset add 100000 to all nodes on disabled list to mark them with boxes
# Also remove all columns with unvarying data
import pandas as pd
import os

# Read disabled IDs
with open('disabled.txt', 'r') as f:
    disabled_ids = f.read().splitlines()
disabled_ids = [int(id) for id in disabled_ids]

# Path to the directory containing the files
#path = 'clean_final/save_lesions/'
path = 'clean_final-lesion-natgrid'

# Iterate over all files in the directory
for filename in os.listdir(path):
    if filename.endswith('.csv'):  # Check that the file is a CSV
        
        
        file_path = os.path.join(path, filename)
        #file_path = os.path.join(output_directory, filename)
        with open(file_path, 'r') as f:
            header_line = f.readline().strip()

        # Read the data without the header
        df = pd.read_csv(file_path, header=None, skiprows=1)
        df.columns = header_line.split(',')
        #df = pd.read_csv(file_path)

        # If the first column value is in the disabled list, add 100000 to that value
        df.iloc[:, 0] = df.iloc[:, 0].apply(lambda x: x + 100000 if x in disabled_ids else x)

        # Drop the columns where all values are the same
        df = df.loc[:, df.nunique() != 1]

        # Save the modified dataframe back to the file
        df.to_csv(file_path, index=False)

# %%
# For the stimulus dataset add 100000 to all nodes on stimulus list to mark them with boxes
# Also remove all columns with unvarying data
import pandas as pd
import os

# Read disabled IDs
with open('stimulus.txt', 'r') as f:
    stimulus_ids = f.read().splitlines()
stimulus_ids = [int(id) for id in stimulus_ids]

# Path to the directory containing the files
#path = 'clean_final/save_stimulus/'
path = 'clean_final-stimulus-natgrid'

# Iterate over all files in the directory
for filename in os.listdir(path):
    if filename.endswith('.csv'):  # Check that the file is a CSV
        
        
        file_path = os.path.join(path, filename)
        #file_path = os.path.join(output_directory, filename)
        with open(file_path, 'r') as f:
            header_line = f.readline().strip()

        # Read the data without the header
        df = pd.read_csv(file_path, header=None, skiprows=1)
        df.columns = header_line.split(',')
        #df = pd.read_csv(file_path)

        # If the first column value is in the disabled list, add 100000 to that value
        df.iloc[:, 0] = df.iloc[:, 0].apply(lambda x: x + 100000 if x in stimulus_ids else x)

        # Drop the columns where all values are the same
        df = df.loc[:, df.nunique() != 2]

        # Save the modified dataframe back to the file
        df.to_csv(file_path, index=False)

# %%
# For the calcium and phase1 burn-in dataset just remove all columns with unvarying data
# Debug version below
import pandas as pd
import os


# Path to the directory containing the files
path = 'final-merged-calcium' #'clean_final_calcium/'

# Iterate over all files in the directory
for filename in os.listdir(path):
    if filename.endswith('.csv'):  # Check that the file is a CSV
               
        file_path = os.path.join(path, filename)
        #file_path = os.path.join(output_directory, filename)
        with open(file_path, 'r') as f:
            header_line = f.readline().strip()

        # Read the data without the header
        df = pd.read_csv(file_path, header=None, skiprows=1)
        df.columns = header_line.split(',')
        #df = pd.read_csv(file_path)

        # Drop the columns where all values are the same
        df = df.loc[:, df.nunique() != 2]

        # Save the modified dataframe back to the file
        df.to_csv(file_path, index=False)

# %%
import os
import pandas as pd

def find_csv_files(path, depth):
    if depth == 0:
        return
    for filename in os.listdir(path):
        full_path = os.path.join(path, filename)
        if os.path.isdir(full_path):
            find_csv_files(full_path, depth - 1)
        elif filename.endswith('.csv'):
            df = pd.read_csv(full_path)
            if df.iloc[:, 4].nunique() > 1 or df.iloc[:, 4].unique()[0] != 1:
                print(full_path)

find_csv_files('umap2', 4)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-126-e4601dd640dd> in <module>
#      14                 print(full_path)
#      15
# ---> 16 find_csv_files('umap2', 4)
#
# <ipython-input-126-e4601dd640dd> in find_csv_files(path, depth)
#       8         full_path = os.path.join(path, filename)
#       9         if os.path.isdir(full_path):
# ---> 10             find_csv_files(full_path, depth - 1)
#      11         elif filename.endswith('.csv'):
#      12             df = pd.read_csv(full_path)
#
# <ipython-input-126-e4601dd640dd> in find_csv_files(path, depth)
#       8         full_path = os.path.join(path, filename)
#       9         if os.path.isdir(full_path):
# ---> 10             find_csv_files(full_path, depth - 1)
#      11         elif filename.endswith('.csv'):
#      12             df = pd.read_csv(full_path)
#
# <ipython-input-126-e4601dd640dd> in find_csv_files(path, depth)
#      11         elif filename.endswith('.csv'):
#      12             df = pd.read_csv(full_path)
# ---> 13             if df.iloc[:, 4].nunique() > 1 or df.iloc[:, 4].unique()[0] != 1:
#      14                 print(full_path)
#      15
#
# ~/.conda/envs/py3condenv/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# ~/.conda/envs/py3condenv/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1448     def _getitem_tuple(self, tup: Tuple):
#    1449
# -> 1450         self._has_valid_tuple(tup)
#    1451         with suppress(IndexingError):
#    1452             return self._getitem_lowerdim(tup)
#
# ~/.conda/envs/py3condenv/lib/python3.8/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     721         for i, k in enumerate(key):
#     722             try:
# --> 723                 self._validate_key(k, i)
#     724             except ValueError as err:
#     725                 raise ValueError(
#
# ~/.conda/envs/py3condenv/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1356             return
#    1357         elif is_integer(key):
# -> 1358             self._validate_integer(key, axis)
#    1359         elif isinstance(key, tuple):
#    1360             # a tuple should already have been caught by this point
#
# ~/.conda/envs/py3condenv/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1442         len_axis = len(self.obj._get_axis(axis))
#    1443         if key >= len_axis or key < -len_axis:
# -> 1444             raise IndexError("single positional indexer is out-of-bounds")
#    1445
#    1446     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
import pandas as pd
import os

# Path to the directory containing the files
path = 'final-merged-calcium' #'clean_final_calcium/'

# Iterate over all files in the directory
for filename in os.listdir(path):
    if filename.endswith('.csv'):  # Check that the file is a CSV
        print(f"Processing file: {filename}")  # DEBUG PRINT
        file_path = os.path.join(path, filename)

        # Read header from file
        with open(file_path, 'r') as f:
            header_line = f.readline().strip()
            print(f"Header: {header_line}")  # DEBUG PRINT

        # Read the data without the header
        df = pd.read_csv(file_path, header=None, skiprows=1)
        df.columns = header_line.split(',')

        # Print unique value counts for each column before dropping
        for col in df.columns:
            print(f"{col} unique count: {df[col].nunique()}")  # DEBUG PRINT

        # Drop the columns where all values are the same
        df = df.loc[:, df.nunique() != 1]

        # Print unique value counts for each column after dropping
        for col in df.columns:
            print(f"{col} unique count: {df[col].nunique()}")  # DEBUG PRINT

        # Save the modified dataframe back to the file
        df.to_csv(file_path, index=False)

        print(f"Finished processing file: {filename}\n")  # DEBUG PRINT
# Out:
# Processing file: final_merged_data_360000_out.csv
# Header: label,anatomy,,,FiredHeatmap,FiredFractionHeatmap,ElectricActivityHeatmap,InhibitionHeatmap,CalciumHeatmap,TargetCalciumHeatmap,SynapticInputHeatmap,BackgroundActivityHeatmap,GrownAxonsHeatmap,ConnectedAxonsHeatmap,GrownDendritesHeatmap,ConnectedDendritesHeatmap,umap,,,UMAPClustering,GridUMAPClustering,isomap,,
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49703
#     49726
#     45937
#     45884
# dtype: int64
#  unique count:     49958
#     49952
#     49703
#     49726
#     45937
#     45884
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49919
#  unique count:     49958
#     49952
#     49703
#     49726
#     45937
#     45884
# dtype: int64
#  unique count:     49958
#     49952
#     49703
#     49726
#     45937
#     45884
# dtype: int64
# UMAPClustering unique count: 129
# GridUMAPClustering unique count: 9
# isomap unique count: 46180
#  unique count:     49958
#     49952
#     49703
#     49726
#     45937
#     45884
# dtype: int64
#  unique count:     49958
#     49952
#     49703
#     49726
#     45937
#     45884
# dtype: int64
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49703
#     49726
#     45937
#     45884
# dtype: int64
#  unique count:     49958
#     49952
#     49703
#     49726
#     45937
#     45884
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49919
#  unique count:     49958
#     49952
#     49703
#     49726
#     45937
#     45884
# dtype: int64
#  unique count:     49958
#     49952
#     49703
#     49726
#     45937
#     45884
# dtype: int64
# UMAPClustering unique count: 129
# GridUMAPClustering unique count: 9
# isomap unique count: 46180
#  unique count:     49958
#     49952
#     49703
#     49726
#     45937
#     45884
# dtype: int64
#  unique count:     49958
#     49952
#     49703
#     49726
#     45937
#     45884
# dtype: int64
# Finished processing file: final_merged_data_360000_out.csv
#
# Processing file: final_merged_data_50000_out.csv
# Header: label,anatomy,,,FiredHeatmap,FiredFractionHeatmap,ElectricActivityHeatmap,InhibitionHeatmap,CalciumHeatmap,TargetCalciumHeatmap,SynapticInputHeatmap,BackgroundActivityHeatmap,GrownAxonsHeatmap,ConnectedAxonsHeatmap,GrownDendritesHeatmap,ConnectedDendritesHeatmap,umap,,,UMAPClustering,GridUMAPClustering,isomap,,,IsomapGridClustering,IsomapClustering
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49930
#     49947
#     50000
#     50000
# dtype: int64
#  unique count:     49958
#     49952
#     49930
#     49947
#     50000
#     50000
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 3
# ConnectedDendritesHeatmap unique count: 3
# umap unique count: 49961
#  unique count:     49958
#     49952
#     49930
#     49947
#     50000
#     50000
# dtype: int64
#  unique count:     49958
#     49952
#     49930
#     49947
#     50000
#     50000
# dtype: int64
# UMAPClustering unique count: 474
# GridUMAPClustering unique count: 31
# isomap unique count: 50000
#  unique count:     49958
#     49952
#     49930
#     49947
#     50000
#     50000
# dtype: int64
#  unique count:     49958
#     49952
#     49930
#     49947
#     50000
#     50000
# dtype: int64
# IsomapGridClustering unique count: 5
# IsomapClustering unique count: 7
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49930
#     49947
#     50000
#     50000
# dtype: int64
#  unique count:     49958
#     49952
#     49930
#     49947
#     50000
#     50000
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 3
# ConnectedDendritesHeatmap unique count: 3
# umap unique count: 49961
#  unique count:     49958
#     49952
#     49930
#     49947
#     50000
#     50000
# dtype: int64
#  unique count:     49958
#     49952
#     49930
#     49947
#     50000
#     50000
# dtype: int64
# UMAPClustering unique count: 474
# GridUMAPClustering unique count: 31
# isomap unique count: 50000
#  unique count:     49958
#     49952
#     49930
#     49947
#     50000
#     50000
# dtype: int64
#  unique count:     49958
#     49952
#     49930
#     49947
#     50000
#     50000
# dtype: int64
# IsomapGridClustering unique count: 5
# IsomapClustering unique count: 7
# Finished processing file: final_merged_data_50000_out.csv
#
# Processing file: final_merged_data_300000_out.csv
# Header: label,anatomy,,,FiredHeatmap,FiredFractionHeatmap,ElectricActivityHeatmap,InhibitionHeatmap,CalciumHeatmap,TargetCalciumHeatmap,SynapticInputHeatmap,BackgroundActivityHeatmap,GrownAxonsHeatmap,ConnectedAxonsHeatmap,GrownDendritesHeatmap,ConnectedDendritesHeatmap,umap,,,UMAPClustering,GridUMAPClustering,isomap,,
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49682
#     49689
#     49857
#     49812
# dtype: int64
#  unique count:     49958
#     49952
#     49682
#     49689
#     49857
#     49812
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49830
#  unique count:     49958
#     49952
#     49682
#     49689
#     49857
#     49812
# dtype: int64
#  unique count:     49958
#     49952
#     49682
#     49689
#     49857
#     49812
# dtype: int64
# UMAPClustering unique count: 131
# GridUMAPClustering unique count: 13
# isomap unique count: 49851
#  unique count:     49958
#     49952
#     49682
#     49689
#     49857
#     49812
# dtype: int64
#  unique count:     49958
#     49952
#     49682
#     49689
#     49857
#     49812
# dtype: int64
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49682
#     49689
#     49857
#     49812
# dtype: int64
#  unique count:     49958
#     49952
#     49682
#     49689
#     49857
#     49812
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49830
#  unique count:     49958
#     49952
#     49682
#     49689
#     49857
#     49812
# dtype: int64
#  unique count:     49958
#     49952
#     49682
#     49689
#     49857
#     49812
# dtype: int64
# UMAPClustering unique count: 131
# GridUMAPClustering unique count: 13
# isomap unique count: 49851
#  unique count:     49958
#     49952
#     49682
#     49689
#     49857
#     49812
# dtype: int64
#  unique count:     49958
#     49952
#     49682
#     49689
#     49857
#     49812
# dtype: int64
# Finished processing file: final_merged_data_300000_out.csv
#
# Processing file: final_merged_data_860000_out.csv
# Header: label,anatomy,,,FiredHeatmap,FiredFractionHeatmap,ElectricActivityHeatmap,InhibitionHeatmap,CalciumHeatmap,TargetCalciumHeatmap,SynapticInputHeatmap,BackgroundActivityHeatmap,GrownAxonsHeatmap,ConnectedAxonsHeatmap,GrownDendritesHeatmap,ConnectedDendritesHeatmap,umap,,,UMAPClustering,GridUMAPClustering,isomap,,,IsomapGridClustering,IsomapClustering
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49752
#     49723
#     40196
#     37610
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     40196
#     37610
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49963
#  unique count:     49958
#     49952
#     49752
#     49723
#     40196
#     37610
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     40196
#     37610
# dtype: int64
# UMAPClustering unique count: 122
# GridUMAPClustering unique count: 14
# isomap unique count: 37613
#  unique count:     49958
#     49952
#     49752
#     49723
#     40196
#     37610
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     40196
#     37610
# dtype: int64
# IsomapGridClustering unique count: 3
# IsomapClustering unique count: 2
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49752
#     49723
#     40196
#     37610
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     40196
#     37610
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49963
#  unique count:     49958
#     49952
#     49752
#     49723
#     40196
#     37610
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     40196
#     37610
# dtype: int64
# UMAPClustering unique count: 122
# GridUMAPClustering unique count: 14
# isomap unique count: 37613
#  unique count:     49958
#     49952
#     49752
#     49723
#     40196
#     37610
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     40196
#     37610
# dtype: int64
# IsomapGridClustering unique count: 3
# IsomapClustering unique count: 2
# Finished processing file: final_merged_data_860000_out.csv
#
# Processing file: final_merged_data_660000_out.csv
# Header: label,anatomy,,,FiredHeatmap,FiredFractionHeatmap,ElectricActivityHeatmap,InhibitionHeatmap,CalciumHeatmap,TargetCalciumHeatmap,SynapticInputHeatmap,BackgroundActivityHeatmap,GrownAxonsHeatmap,ConnectedAxonsHeatmap,GrownDendritesHeatmap,ConnectedDendritesHeatmap,umap,,,UMAPClustering,GridUMAPClustering,isomap,,
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49752
#     49723
#     49940
#     49909
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     49940
#     49909
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 9
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49963
#  unique count:     49958
#     49952
#     49752
#     49723
#     49940
#     49909
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     49940
#     49909
# dtype: int64
# UMAPClustering unique count: 122
# GridUMAPClustering unique count: 14
# isomap unique count: 49940
#  unique count:     49958
#     49952
#     49752
#     49723
#     49940
#     49909
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     49940
#     49909
# dtype: int64
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49752
#     49723
#     49940
#     49909
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     49940
#     49909
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 9
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49963
#  unique count:     49958
#     49952
#     49752
#     49723
#     49940
#     49909
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     49940
#     49909
# dtype: int64
# UMAPClustering unique count: 122
# GridUMAPClustering unique count: 14
# isomap unique count: 49940
#  unique count:     49958
#     49952
#     49752
#     49723
#     49940
#     49909
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     49940
#     49909
# dtype: int64
# Finished processing file: final_merged_data_660000_out.csv
#
# Processing file: final_merged_data_940000_in.csv
# Header: label,anatomy,,,FiredHeatmap,FiredFractionHeatmap,ElectricActivityHeatmap,InhibitionHeatmap,CalciumHeatmap,TargetCalciumHeatmap,SynapticInputHeatmap,BackgroundActivityHeatmap,GrownAxonsHeatmap,ConnectedAxonsHeatmap,GrownDendritesHeatmap,ConnectedDendritesHeatmap,umap,,,UMAPClustering,GridUMAPClustering,isomap,,,IsomapGridClustering,IsomapClustering
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49752
#     49723
#     34769
#     34149
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     34769
#     34149
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49963
#  unique count:     49958
#     49952
#     49752
#     49723
#     34769
#     34149
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     34769
#     34149
# dtype: int64
# UMAPClustering unique count: 122
# GridUMAPClustering unique count: 14
# isomap unique count: 34560
#  unique count:     49958
#     49952
#     49752
#     49723
#     34769
#     34149
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     34769
#     34149
# dtype: int64
# IsomapGridClustering unique count: 3
# IsomapClustering unique count: 3
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49752
#     49723
#     34769
#     34149
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     34769
#     34149
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49963
#  unique count:     49958
#     49952
#     49752
#     49723
#     34769
#     34149
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     34769
#     34149
# dtype: int64
# UMAPClustering unique count: 122
# GridUMAPClustering unique count: 14
# isomap unique count: 34560
#  unique count:     49958
#     49952
#     49752
#     49723
#     34769
#     34149
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     34769
#     34149
# dtype: int64
# IsomapGridClustering unique count: 3
# IsomapClustering unique count: 3
# Finished processing file: final_merged_data_940000_in.csv
#
# Processing file: final_merged_data_640000_out.csv
# Header: label,anatomy,,,FiredHeatmap,FiredFractionHeatmap,ElectricActivityHeatmap,InhibitionHeatmap,CalciumHeatmap,TargetCalciumHeatmap,SynapticInputHeatmap,BackgroundActivityHeatmap,GrownAxonsHeatmap,ConnectedAxonsHeatmap,GrownDendritesHeatmap,ConnectedDendritesHeatmap,umap,,,UMAPClustering,GridUMAPClustering,isomap,,
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49752
#     49723
#     49865
#     49854
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     49865
#     49854
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49963
#  unique count:     49958
#     49952
#     49752
#     49723
#     49865
#     49854
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     49865
#     49854
# dtype: int64
# UMAPClustering unique count: 122
# GridUMAPClustering unique count: 14
# isomap unique count: 49874
#  unique count:     49958
#     49952
#     49752
#     49723
#     49865
#     49854
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     49865
#     49854
# dtype: int64
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49752
#     49723
#     49865
#     49854
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     49865
#     49854
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49963
#  unique count:     49958
#     49952
#     49752
#     49723
#     49865
#     49854
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     49865
#     49854
# dtype: int64
# UMAPClustering unique count: 122
# GridUMAPClustering unique count: 14
# isomap unique count: 49874
#  unique count:     49958
#     49952
#     49752
#     49723
#     49865
#     49854
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     49865
#     49854
# dtype: int64
# Finished processing file: final_merged_data_640000_out.csv
#
# Processing file: final_merged_data_710000_in.csv
# Header: label,anatomy,,,FiredHeatmap,FiredFractionHeatmap,ElectricActivityHeatmap,InhibitionHeatmap,CalciumHeatmap,TargetCalciumHeatmap,SynapticInputHeatmap,BackgroundActivityHeatmap,GrownAxonsHeatmap,ConnectedAxonsHeatmap,GrownDendritesHeatmap,ConnectedDendritesHeatmap,umap,,,UMAPClustering,GridUMAPClustering,isomap,,,IsomapGridClustering,IsomapClustering
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49752
#     49723
#     49382
#     49249
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     49382
#     49249
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 9
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49963
#  unique count:     49958
#     49952
#     49752
#     49723
#     49382
#     49249
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     49382
#     49249
# dtype: int64
# UMAPClustering unique count: 122
# GridUMAPClustering unique count: 14
# isomap unique count: 48392
#  unique count:     49958
#     49952
#     49752
#     49723
#     49382
#     49249
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     49382
#     49249
# dtype: int64
# IsomapGridClustering unique count: 2
# IsomapClustering unique count: 2
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49752
#     49723
#     49382
#     49249
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     49382
#     49249
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 9
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49963
#  unique count:     49958
#     49952
#     49752
#     49723
#     49382
#     49249
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     49382
#     49249
# dtype: int64
# UMAPClustering unique count: 122
# GridUMAPClustering unique count: 14
# isomap unique count: 48392
#  unique count:     49958
#     49952
#     49752
#     49723
#     49382
#     49249
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     49382
#     49249
# dtype: int64
# IsomapGridClustering unique count: 2
# IsomapClustering unique count: 2
# Finished processing file: final_merged_data_710000_in.csv
#
# Processing file: final_merged_data_310000_in.csv
# Header: label,anatomy,,,FiredHeatmap,FiredFractionHeatmap,ElectricActivityHeatmap,InhibitionHeatmap,CalciumHeatmap,TargetCalciumHeatmap,SynapticInputHeatmap,BackgroundActivityHeatmap,GrownAxonsHeatmap,ConnectedAxonsHeatmap,GrownDendritesHeatmap,ConnectedDendritesHeatmap,umap,,,UMAPClustering,GridUMAPClustering,isomap,,
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49735
#     49752
#     47059
#     48026
# dtype: int64
#  unique count:     49958
#     49952
#     49735
#     49752
#     47059
#     48026
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49907
#  unique count:     49958
#     49952
#     49735
#     49752
#     47059
#     48026
# dtype: int64
#  unique count:     49958
#     49952
#     49735
#     49752
#     47059
#     48026
# dtype: int64
# UMAPClustering unique count: 121
# GridUMAPClustering unique count: 9
# isomap unique count: 40718
#  unique count:     49958
#     49952
#     49735
#     49752
#     47059
#     48026
# dtype: int64
#  unique count:     49958
#     49952
#     49735
#     49752
#     47059
#     48026
# dtype: int64
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49735
#     49752
#     47059
#     48026
# dtype: int64
#  unique count:     49958
#     49952
#     49735
#     49752
#     47059
#     48026
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49907
#  unique count:     49958
#     49952
#     49735
#     49752
#     47059
#     48026
# dtype: int64
#  unique count:     49958
#     49952
#     49735
#     49752
#     47059
#     48026
# dtype: int64
# UMAPClustering unique count: 121
# GridUMAPClustering unique count: 9
# isomap unique count: 40718
#  unique count:     49958
#     49952
#     49735
#     49752
#     47059
#     48026
# dtype: int64
#  unique count:     49958
#     49952
#     49735
#     49752
#     47059
#     48026
# dtype: int64
# Finished processing file: final_merged_data_310000_in.csv
#
# Processing file: final_merged_data_980000_in.csv
# Header: label,anatomy,,,FiredHeatmap,FiredFractionHeatmap,ElectricActivityHeatmap,InhibitionHeatmap,CalciumHeatmap,TargetCalciumHeatmap,SynapticInputHeatmap,BackgroundActivityHeatmap,GrownAxonsHeatmap,ConnectedAxonsHeatmap,GrownDendritesHeatmap,ConnectedDendritesHeatmap,umap,,,UMAPClustering,GridUMAPClustering,isomap,,,IsomapGridClustering,IsomapClustering
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49752
#     49723
#     33175
#     33608
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     33175
#     33608
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49963
#  unique count:     49958
#     49952
#     49752
#     49723
#     33175
#     33608
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     33175
#     33608
# dtype: int64
# UMAPClustering unique count: 122
# GridUMAPClustering unique count: 14
# isomap unique count: 32659
#  unique count:     49958
#     49952
#     49752
#     49723
#     33175
#     33608
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     33175
#     33608
# dtype: int64
# IsomapGridClustering unique count: 2
# IsomapClustering unique count: 2
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49752
#     49723
#     33175
#     33608
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     33175
#     33608
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49963
#  unique count:     49958
#     49952
#     49752
#     49723
#     33175
#     33608
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     33175
#     33608
# dtype: int64
# UMAPClustering unique count: 122
# GridUMAPClustering unique count: 14
# isomap unique count: 32659
#  unique count:     49958
#     49952
#     49752
#     49723
#     33175
#     33608
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     33175
#     33608
# dtype: int64
# IsomapGridClustering unique count: 2
# IsomapClustering unique count: 2
# Finished processing file: final_merged_data_980000_in.csv
#
# Processing file: final_merged_data_780000_in.csv
# Header: label,anatomy,,,FiredHeatmap,FiredFractionHeatmap,ElectricActivityHeatmap,InhibitionHeatmap,CalciumHeatmap,TargetCalciumHeatmap,SynapticInputHeatmap,BackgroundActivityHeatmap,GrownAxonsHeatmap,ConnectedAxonsHeatmap,GrownDendritesHeatmap,ConnectedDendritesHeatmap,umap,,,UMAPClustering,GridUMAPClustering,isomap,,,IsomapGridClustering,IsomapClustering
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49752
#     49723
#     35870
#     35286
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     35870
#     35286
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49963
#  unique count:     49958
#     49952
#     49752
#     49723
#     35870
#     35286
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     35870
#     35286
# dtype: int64
# UMAPClustering unique count: 122
# GridUMAPClustering unique count: 14
# isomap unique count: 36966
#  unique count:     49958
#     49952
#     49752
#     49723
#     35870
#     35286
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     35870
#     35286
# dtype: int64
# IsomapGridClustering unique count: 3
# IsomapClustering unique count: 3
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49752
#     49723
#     35870
#     35286
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     35870
#     35286
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49963
#  unique count:     49958
#     49952
#     49752
#     49723
#     35870
#     35286
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     35870
#     35286
# dtype: int64
# UMAPClustering unique count: 122
# GridUMAPClustering unique count: 14
# isomap unique count: 36966
#  unique count:     49958
#     49952
#     49752
#     49723
#     35870
#     35286
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     35870
#     35286
# dtype: int64
# IsomapGridClustering unique count: 3
# IsomapClustering unique count: 3
# Finished processing file: final_merged_data_780000_in.csv
#
# Processing file: final_merged_data_450000_in.csv
# Header: label,anatomy,,,FiredHeatmap,FiredFractionHeatmap,ElectricActivityHeatmap,InhibitionHeatmap,CalciumHeatmap,TargetCalciumHeatmap,SynapticInputHeatmap,BackgroundActivityHeatmap,GrownAxonsHeatmap,ConnectedAxonsHeatmap,GrownDendritesHeatmap,ConnectedDendritesHeatmap,umap,,,UMAPClustering,GridUMAPClustering,isomap,,,IsomapGridClustering,IsomapClustering
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49766
#     49736
#     49922
#     49376
# dtype: int64
#  unique count:     49958
#     49952
#     49766
#     49736
#     49922
#     49376
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49840
#  unique count:     49958
#     49952
#     49766
#     49736
#     49922
#     49376
# dtype: int64
#  unique count:     49958
#     49952
#     49766
#     49736
#     49922
#     49376
# dtype: int64
# UMAPClustering unique count: 135
# GridUMAPClustering unique count: 12
# isomap unique count: 49992
#  unique count:     49958
#     49952
#     49766
#     49736
#     49922
#     49376
# dtype: int64
#  unique count:     49958
#     49952
#     49766
#     49736
#     49922
#     49376
# dtype: int64
# IsomapGridClustering unique count: 2
# IsomapClustering unique count: 2
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49766
#     49736
#     49922
#     49376
# dtype: int64
#  unique count:     49958
#     49952
#     49766
#     49736
#     49922
#     49376
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49840
#  unique count:     49958
#     49952
#     49766
#     49736
#     49922
#     49376
# dtype: int64
#  unique count:     49958
#     49952
#     49766
#     49736
#     49922
#     49376
# dtype: int64
# UMAPClustering unique count: 135
# GridUMAPClustering unique count: 12
# isomap unique count: 49992
#  unique count:     49958
#     49952
#     49766
#     49736
#     49922
#     49376
# dtype: int64
#  unique count:     49958
#     49952
#     49766
#     49736
#     49922
#     49376
# dtype: int64
# IsomapGridClustering unique count: 2
# IsomapClustering unique count: 2
# Finished processing file: final_merged_data_450000_in.csv
#
# Processing file: final_merged_data_510000_in.csv
# Header: label,anatomy,,,FiredHeatmap,FiredFractionHeatmap,ElectricActivityHeatmap,InhibitionHeatmap,CalciumHeatmap,TargetCalciumHeatmap,SynapticInputHeatmap,BackgroundActivityHeatmap,GrownAxonsHeatmap,ConnectedAxonsHeatmap,GrownDendritesHeatmap,ConnectedDendritesHeatmap,umap,,,UMAPClustering,GridUMAPClustering,isomap,,,IsomapGridClustering,IsomapClustering
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49942
#     49734
#     40928
#     40440
# dtype: int64
#  unique count:     49958
#     49952
#     49942
#     49734
#     40928
#     40440
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49686
#  unique count:     49958
#     49952
#     49942
#     49734
#     40928
#     40440
# dtype: int64
#  unique count:     49958
#     49952
#     49942
#     49734
#     40928
#     40440
# dtype: int64
# UMAPClustering unique count: 130
# GridUMAPClustering unique count: 8
# isomap unique count: 38404
#  unique count:     49958
#     49952
#     49942
#     49734
#     40928
#     40440
# dtype: int64
#  unique count:     49958
#     49952
#     49942
#     49734
#     40928
#     40440
# dtype: int64
# IsomapGridClustering unique count: 2
# IsomapClustering unique count: 2
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49942
#     49734
#     40928
#     40440
# dtype: int64
#  unique count:     49958
#     49952
#     49942
#     49734
#     40928
#     40440
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49686
#  unique count:     49958
#     49952
#     49942
#     49734
#     40928
#     40440
# dtype: int64
#  unique count:     49958
#     49952
#     49942
#     49734
#     40928
#     40440
# dtype: int64
# UMAPClustering unique count: 130
# GridUMAPClustering unique count: 8
# isomap unique count: 38404
#  unique count:     49958
#     49952
#     49942
#     49734
#     40928
#     40440
# dtype: int64
#  unique count:     49958
#     49952
#     49942
#     49734
#     40928
#     40440
# dtype: int64
# IsomapGridClustering unique count: 2
# IsomapClustering unique count: 2
# Finished processing file: final_merged_data_510000_in.csv
#
# Processing file: final_merged_data_530000_in.csv
# Header: label,anatomy,,,FiredHeatmap,FiredFractionHeatmap,ElectricActivityHeatmap,InhibitionHeatmap,CalciumHeatmap,TargetCalciumHeatmap,SynapticInputHeatmap,BackgroundActivityHeatmap,GrownAxonsHeatmap,ConnectedAxonsHeatmap,GrownDendritesHeatmap,ConnectedDendritesHeatmap,umap,,,UMAPClustering,GridUMAPClustering,isomap,,,IsomapGridClustering,IsomapClustering
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49744
#     49789
#     44173
#     44592
# dtype: int64
#  unique count:     49958
#     49952
#     49744
#     49789
#     44173
#     44592
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49865
#  unique count:     49958
#     49952
#     49744
#     49789
#     44173
#     44592
# dtype: int64
#  unique count:     49958
#     49952
#     49744
#     49789
#     44173
#     44592
# dtype: int64
# UMAPClustering unique count: 139
# GridUMAPClustering unique count: 22
# isomap unique count: 47039
#  unique count:     49958
#     49952
#     49744
#     49789
#     44173
#     44592
# dtype: int64
#  unique count:     49958
#     49952
#     49744
#     49789
#     44173
#     44592
# dtype: int64
# IsomapGridClustering unique count: 2
# IsomapClustering unique count: 2
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49744
#     49789
#     44173
#     44592
# dtype: int64
#  unique count:     49958
#     49952
#     49744
#     49789
#     44173
#     44592
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49865
#  unique count:     49958
#     49952
#     49744
#     49789
#     44173
#     44592
# dtype: int64
#  unique count:     49958
#     49952
#     49744
#     49789
#     44173
#     44592
# dtype: int64
# UMAPClustering unique count: 139
# GridUMAPClustering unique count: 22
# isomap unique count: 47039
#  unique count:     49958
#     49952
#     49744
#     49789
#     44173
#     44592
# dtype: int64
#  unique count:     49958
#     49952
#     49744
#     49789
#     44173
#     44592
# dtype: int64
# IsomapGridClustering unique count: 2
# IsomapClustering unique count: 2
# Finished processing file: final_merged_data_530000_in.csv
#
# Processing file: final_merged_data_160000_in.csv
# Header: label,anatomy,,,FiredHeatmap,FiredFractionHeatmap,ElectricActivityHeatmap,InhibitionHeatmap,CalciumHeatmap,TargetCalciumHeatmap,SynapticInputHeatmap,BackgroundActivityHeatmap,GrownAxonsHeatmap,ConnectedAxonsHeatmap,GrownDendritesHeatmap,ConnectedDendritesHeatmap,umap,,,UMAPClustering,GridUMAPClustering,isomap,,,IsomapGridClustering,IsomapClustering
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49781
#     49942
#     48480
#     49627
# dtype: int64
#  unique count:     49958
#     49952
#     49781
#     49942
#     48480
#     49627
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49898
#  unique count:     49958
#     49952
#     49781
#     49942
#     48480
#     49627
# dtype: int64
#  unique count:     49958
#     49952
#     49781
#     49942
#     48480
#     49627
# dtype: int64
# UMAPClustering unique count: 165
# GridUMAPClustering unique count: 10
# isomap unique count: 48779
#  unique count:     49958
#     49952
#     49781
#     49942
#     48480
#     49627
# dtype: int64
#  unique count:     49958
#     49952
#     49781
#     49942
#     48480
#     49627
# dtype: int64
# IsomapGridClustering unique count: 2
# IsomapClustering unique count: 4
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49781
#     49942
#     48480
#     49627
# dtype: int64
#  unique count:     49958
#     49952
#     49781
#     49942
#     48480
#     49627
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49898
#  unique count:     49958
#     49952
#     49781
#     49942
#     48480
#     49627
# dtype: int64
#  unique count:     49958
#     49952
#     49781
#     49942
#     48480
#     49627
# dtype: int64
# UMAPClustering unique count: 165
# GridUMAPClustering unique count: 10
# isomap unique count: 48779
#  unique count:     49958
#     49952
#     49781
#     49942
#     48480
#     49627
# dtype: int64
#  unique count:     49958
#     49952
#     49781
#     49942
#     48480
#     49627
# dtype: int64
# IsomapGridClustering unique count: 2
# IsomapClustering unique count: 4
# Finished processing file: final_merged_data_160000_in.csv
#
# Processing file: final_merged_data_480000_out.csv
# Header: label,anatomy,,,FiredHeatmap,FiredFractionHeatmap,ElectricActivityHeatmap,InhibitionHeatmap,CalciumHeatmap,TargetCalciumHeatmap,SynapticInputHeatmap,BackgroundActivityHeatmap,GrownAxonsHeatmap,ConnectedAxonsHeatmap,GrownDendritesHeatmap,ConnectedDendritesHeatmap,umap,,,UMAPClustering,GridUMAPClustering,isomap,,
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49736
#     49716
#     48523
#     49809
# dtype: int64
#  unique count:     49958
#     49952
#     49736
#     49716
#     48523
#     49809
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49836
#  unique count:     49958
#     49952
#     49736
#     49716
#     48523
#     49809
# dtype: int64
#  unique count:     49958
#     49952
#     49736
#     49716
#     48523
#     49809
# dtype: int64
# UMAPClustering unique count: 136
# GridUMAPClustering unique count: 22
# isomap unique count: 49361
#  unique count:     49958
#     49952
#     49736
#     49716
#     48523
#     49809
# dtype: int64
#  unique count:     49958
#     49952
#     49736
#     49716
#     48523
#     49809
# dtype: int64
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49736
#     49716
#     48523
#     49809
# dtype: int64
#  unique count:     49958
#     49952
#     49736
#     49716
#     48523
#     49809
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49836
#  unique count:     49958
#     49952
#     49736
#     49716
#     48523
#     49809
# dtype: int64
#  unique count:     49958
#     49952
#     49736
#     49716
#     48523
#     49809
# dtype: int64
# UMAPClustering unique count: 136
# GridUMAPClustering unique count: 22
# isomap unique count: 49361
#  unique count:     49958
#     49952
#     49736
#     49716
#     48523
#     49809
# dtype: int64
#  unique count:     49958
#     49952
#     49736
#     49716
#     48523
#     49809
# dtype: int64
# Finished processing file: final_merged_data_480000_out.csv
#
# Processing file: final_merged_data_250000_in.csv
# Header: label,anatomy,,,FiredHeatmap,FiredFractionHeatmap,ElectricActivityHeatmap,InhibitionHeatmap,CalciumHeatmap,TargetCalciumHeatmap,SynapticInputHeatmap,BackgroundActivityHeatmap,GrownAxonsHeatmap,ConnectedAxonsHeatmap,GrownDendritesHeatmap,ConnectedDendritesHeatmap,umap,,,UMAPClustering,GridUMAPClustering,isomap,,,IsomapGridClustering,IsomapClustering
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49727
#     49822
#     48147
#     45980
# dtype: int64
#  unique count:     49958
#     49952
#     49727
#     49822
#     48147
#     45980
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49962
#  unique count:     49958
#     49952
#     49727
#     49822
#     48147
#     45980
# dtype: int64
#  unique count:     49958
#     49952
#     49727
#     49822
#     48147
#     45980
# dtype: int64
# UMAPClustering unique count: 145
# GridUMAPClustering unique count: 11
# isomap unique count: 46889
#  unique count:     49958
#     49952
#     49727
#     49822
#     48147
#     45980
# dtype: int64
#  unique count:     49958
#     49952
#     49727
#     49822
#     48147
#     45980
# dtype: int64
# IsomapGridClustering unique count: 2
# IsomapClustering unique count: 3
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49727
#     49822
#     48147
#     45980
# dtype: int64
#  unique count:     49958
#     49952
#     49727
#     49822
#     48147
#     45980
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49962
#  unique count:     49958
#     49952
#     49727
#     49822
#     48147
#     45980
# dtype: int64
# ...
# GridUMAPClustering unique count: 14
# isomap unique count: 49727
#  unique count:     49958
#     49952
#     49752
#     49723
#     49308
#     49726
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     49308
#     49726
# dtype: int64
# IsomapGridClustering unique count: 2
# IsomapClustering unique count: 3
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49752
#     49723
#     49308
#     49726
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     49308
#     49726
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49963
#  unique count:     49958
#     49952
#     49752
#     49723
#     49308
#     49726
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     49308
#     49726
# dtype: int64
# UMAPClustering unique count: 122
# GridUMAPClustering unique count: 14
# isomap unique count: 49727
#  unique count:     49958
#     49952
#     49752
#     49723
#     49308
#     49726
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     49308
#     49726
# dtype: int64
# IsomapGridClustering unique count: 2
# IsomapClustering unique count: 3
# Finished processing file: final_merged_data_730000_out.csv
#
# Processing file: final_merged_data_840000_in.csv
# Header: label,anatomy,,,FiredHeatmap,FiredFractionHeatmap,ElectricActivityHeatmap,InhibitionHeatmap,CalciumHeatmap,TargetCalciumHeatmap,SynapticInputHeatmap,BackgroundActivityHeatmap,GrownAxonsHeatmap,ConnectedAxonsHeatmap,GrownDendritesHeatmap,ConnectedDendritesHeatmap,umap,,,UMAPClustering,GridUMAPClustering,isomap,,,IsomapGridClustering,IsomapClustering
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49752
#     49723
#     34349
#     34498
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     34349
#     34498
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49963
#  unique count:     49958
#     49952
#     49752
#     49723
#     34349
#     34498
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     34349
#     34498
# dtype: int64
# UMAPClustering unique count: 122
# GridUMAPClustering unique count: 14
# isomap unique count: 32469
#  unique count:     49958
#     49952
#     49752
#     49723
#     34349
#     34498
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     34349
#     34498
# dtype: int64
# IsomapGridClustering unique count: 4
# IsomapClustering unique count: 4
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49752
#     49723
#     34349
#     34498
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     34349
#     34498
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49963
#  unique count:     49958
#     49952
#     49752
#     49723
#     34349
#     34498
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     34349
#     34498
# dtype: int64
# UMAPClustering unique count: 122
# GridUMAPClustering unique count: 14
# isomap unique count: 32469
#  unique count:     49958
#     49952
#     49752
#     49723
#     34349
#     34498
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     34349
#     34498
# dtype: int64
# IsomapGridClustering unique count: 4
# IsomapClustering unique count: 4
# Finished processing file: final_merged_data_840000_in.csv
#
# Processing file: final_merged_data_410000_in.csv
# Header: label,anatomy,,,FiredHeatmap,FiredFractionHeatmap,ElectricActivityHeatmap,InhibitionHeatmap,CalciumHeatmap,TargetCalciumHeatmap,SynapticInputHeatmap,BackgroundActivityHeatmap,GrownAxonsHeatmap,ConnectedAxonsHeatmap,GrownDendritesHeatmap,ConnectedDendritesHeatmap,umap,,,UMAPClustering,GridUMAPClustering,isomap,,
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49756
#     49730
#     39693
#     39665
# dtype: int64
#  unique count:     49958
#     49952
#     49756
#     49730
#     39693
#     39665
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49941
#  unique count:     49958
#     49952
#     49756
#     49730
#     39693
#     39665
# dtype: int64
#  unique count:     49958
#     49952
#     49756
#     49730
#     39693
#     39665
# dtype: int64
# UMAPClustering unique count: 141
# GridUMAPClustering unique count: 10
# isomap unique count: 39918
#  unique count:     49958
#     49952
#     49756
#     49730
#     39693
#     39665
# dtype: int64
#  unique count:     49958
#     49952
#     49756
#     49730
#     39693
#     39665
# dtype: int64
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49756
#     49730
#     39693
#     39665
# dtype: int64
#  unique count:     49958
#     49952
#     49756
#     49730
#     39693
#     39665
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49941
#  unique count:     49958
#     49952
#     49756
#     49730
#     39693
#     39665
# dtype: int64
#  unique count:     49958
#     49952
#     49756
#     49730
#     39693
#     39665
# dtype: int64
# UMAPClustering unique count: 141
# GridUMAPClustering unique count: 10
# isomap unique count: 39918
#  unique count:     49958
#     49952
#     49756
#     49730
#     39693
#     39665
# dtype: int64
#  unique count:     49958
#     49952
#     49756
#     49730
#     39693
#     39665
# dtype: int64
# Finished processing file: final_merged_data_410000_in.csv
#
# Processing file: final_merged_data_510000_out.csv
# Header: label,anatomy,,,FiredHeatmap,FiredFractionHeatmap,ElectricActivityHeatmap,InhibitionHeatmap,CalciumHeatmap,TargetCalciumHeatmap,SynapticInputHeatmap,BackgroundActivityHeatmap,GrownAxonsHeatmap,ConnectedAxonsHeatmap,GrownDendritesHeatmap,ConnectedDendritesHeatmap,umap,,,UMAPClustering,GridUMAPClustering,isomap,,,IsomapGridClustering,IsomapClustering
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49942
#     49734
#     38428
#     38539
# dtype: int64
#  unique count:     49958
#     49952
#     49942
#     49734
#     38428
#     38539
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49686
#  unique count:     49958
#     49952
#     49942
#     49734
#     38428
#     38539
# dtype: int64
#  unique count:     49958
#     49952
#     49942
#     49734
#     38428
#     38539
# dtype: int64
# UMAPClustering unique count: 130
# GridUMAPClustering unique count: 8
# isomap unique count: 38688
#  unique count:     49958
#     49952
#     49942
#     49734
#     38428
#     38539
# dtype: int64
#  unique count:     49958
#     49952
#     49942
#     49734
#     38428
#     38539
# dtype: int64
# IsomapGridClustering unique count: 2
# IsomapClustering unique count: 2
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49942
#     49734
#     38428
#     38539
# dtype: int64
#  unique count:     49958
#     49952
#     49942
#     49734
#     38428
#     38539
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49686
#  unique count:     49958
#     49952
#     49942
#     49734
#     38428
#     38539
# dtype: int64
#  unique count:     49958
#     49952
#     49942
#     49734
#     38428
#     38539
# dtype: int64
# UMAPClustering unique count: 130
# GridUMAPClustering unique count: 8
# isomap unique count: 38688
#  unique count:     49958
#     49952
#     49942
#     49734
#     38428
#     38539
# dtype: int64
#  unique count:     49958
#     49952
#     49942
#     49734
#     38428
#     38539
# dtype: int64
# IsomapGridClustering unique count: 2
# IsomapClustering unique count: 2
# Finished processing file: final_merged_data_510000_out.csv
#
# Processing file: final_merged_data_970000_in.csv
# Header: label,anatomy,,,FiredHeatmap,FiredFractionHeatmap,ElectricActivityHeatmap,InhibitionHeatmap,CalciumHeatmap,TargetCalciumHeatmap,SynapticInputHeatmap,BackgroundActivityHeatmap,GrownAxonsHeatmap,ConnectedAxonsHeatmap,GrownDendritesHeatmap,ConnectedDendritesHeatmap,umap,,,UMAPClustering,GridUMAPClustering,isomap,,,IsomapGridClustering,IsomapClustering
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49752
#     49723
#     32395
#     32294
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     32395
#     32294
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49963
#  unique count:     49958
#     49952
#     49752
#     49723
#     32395
#     32294
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     32395
#     32294
# dtype: int64
# UMAPClustering unique count: 122
# GridUMAPClustering unique count: 14
# isomap unique count: 31914
#  unique count:     49958
#     49952
#     49752
#     49723
#     32395
#     32294
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     32395
#     32294
# dtype: int64
# IsomapGridClustering unique count: 2
# IsomapClustering unique count: 2
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49752
#     49723
#     32395
#     32294
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     32395
#     32294
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 10
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49963
#  unique count:     49958
#     49952
#     49752
#     49723
#     32395
#     32294
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     32395
#     32294
# dtype: int64
# UMAPClustering unique count: 122
# GridUMAPClustering unique count: 14
# isomap unique count: 31914
#  unique count:     49958
#     49952
#     49752
#     49723
#     32395
#     32294
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     32395
#     32294
# dtype: int64
# IsomapGridClustering unique count: 2
# IsomapClustering unique count: 2
# Finished processing file: final_merged_data_970000_in.csv
#
# Processing file: final_merged_data_960000_out.csv
# Header: label,anatomy,,,FiredHeatmap,FiredFractionHeatmap,ElectricActivityHeatmap,InhibitionHeatmap,CalciumHeatmap,TargetCalciumHeatmap,SynapticInputHeatmap,BackgroundActivityHeatmap,GrownAxonsHeatmap,ConnectedAxonsHeatmap,GrownDendritesHeatmap,ConnectedDendritesHeatmap,umap,,,UMAPClustering,GridUMAPClustering,isomap,,,IsomapGridClustering,IsomapClustering
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49752
#     49723
#     35631
#     35698
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     35631
#     35698
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 9
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49963
#  unique count:     49958
#     49952
#     49752
#     49723
#     35631
#     35698
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     35631
#     35698
# dtype: int64
# UMAPClustering unique count: 122
# GridUMAPClustering unique count: 14
# isomap unique count: 35364
#  unique count:     49958
#     49952
#     49752
#     49723
#     35631
#     35698
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     35631
#     35698
# dtype: int64
# IsomapGridClustering unique count: 2
# IsomapClustering unique count: 2
# label unique count: 50000
# anatomy unique count: 49965
#  unique count:     49958
#     49952
#     49752
#     49723
#     35631
#     35698
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     35631
#     35698
# dtype: int64
# FiredHeatmap unique count: 10
# FiredFractionHeatmap unique count: 10
# ElectricActivityHeatmap unique count: 10
# InhibitionHeatmap unique count: 9
# CalciumHeatmap unique count: 10
# TargetCalciumHeatmap unique count: 10
# SynapticInputHeatmap unique count: 10
# BackgroundActivityHeatmap unique count: 10
# GrownAxonsHeatmap unique count: 10
# ConnectedAxonsHeatmap unique count: 10
# GrownDendritesHeatmap unique count: 10
# ConnectedDendritesHeatmap unique count: 10
# umap unique count: 49963
#  unique count:     49958
#     49952
#     49752
#     49723
#     35631
#     35698
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     35631
#     35698
# dtype: int64
# UMAPClustering unique count: 122
# GridUMAPClustering unique count: 14
# isomap unique count: 35364
#  unique count:     49958
#     49952
#     49752
#     49723
#     35631
#     35698
# dtype: int64
#  unique count:     49958
#     49952
#     49752
#     49723
#     35631
#     35698
# dtype: int64
# IsomapGridClustering unique count: 2
# IsomapClustering unique count: 2
# Finished processing file: final_merged_data_960000_out.csv
